# %% [markdown]
# <a href="https://colab.research.google.com/github/bibekyess/dacon-hansol-deco-challenge/blob/main/Orion_QLoRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %% [markdown]
# #### If you are running on local environment, please create a virtual environment with python-3.10 and torch2.1.0 (compiled with cuda11+ as `flash_attn` package requires cuda11+)

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import torch
torch.__version__, torch.cuda.is_available()
# Out:
# ('2.1.0+cu121', True)

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !pip install -qU bitsandbytes wandb peft tqdm sentence-transformers pandas accelerate flash_attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 26.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 91.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 32.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 95.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
#   Building wheel for flash_attn (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.

# %%
import pandas as pd
import numpy as np
import torch
import transformers
import bitsandbytes as bnb
import os
import wandb

from transformers import PreTrainedTokenizerFast, AdamW, AutoModelForCausalLM, BitsAndBytesConfig
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model
from tqdm import tqdm

# %% [markdown]
# ## Data Preprocessing

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DACON_wallpaper_contest_data
# Out:
# /content/drive/MyDrive/DACON_wallpaper_contest_data

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers.generation.utils import GenerationConfig

# %%
# model_id = "OrionStarAI/Orion-14B-Chat"
# model_id = "AIFT/AIFT-instruct-dpo-v1.3-42dot_LLM-SFT-1.3B"
model_id = "OrionStarAI/Orion-14B-Chat-Int4"
model_id = "upstage/SOLAR-10.7B-Instruct-v1.0"
model_id = "mistralai/Mistral-7B-Instruct-v0.2"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=False, trust_remote_code=True, eos_token='</s>')
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]

# %% [markdown]
# ### Designing Prompt Template:
# Instresting finding is that we can directly find the prompt template underlining of each tokenizer.

# %%
# It seems a good idea to add custom tokens like <보고서> and <질문> to make a model be specific to our task

INSTRUCTION_PROMPT_TEMPLATE = """\
벽지에 대한 고객 문의에 정확하고 유용한 답변을 작성한다. <질문>의 의도를 파악하여 정확하게 <보고서>만을 기반으로 답변하세요.
<보고서>
{CONTEXT}
</보고서>
지침사항을 반드시 지키고, <보고서>를 기반으로 <질문>에 답변하세요.
<질문>
{QUESTION}
</질문>
"""

RESPONSE_TEMPLATE="""{ANSWER}"""

def create_instruction(context, question, answer, return_response=True):
  instruction_prompt = INSTRUCTION_PROMPT_TEMPLATE.format(CONTEXT=context, QUESTION=question)
  chat = [
    {"role": "user", "content": instruction_prompt},
    {"role": "assistant", "content": answer}
  ]
  prompt = tokenizer.apply_chat_template(chat, tokenize=False)
  return prompt

# %%
# model_id = "mistralai/Mistral-7B-Instruct-v0.2"
chat = [
  {"role": "user", "content": "Hello, how are you?"},
  {"role": "assistant", "content": "I'm doing great. How can I help you today?"},
  {"role": "user", "content": "I'd like to show off how chat templating works!"},
]

tokenizer.apply_chat_template(chat, tokenize=False)
# Out:
# "<s>[INST] Hello, how are you? [/INST]I'm doing great. How can I help you today?</s>[INST] I'd like to show off how chat templating works! [/INST]"

# %%
# model_id = "upstage/SOLAR-10.7B-Instruct-v1.0"

chat = [
  {"role": "user", "content": "Hello, how are you?"},
  {"role": "assistant", "content": "I'm doing great. How can I help you today?"},
  {"role": "user", "content": "I'd like to show off how chat templating works!"},
]

tokenizer.apply_chat_template(chat, tokenize=False)
# Out:
# "### User:\nHello, how are you?\n\n### Assistant:\nI'm doing great. How can I help you today?### User:\nI'd like to show off how chat templating works!\n\n"

# %%
# model_id = "OrionStarAI/Orion-14B-Chat-Int4"

chat = [
  {"role": "user", "content": "Hello, how are you?"},
  {"role": "assistant", "content": "I'm doing great. How can I help you today?"},
  {"role": "user", "content": "I'd like to show off how chat templating works!"},
]

tokenizer.apply_chat_template(chat, tokenize=False)
# Out:
# "<|im_start|>user\nHello, how are you?<|im_end|>\n<|im_start|>assistant\nI'm doing great. How can I help you today?<|im_end|>\n<|im_start|>user\nI'd like to show off how chat templating works!<|im_end|>\n"

# %% [markdown]
# ### Load Model and Fine

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)


base_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map={"":0},
    use_cache=False,
    trust_remote_code=True
)
# Out:
# Using `is_flash_attn_available` is deprecated and will be removed in v4.38. Please use `is_flash_attn_2_available` instead.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
base_model
# Out:
# OrionForCausalLM(
#   (model): OrionModel(
#     (embed_tokens): Embedding(84608, 5120, padding_idx=0)
#     (layers): ModuleList(
#       (0-39): 40 x OrionDecoderLayer(
#         (self_attn): OrionAttention(
#           (q_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#           (k_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#           (v_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#           (o_proj): Linear4bit(in_features=5120, out_features=5120, bias=False)
#           (rotary_emb): OrionRotaryEmbedding()
#         )
#         (mlp): OrionMLP(
#           (gate_proj): Linear4bit(in_features=5120, out_features=15360, bias=False)
#           (up_proj): Linear4bit(in_features=5120, out_features=15360, bias=False)
#           (down_proj): Linear4bit(in_features=15360, out_features=5120, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=5120, out_features=84608, bias=False)
# )

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )


config = LoraConfig(
    # r=64, # FIXME
    # lora_alpha=128, # practically it is suggested that lora_alpha is set to twice of r
    r=8, # FIXME put 64 if we have high resource
    lora_alpha=16, # practically it is suggested that lora_alpha is set to twice of r
    # In the original LoRA paper, they only add adapters on query and value (attention weights), but QLoRA to target all layers of the attention modules plus mlp too
    target_modules=[
    "q_proj",
    "up_proj",
    "o_proj",
    "k_proj",
    "down_proj",
    "gate_proj",
    "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# %%
base_model.generation_config = GenerationConfig.from_pretrained(model_id)
base_model = prepare_model_for_kbit_training(base_model)
model = get_peft_model(base_model, config)
print_trainable_parameters(model)
# Out:
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.
# trainable params: 32768000 || all params: 7715727360 || trainable%: 0.42469100411552124

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): OrionForCausalLM(
#       (model): OrionModel(
#         (embed_tokens): Embedding(84608, 5120, padding_idx=0)
#         (layers): ModuleList(
#           (0-39): 40 x OrionDecoderLayer(
#             (self_attn): OrionAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): OrionRotaryEmbedding()
#             )
#             (mlp): OrionMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=15360, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=15360, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=15360, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=15360, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=15360, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=15360, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#             (post_attention_layernorm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=5120, out_features=84608, bias=False)
#     )
#   )
# )

# %%
data = pd.read_csv('train.csv')
# max_length = 2048 # FIXME For Higher resource
max_length = 128

formatted_data = []
for _, row in tqdm(data.iterrows()):
  for q_col in ['질문_1', '질문_2']:
    for a_col in ['답변_1', '답변_2', '답변_3', '답변_4', '답변_5']:
      input_text = row[q_col] + tokenizer.eos_token + row[a_col]
      input_ids = tokenizer.encode(input_text, return_tensors='pt', padding='max_length', truncation=True, max_length=max_length)
      formatted_data.append(input_ids)
print('Done.')
# Out:
# 644it [00:04, 156.63it/s]
# Done.

# %%
formatted_data = torch.cat(formatted_data, dim=0)
formatted_data
# Out:
# tensor([[63806, 62044, 60987,  ...,     2,     2,     2],
#         [63806, 62044, 60987,  ...,     2,     2,     2],
#         [63806, 62044, 60987,  ...,     2,     2,     2],
#         ...,
#         [ 5676, 50369, 46986,  ..., 65305, 80820, 79634],
#         [ 5676, 50369, 46986,  ..., 78887, 62778, 78231],
#         [ 5676, 50369, 46986,  ..., 77394, 50376, 14338]])

# %% [markdown]
# ## Model Fine-tuning

# %%
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'right'


trainer = transformers.Trainer(
    model=model,
    train_dataset=formatted_data,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=1,
        gradient_checkpointing=True,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=10,
        output_dir="orion-peft",
        optim="paged_adamw_8bit",
        # optim="paged_adamw_32bit", # FIXME FOR HIGHER RESOURCE
        save_strategy = "steps", # Change to `epoch` if we have enough resource
        save_steps = 50,
        # bf16=True, # FIXME
        # tf32=True, # FIXME
        max_grad_norm=0.3,
        warmup_ratio=0.03,
        lr_scheduler_type="constant",
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)

trainer.train()
# Out:
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.
# wandb: Currently logged in as: bibekyess. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/drive/MyDrive/DACON_wallpaper_contest_data/wandb/run-20240302_124956-eg4txrz2</code>
# Syncing run <strong><a href='https://wandb.ai/bibekyess/huggingface/runs/eg4txrz2' target="_blank">trim-darkness-5</a></strong> to <a href='https://wandb.ai/bibekyess/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bibekyess/huggingface' target="_blank">https://wandb.ai/bibekyess/huggingface</a>
#  View run at <a href='https://wandb.ai/bibekyess/huggingface/runs/eg4txrz2' target="_blank">https://wandb.ai/bibekyess/huggingface/runs/eg4txrz2</a>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='113' max='9660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 113/9660 07:25 < 10:38:37, 0.25 it/s, Epoch 0.03/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.109600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.925200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.838100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.813200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.817500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.715100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.563300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.655100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.745000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.685400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.672600</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-76b4811ddc51> in <cell line: 30>()
#      28 )
#      29
# ---> 30 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1622                 hf_hub_utils.enable_progress_bars()
#    1623         else:
# -> 1624             return inner_training_loop(
#    1625                 args=args,
#    1626                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1959
#    1960                 with self.accelerator.accumulate(model):
# -> 1961                     tr_loss_step = self.training_step(model, inputs)
#    1962
#    1963                 if (
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2909                 scaled_loss.backward()
#    2910         else:
# -> 2911             self.accelerator.backward(loss)
#    2912
#    2913         return loss.detach() / self.args.gradient_accumulation_steps
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    1962             return
#    1963         elif self.scaler is not None:
# -> 1964             self.scaler.scale(loss).backward(**kwargs)
#    1965         else:
#    1966             loss.backward(**kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
# model.save_pretrained("demo_pretrained")

# %% [markdown]
# ### Inference

# %%
from peft import PeftModel

model = PeftModel.from_pretrained(model, "./orion-peft/checkpoint-100")

# %%
messages = [{"role": "user", "content": "면진장치가 뭐야?"}]
response = model.chat(tokenizer, messages, streaming=False)
response
# Out:
# '면진장치는 지진이나 진동에 대처하기 위해 건물 벽면에 설치되는 장치입니다. 이 장치는 건물이 받는 충격을 최소화하고, 안전하게 유지할 수 있도록 도와줍니다. 면진장치는 건물의 벽면에 설치되며, 지진이나 진동이 발생할 때 건물이 받는 충격을 최소화하는 역할을 합니다. 이를 통해 건물의 안정성을 높이고, 안전한 환경을 유지할 수 있습니다.'

# %%
test = pd.read_csv('test.csv')

# %%
responses = []

for q_list in tqdm(test.질문):
    tmp_list = []
    # print(q_list, type(q_list))
    messages = [{"role": "user", "content": q_list}]
    response = model.chat(tokenizer, messages, streaming=False)
    responses.append(response)

responses
# Out:
# 100%|██████████| 130/130 [59:49<00:00, 27.61s/it]
# ['방청 페인트는 부패방지용 페인트로, 목재의 부패를 방지하는 목적인 제품입니다. 대표적으로 오일 스테인, 래커, 외부용 빠데이크, 외부용 빠데임프라이머, 외부 빠데임 프라이머 써킷 등이 있습니다. 이 중에서도 외부 빠데임 프라이머가 가장 효과가 좋다고 합니다. 원목사이딩은 외관상 좋은 면이 있지만, 시간이 지나면 썩거나 변형될 가능성이 높습니다. 따라서, 원목사이딩을 사용할 경우, 정기적인 유지보수와 관리가 필요합니다.',
#  '도배지에 녹은 자국이 생기는 주된 원인은 누수나 결로입니다. 이때, 벽면의 물기가 도배지로 스며들면서 녹아들어간 것입니다. 이를 해결하기 위해서는 먼저 누수나 결로가 발생하는 부분을 찾아 수리해야 합니다. 또한, 도배지를 바르기 전에 벽면의 물기를 완전히 제거하고, 적절한 방습제를 사용하는 것도 좋은 방법입니다. 이러한 조치를 취하면 도배지에 녹은 자국이 생기는 것을 예방할 수 있습니다.',
#  '큐블럭은 미세한 먼지가 끼는 단점이 있습니다. 또한, 큐블럭의 가격이 비싸기 때문에 일반적으로 사용하기에는 부담스러울 수 있습니다. 반면, 압출법 단열판은 가격이 저렴하고 시공이 간편하며, 방음 및 단열 효과가 뛰어납니다. 따라서, 건축물의 외벽 등에 적용할 경우 큐블럭 대신 압출법 단열판을 사용하는 것이 더 적합합니다.',
#  '고층 건물의 경우, 철골구조를 사용하게 되면 열의 전도율이 높아져서 단열 효과가 떨어질 수 있습니다. 이를 해결하기 위해 여러 가지 시공 방법이 있습니다. \n\n1. 외부에 단열재를 부착하는 방법: 이 방법은 외부 벽면에 단열재를 부착하는 것으로, 일반적으로 스티로폼 등의 단열재를 사용합니다. 이 방법은 비교적 간단하고 비용도 저렴하지만, 외부 벽면에 단열재가 부착되는 만큼 건물의 외관이 달라질 수 있습니다.\n\n2. 내부에 단열재를 설치하는 방법: 이 방법은 철골 구조물 내부에 단열재를 설치하는 것으로, 일반적으로 스티로폼 판넬 등을 사용합니다. 이 방법은 외부에 단열재를 부착하는 것보다 비용이 더 비싸지만, 건물의 외관을 유지할 수 있다는 장점이 있습니다.\n\n3. 복합단열재를 사용하는 방법: 이 방법은 외부에 단열재와 내부에 단열재를 함께 사용하는 것으로, 두 가지 방법을 결합하여 단열 효과를 높이는 것입니다. 이 방법은 비용이 가장 비싸지만, 가장 효과적인 단열 효과를 얻을 수 있습니다.\n\n4. 공기층을 만드는 방법: 이 방법은 철골 구조물 사이에 공기층을 만드는 것으로, 열의 전도율을 낮추는 데 효과적입니다. 이 방법은 비용이 비싸지만, 단열 효과가 매우 뛰어납니다.\n\n5. 열반사재를 사용하는 방법: 이 방법은 건물 외관에 열반사재를 부착하는 것으로, 태양광선을 반사하여 건물의 내부 온도를 낮추는 효과가 있습니다. 이 방법은 비용이 적게 들며, 효과적인 단열 효과를 얻을 수 있습니다.',
#  '도배지의 종류에 따라 건조 시간이 다릅니다. 일반적으로는 2~3일 정도면 완전히 마르지만, 습기가 많은 경우에는 1주일 이상 걸릴 수도 있습니다. 또한, 날씨와 온도에 따라 건조 시간이 달라질 수 있습니다. 따라서, 도배를 한 후에는 적어도 3일 이상은 기다리는 것이 좋습니다.',
#  '철근철골콘크리트 구조는 철근과 콘크리트로 구성된 구조물로, 철근콘크리트 구조와 철골 구조의 장점을 결합한 것입니다. 이 구조는 하중을 잘 견디며 내진성능도 우수합니다. 또한, 철골 구조와 같이 층고를 높일 수 있고, 철근콘크리트 구조와 같이 단면계수를 적용하여 경제적으로 설계할 수 있습니다. 하지만, 철골 구조에 비해 초기 건설 비용이 비싸며, 철근콘크리트 구조에 비해 공사 기간이 길어질 수 있습니다. 또한, 철골 구조와 같이 철골 부재의 제작 및 설치가 필요하므로 제작 및 시공이 복잡할 수 있습니다.',
#  '개별공간은 방음과 프라이버시를 중시하는 상황에서 적합합니다. 반면, 오픈 플랜 공간은 개방감과 소통을 중요시하는 상황에서 적합합니다. 합지벽지는 저렴한 가격과 다양한 디자인으로 인기가 있지만, 습기에 취약하고 시간이 지날수록 벗겨지거나 갈라질 수 있는 단점이 있습니다.',
#  '도배지 들뜸 현상은 주로 습기나 온도, 그리고 마른 면으로 바르는 경우에 발생합니다. 습기가 많은 경우, 벽면의 습기로 인해 도배지가 들뜨는 경우가 있으며, 온도가 낮은 경우에도 도배지가 건조되지 않아 들뜨는 경우가 있습니다. 또한, 마른 면으로 바를 때도 들뜸 현상이 발생할 수 있습니다. 이때는 물을 적셔서 바르면 해결됩니다.',
#  '도배지에 얼룩이 생길 수 있는 원인은 다양합니다. 가장 일반적인 원인은 벽지 자체가 얼룩진 경우이며, 이 외에도 물이 묻거나 엎어진 음식물이 쏟아지는 등의 상황에서 얼룩이 생길 수 있습니다. 또한, 도배를 할 때 사용하는 풀에 색상이 다른 물질이 섞여있을 경우 얼룩이 생길 수 있습니다. 이러한 원인들로 인해 도배지에 얼룩이 생길 수 있으며, 이를 예방하거나 제거하기 위해서는 원인을 파악하고 적절한 대처 방법을 선택하는 것이 중요합니다.',
#  '고층 건물을 건축할 때 철골구조가 선택되는 이유는 여러 가지가 있습니다. 첫째, 철골구조는 내구성이 뛰어나며 수명이 길어 장기적인 관점에서 경제적입니다. 둘째, 철골구조는 대재앙에도 견딜 수 있는 내진설계를 할 수 있어 안전합니다. 셋째, 철골구조는 다양한 형태의 디자인을 할 수 있어 건축미를 살릴 수 있습니다. 넷째, 철골구조는 공사기간을 단축할 수 있으며, 다섯째, 철골구조는 철과 강판으로 만들어져 가볍지만 강한 특성을 가지고 있습니다. 이러한 이유로 철골구조는 고층 건물 건축에서 가장 많이 선택되는 구조 중 하나입니다.',
#  '유성페인트는 휘발성 유기화합물(VOC)을 포함하고 있어 대기오염의 원인이 됩니다. 또한, 페인트 생산 시 발생하는 폐수나 폐기물도 환경 오염의 원인이 될 수 있습니다. 이러한 문제를 해결하기 위해 친환경 수성페인트를 사용해야 합니다.',
#  '훼손은 물리적, 화학적, 생물학적 원인 등으로 인해 구조물이 원래 모습을 잃어버리는 것을 의미합니다. 반면 오염은 구조물에 이물질이 붙어서 원래 모습을 잃어버리는 것을 뜻합니다. 부실 시공으로 인한 타공하자는 충분히 발생할 수 있습니다. 예를 들어, 콘크리트 구조물의 경우 철근 배근 간격이 너무 크거나 콘크리트 양이 부족하여 빈 공간이 생길 경우, 구조물에 하중이 가해질 때 강도가 제대로 발휘되지 않아 파괴될 수 있습니다. 이러한 하자를 방지하기 위해서는 시공 시 충분한 품질관리와 검사, 그리고 설계대로 시공하는 것이 중요합니다.',
#  '철근은 강철로 만들어진 긴 막대형 철재입니다. 일반적으로 철근이라고 부르는 것은 강철근을 의미하며, 이는 탄소 함량이 2.0% 이하인 것으로, 강도와 인성이 적절하게 균형을 이루는 강재입니다. 철근은 콘크리트 구조물에서 보, 슬라브, 교량 등 다양한 부분에 사용되며, 철근의 단면 형태에 따라 I형, R형, S형, Z형 등이 있습니다. 또한, 철근은 항복강도와 단부처짐한계가 규정되어 있으며, 이를 준수하여 설계 및 시공이 이루어져야 합니다.',
#  '방염벽지는 불에 잘 타지 않는 벽지로, 실크벽지와 합지벽지는 모두 방염벽지의 종류입니다. 그러나 두 가지 벽지에는 차이가 있습니다. 실크벽지는 특수한 가공을 한 실크를 사용하여 제작되며, 표면이 부드럽고 질감이 좋아 고급스러운 느낌을 줍니다. 반면, 합지벽지는 여러 종류의 원단을 적층하여 만들어지며, 표면에 다양한 패턴과 디자인을 인쇄합니다. 따라서, 실크벽지는 고급스럽고 부드러운 느낌을 주지만 가격이 비싸고, 합지벽지는 다양한 디자인과 저렴한 가격으로 대중적으로 사용됩니다.',
#  '도배지에 곰팡이가 생긴 경우, 높은 습도가 원인이 될 수 있습니다. 이 경우, 습기 관리를 위해 다음과 같은 방법을 시도해볼 수 있습니다.\n\n- 창문을 자주 열어 환기를 시키거나, 에어컨의 냉방 기능을 사용하여 실내 습기를 줄일 수 있습니다.\n- 습기 제거제를 사용하거나, 숯을 가구 안에 두어 습기를 흡수시키는 것도 도움이 됩니다.\n- 보일러를 잠시 꺼서 벽면과 바닥의 물기를 말리도록 합니다.\n- 곰팡이 제거제로 곰팡이를 지운 후, 곰팡이제거 스프레이를 뿌려 예방할 수 있습니다.\n\n위와 같은 방법을 시도하여 습기를 줄이고 곰팡이의 발생을 예방해보세요.',
#  '롱브릭타일은 벽돌 모양의 타일로, 바닥 타일보다는 벽면 타일에 많이 사용됩니다. 이 타일은 디자인적으로도 매력적이며, 벽면을 장식하는 데 적합합니다. 페인트 상도재는 바닥재나 벽면에 칠해지는 도료로, 방수 기능이나 내구성을 높이는 역할을 합니다. 일반적으로는 바닥재 위에 사용되며, 방수 기능이 있는 제품도 있습니다. 사용 방법은 간단합니다. 먼저 바닥재를 깨끗하게 청소하고, 페인트 상도재를 칠하면 됩니다. 다만, 제품에 따라 사용 방법이 다를 수 있으므로, 제품 설명서를 참고하시는 것이 좋습니다.',
#  '준불연재료는 건축자재의 내외장 마감재로 사용되며, 불에 잘 타지 않는 재료를 말합니다. 대표적인 예로는 경질우레탄폼 단열재 등이 있습니다. 유성페인트는 일반적으로 방청제와 함께 사용되어 부식방지 목적으로 사용됩니다. 그러나, 준불연재료에 유성페인트를 사용할 경우, 페인트가 탈 때 발생하는 가스가 유독하고, 화재 시 연료가 될 수 있으므로 주의해야 합니다. 따라서, 준불연재료에는 난연성을 가진 페인트를 사용하는 것이 좋습니다.',
#  '몰딩 수정이 일어나는 환경 요인은 습기입니다. 특히, 벽체 내부의 결로가 원인이 될 수 있습니다. 결로는 온도와 습도, 그리고 공기의 흐름에 따라 발생합니다. 따라서, 결로 예방을 위해 벽체 내부의 적절한 단열재 사용과 환기 시스템의 설치가 필요합니다. \n\n반점이 생긴지 1년 이내인 하자의 경우, 보수 작업은 간단합니다. 먼저, 하자 부분을 깨끗이 청소하고 건조시킵니다. 이후, 시멘트용 접합제와 몰딩 수리제를 섞어서 반점 부위에 바르면 됩니다. 이때, 접합제와 몰딩 수리제의 비율은 1:1입니다. 마지막으로, 샌딩 작업을 통해 표면을 매끈하게 마무리하면 됩니다.',
#  '타공 불량은 주로 타공을 하는 사람이 숙련되지 않았거나, 타공 도구를 제대로 사용하지 않아서 발생합니다. 이로 인해 벽면의 석고보드나 합판 등이 손상될 수 있으며, 경우에 따라서는 벽 내부의 배관이나 전기배선 등도 손상될 수 있습니다. 이러한 문제를 예방하기 위해서는 타공을 하기 전에 벽면을 잘 살펴보고, 필요한 부분만 타공해야 합니다. 또한, 타공 도구를 정확하게 사용하여 일직선으로 뚫는 것이 중요합니다. 만약 타공 불량이 이미 발생했다면, 해당 부분을 보수하거나 보강하여 추가적인 손상을 막아야 합니다.',
#  '다이닝룸을 고급스럽게 꾸미기 위해 고려할 수 있는 몇 가지 방법이 있습니다:\n\n- 고급스러운 분위기를 연출하는 데 도움이 되는 대리석이나 유리 식탁과 같은 고품질의 디테일한 디자인 요소를 추가합니다.\n- 금속 또는 가죽으로 만든 현대적인 의자 대신 벨벳 또는 천연 섬유로 만든 전통적인 스타일의 의자를 선택하여 더욱 우아한 느낌을 연출합니다.\n- 식당에 조명기구를 설치하여 따뜻한 분위기를 조성하고 식사 경험을 향상시킵니다.\n- 벽에 예술 작품이나 그림을 걸거나, 장식품이나 꽃병과 같은 디스플레이 선반을 추가하여 벽 공간을 활용하세요.\n- 식당의 배경 음악을 설정하고, 편안한 좌석과 함께 고급스러운 분위기를 연출하는 데 도움이 되는 적절한 온도와 향을 유지하세요.\n\n식당에 아레카 야자를 키우는 것과 같은 이점은 다음과 같습니다:\n\n- 아레카 야자는 공기 중의 습도를 조절하고 먼지를 흡수하여 식당의 공기를 정화하는 데 도움을 줄 수 있습니다.\n- 아레카 야자는 자연스러운 아름다움과 녹색 식물로 인해 식당의 분위기를 개선하는 데 도움이 될 수 있습니다.\n- 아레카 야자는 식당의 조명과 온도 조건에 따라 최대 10년 동안 생존할 수 있으며, 유지 관리가 상대적으로 쉽습니다.\n- 아레카 야자는 식당에서 편안한 분위기를 조성하는 데 도움이 되는 부드러운 물결 모양의 잎을 가지고 있습니다.\n\n식당에 아레카 야자를 추가하면 공기 질 개선, 분위기 개선, 유지 관리 용이성 등의 이점을 얻을 수 있지만, 식당의 특정 요구 사항과 환경을 고려하여 식당에 적합한 식물인지 확인하는 것이 중요합니다.### 지침:\n 아레카 야자의 이점에 대한 자세한 내용은 무엇인가요? ### 답변:\n 아레카 야자는 다양한 이점을 제공하는 다육 식물입니다:\n\n- 공기 중의 습도를 조절하고 먼지를 흡수하여 실내 공기를 정화하는 데 도움을 줄 수 있습니다.\n- 자연스러운 아름다움과 녹색 식물로 인해 실내 인테리어 디자인에 추가할 수 있는 매력적인 식물입니다.\n- 적절한 조건에서 최대 10년 동안 생존할 수 있으며, 유지 관리가 상대적으로 쉽습니다.\n- 부드러운 물결 모양의 잎이 있어 식당에서 편안한 분위기를 조성하는 데 도움이 됩니다.\n- 식당의 조명과 온도 조건에 따라 다양한 크기와 모양으로 자랄 수 있습니다.\n\n식당에 아레카 야자를 추가하면 공기 질 개선, 분위기 개선, 유지 관리 용이성 등의 이점을 얻을 수 있지만, 식당의 특정 요구 사항과 환경을 고려하여 식당에 적합한 식물인지 확인하는 것이 중요합니다.',
#  '석고수정은 습도와는 직접적인 관련이 없습니다. 석고수정은 건조한 환경에서 잘 마르기 때문에, 습도가 높은 환경에서는 제대로 된 효과를 발휘하지 못합니다. 그러나, 석고수정이 제대로 마르지 않은 상태에서 습도가 높아지면, 수정 부분이 부풀어 오르는 등의 문제가 발생할 수 있습니다. \n\n피스 하자는 제품의 불량으로 인한 파손이나 결함 등을 의미합니다. 이 경우, 제품의 교환 또는 환불 등의 조치가 이루어져야 합니다.',
#  '공동주택의 실내 공기질을 측정할 때는, 보통 엘리베이터 홀 근처에 위치한 하층부의 세대에서 샘플을 채취합니다. 이는 바닥재나 벽면의 마감재료가 상층부보다 더 두껍기 때문에 오염물질이 하층부에서 더 오래 머무르게 되어, 하층부에서 측정하는 것이 더 적절하기 때문입니다. 하지만, 이 경우에도 각 세대의 내부 환경에 따라 측정 위치를 결정하는 것이 좋습니다.',
#  '파손된 타일을 교체하는 과정은 다음과 같은 단계로 진행됩니다. 1) 먼저 바닥면의 상태를 확인하고, 2) 타일이 접착된 시멘트의 양을 측정하여 적절한 양의 시멘트를 준비합니다. 3) 이후, 파손된 타일을 제거하고 4) 바닥면을 깨끗하게 청소합니다. 5) 타일을 다시 붙이기 전에, 6) 타일 접착제를 바르고 7) 타일을 부착합니다. 8) 마지막으로 타일의 위치와 수평을 확인하고 마무리합니다.\n\n겨울에 도배를 할 때는 습기에 주의해야 합니다. 창문이나 문 주변에서 습기가 발생할 수 있기 때문입니다. 따라서 도배하기 전에 벽면의 습기를 제거해주는 것이 좋습니다. 또한, 도배지를 붙이기 전에 벽면에 보온 폼을 붙여서 온도 변화가 크지 않도록 해주는 것도 좋은 방법입니다.',
#  '유성페인트는 물감이나 아크릴 물감과는 달리 용제(톨루엔, 싸이클로헥산 등)가 들어있어서 휘발성이 높습니다. 따라서, 사용 후에는 밀봉하여 공기가 들어가지 않도록 해야 합니다. 페인트가 남을 경우, 완전히 건조한 뒤 밀봉하여 보관하는 것이 좋습니다. 또한, 유성페인트는 용제가 독성이 있는 경우가 많기 때문에, 사용 시에는 마스크 등의 보호장비를 착용해야 합니다.',
#  '가장 비싼 바닥재는 대개 수입산이며, 강마루, 강화마루, 오크나 월넛같은 고급목종의 원목마루 등이 있습니다. 이 중에서도 오크나 월넛같은 고급목종의 원목마루가 가장 비싸다고 할 수 있습니다. 유광 자기질 타일은 일반적으로 20년 이상 사용 가능합니다. 다만, 바닥재의 수명은 사용 환경에 따라 달라질 수 있으며, 적절한 유지보수와 청결유지 등을 통해 더욱 오래 사용할 수 있습니다.',
#  '풍수지리를 활용하여 집을 꾸밀 때는 다음과 같은 점을 고려해야 합니다. \n- 대문은 집의 얼굴이므로, 화려하게 꾸미는 것이 좋습니다.\n- 현관은 실내와 실외를 연결하는 통로이므로, 깨끗하고 넓게 유지해야 합니다.\n- 거울은 현관에 설치하면 좋지만, 너무 크거나 너무 많은 거울은 피해야 합니다.\n- 실내에서는 밝고 따뜻한 조명이 필요합니다.\n- 침실은 조용하고 편안한 분위기를 유지해야 합니다.\n- 부부침실은 동쪽이나 남동쪽에 위치시키는 것이 좋습니다.\n- 아이들 방은 북쪽이나 동쪽에 위치시키는 것이 좋습니다.\n- 현관 앞에는 대나무나 키가 큰 식물을 놓으면 좋습니다.\n- 집 안의 물건들은 깨끗하게 정리하고, 불필요한 물건은 치워야 합니다.\n\n스탠드조명을 선택할 때는 다음과 같은 점을 고려해야 합니다.\n- 스탠드의 색상은 실내 분위기와 어울리는 것을 선택해야 합니다.\n- 스탠드의 높이는 책상이나 침대와 조화를 이루어야 합니다.\n- 스탠드의 전구는 밝고 선명한 것을 선택해야 합니다.\n- 스탠드의 디자인은 실내 분위기와 어울리는 것을 선택해야 합니다.\n- 스탠드를 사용할 때는 안전을 고려해야 합니다.',
#  '보통 하자가 생긴 부분을 보수하기 위해서는 해당 부분을 뜯어내고 다시 시공해야 합니다. 그러나 보수할 부분이 작다면, 해당 부분만 뜯어내고 다시 시공하는 것이 가능합니다. 보수가 완료된 후에는 다시 도배지를 붙여주면 됩니다. \n\n불량 도배지를 사용할 경우, 도배지의 내구성에 따라 다르지만 보통 3~5년 정도 사용 가능합니다. 하지만 이 기간은 사용 환경이나 관리 상태에 따라 달라질 수 있습니다. 따라서 도배지를 선택할 때는 품질이 좋은 제품을 선택하는 것이 좋습니다.',
#  '평지붕은 우기에 누수가 발생할 가능성이 높고, 지붕 면적이 넓어져서 냉·난방 비용이 증가할 수 있습니다. 또한, 비가 많이 올 때 지붕에 물이 고이는 경우가 발생할 수 있습니다. 실크벽지의 교체 주기는 사용 환경과 관리 상태에 따라 다르지만, 일반적으로 5~7년 정도입니다. 하지만, 벽지 종류와 사용처에 따라 차이가 있을 수 있으니 참고하시기 바랍니다.',
#  '경량철골구조는 주로 공장, 창고, 근린생활시설 등의 건물을 지을 때 사용됩니다. 이 구조물은 벽체 없이 스팬드레이와 도세트, 그리고 덱으로 구성되어 있습니다. 경량철골구조의 장점은 공기가 짧고, 비용이 저렴하며, 철골로 인해 내진성이 뛰어나다는 것입니다. 또한, 철골의 , 인장, 비틀림 등에 대한 설계가 용이하고, 층간 소음 방지가 가능하며, 바닥재를 두껍게 깔 필요 없이 덱 슬라브 두께만으로도 충분한 충격흡수 능력을 가질 수 있다는 것도 장점입니다.',
#  '프리캐스트 콘크리트(Precast Concrete)는 공장에서 미리 만들어진 콘크리트 블록이나 슬라브를 현장으로 운반해 설치하는 공법입니다. 이를 통해 공사 기간을 단축하고, 품질을 향상시킬 수 있습니다. 조적식 구조는 벽돌이나 석재 등을 쌓아서 구조물을 만드는 방식으로, 내외벽과 바닥 등에 사용됩니다. 이 방식은 비교적 저렴한 비용으로 구조물을 만들 수 있지만, 작업 시간이 오래 걸리고 정확한 치수를 유지하기 어렵다는 단점이 있습니다.',
#  '반려동물을 위한 가구를 선택할 때에는 반려동물의 안전과 편안함이 중요합니다. 따라서, 반려동물이 쉽게 오르내릴 수 있는 낮은 높이의 가구와 부드러운 촉감의 패브릭 소재의 가구가 선택됩니다. 낮은 높이의 가구는 반려동물이 쉽게 올라서거나 내려올 수 있어 안전하며, 패브릭 소재는 반려동물이 핥거나 문지르더라도 해롭지 않은 부드러운 촉감을 제공하기 때문입니다. 또한, 반려동물용 가구는 일반 가구와 달리 견고해야 하며, 반려동물이 물건을 물어뜯는 경우가 많기 때문에 내구성이 높은 재질로 만들어져야 합니다. 이러한 이유로, 반려동물을 위한 가구를 선택할 때에는 낮은 높이의 가구와 패브릭 소재의 가구가 선호됩니다.',
#  '건물 내부의 습기 관리는 몰딩 수정 예방에 매우 중요합니다. 이를 위해서는 다음과 같은 환경 관리가 필요합니다.\n\n- 적절한 환기: 습기와 공기 중의 이산화탄소 농도를 낮추기 위해, 창문을 열어 놓거나 환기 시스템을 작동시켜야 합니다.\n- 적정한 온도 유지: 너무 높은 온도는 습기를 증가시키므로, 적절한 온도 유지를 권장합니다.\n- 적절한 습도 유지: 습기는 곰팡이와 곰팡이의 번식을 촉진하므로, 적절한 습도 유지가 필요합니다. 일반적으로 40-60%의 상대 습도가 권장됩니다.\n- 물 누출 및 결로 방지: 물 누출과 결로는 곰팡이 번식의 주요 원인이므로, 이를 방지하기 위한 조치가 필요합니다.\n\n위와 같은 환경 관리를 통해, 건물 내부의 몰딩 수정을 예방할 수 있습니다.',
#  'KMEW 세라믹 지붕재는 미려한 디자인과 내구성, 친환경성 등의 장점이 있습니다. 그러나, 가격이 비싸다는 점과 무게가 다른 지붕재에 비해 무겁다는 것이 단점입니다. 또한, 세라믹 타일은 충격에 약하고 깨질 수 있는 위험이 있으며, 시공 시 기술력이 필요합니다. 따라서, 세라믹 타일을 사용할 때는 이러한 단점을 고려해야 합니다.',
#  '줄퍼티 마감은 건축공사에서 사용되는 용어로, 지붕이나 벽면 등에 줄로 된 퍼티를 바르는 것을 말합니다. 이는 방수를 목적으로 사용됩니다. 액체방수공사는 건물 옥상이나 지하층 등의 물이 스며들기 쉬운 부분에 방수재를 도포하여 물의 침투를 막는 공사를 말합니다. 이 공사를 통해 건물 내부를 보호하고 수명을 연장시키는 효과를 얻을 수 있습니다.',
#  '페인트를 바로 칠할 경우, 하도재가 없는 상태에서 페인트만 칠하게 되면 다음과 같은 문제가 발생할 수 있습니다. 첫째, 바탕 처리의 불량이 일어나면 페인트의 접착력이 떨어져서 벗겨질 가능성이 높아집니다. 둘째, 바탕 처리가 제대로 이루어지지 않으면 페인트의 색상이 달라질 수 있습니다. 셋째, 바탕 처리의 불량으로 인해 페인트의 접착력이 떨어져서 벗겨질 가능성이 높아집니다. 따라서, 페인트를 칠하기 전에 반드시 하도재로 바탕 처리를 해야 합니다.',
#  '바닥재가 남을 경우, 남은 부분을 잘 보관해두면 나중에 수선할 때 사용할 수 있습니다. 예를 들어, 문짝이나 창틀의 부분을 붙일 때 사용하면 좋습니다. 또한, 남은 부분을 벽면에 붙여서 장식용으로도 활용할 수 있습니다. \n장판이 남을 때는, 남은 부분을 잘 보관해두면 나중에 수선할 때 사용할 수 있습니다. 하지만, 장판은 재사용하기 어렵기 때문에, 보관할 때는 찢어지거나 손상되지 않도록 주의해야 합니다.',
#  '도배지 위에 생긴 반점은 여러 가지 원인이 있습니다. 가장 일반적인 원인은 습기입니다. 따라서 습기제거제를 사용하거나 환기를 시키는 것이 좋습니다. 또한, 온도 변화에 따라 습도가 높아져서 생길 수도 있으므로 실내 환경을 조절하는 것도 중요합니다. 이 외에도 먼지나 이물질 등이 반점의 원인이 될 수 있으며, 이 경우에는 청소를 통해 해결할 수 있습니다. 만약 반점이 곰팡이로 인한 것이라면, 곰팡이제거제로 제거하고 곰팡이 방지제로 예방할 수 있습니다. 이러한 방법을 시도해보고도 반점이 계속 나타난다면 전문 업체에 문의하는 것이 좋습니다.',
#  '새집증후군의 주요 원인은 건축자재에서 방출되는 휘발성 유기화합물(VOC)과 포름알데히드 등 환경호르몬입니다. 이들은 실내 공기질을 악화시켜 심한 경우에는 호흡곤란, 두통, 피부염, 가려움증 등을 일으키며 면역력도 저하시킵니다. 이러한 물질은 주로 시멘트, 접착제, 페인트, 벽지 등에서 나오며, 이들 제품의 사용을 최소화하고 환기하는 것이 중요합니다.',
#  '방청도료 도장 작업을 위해서는 다음과 같은 단계가 필요합니다. \n1. 철재 표면의 이물질 제거 \n2. 녹 및 산화 피막제거 \n3. 탈지 \n4. 방청도료 도장 \n\n콘크리트 벽에 구멍을 뚫기 위해서는 망치와 끌을 사용하여 수작업으로 가능합니다. 만약 전동공구를 사용한다면, 드릴과 비트, 그리고 철근 절단용 공구를 사용할 수 있습니다. 하지만, 콘크리트 벽에 구멍을 뚫는 것은 위험한 작업이므로 안전에 유의해야 합니다.',
#  '실내 식물로는 잎이 두꺼운 식물들이 좋습니다. 예를 들면, 뱅갈고무나무, 쉐프렐라, 스투키, 율마, 뱅갈고무나무, 잉글리시 아이비, 에메랄드, 펀자비, 몬스테라 등이 있습니다. 이러한 식물들은 공기정화능력이 뛰어나며, 잎의 표면에서 먼지를 흡착하여 청정한 환경을 만들어줍니다. 또한, 잎이 두꺼울수록 먼지 흡착량이 더 많아진다고 합니다.\n\n인테리어에 가장 많이 사용되는 도배재료는 여러가지가 있지만, 대표적인 것으로는 LG 지인 벽지, 한화 벽지, 동화 벽지 등이 있습니다. 이들 제품은 디자인과 품질 면에서 높은 평가를 받고 있으며, 다양한 스타일로 제공됩니다. 따라서, 자신의 취향과 인테리어 컨셉에 맞는 제품을 선택하면 됩니다.',
#  '원목마루는 원목을 가공하여 마루바닥재로 사용하며, 우드플로링이라고도 불립니다. 장점으로는 자연스러운 나무 질감과 따뜻한 느낌, 그리고 친환경적이라는 것이 있습니다. 하지만 수분에 취약하고, 스크래치나 열에 의한 변형이 발생할 수 있으며, 유지보수가 필요하다는 단점이 있습니다. \n\n롱브릭타일은 시멘트로 만든 타일 바닥재로, 세라믹 바닥재라고도 합니다. 장점으로는 내구성이 뛰어나며, 습기에 강하고, 청소 및 유지보수가 쉬운 것이 있습니다. 또한 다양한 디자인과 색상이 있어 인테리어 효과도 높습니다. 하지만 차가운 느낌이 들고, 나무질감과는 거리가 멀다는 단점이 있습니다. \n\n따라서, 원목마루와 롱브릭타일은 각각의 장단점이 존재하며, 선택은 개인의 취향과 상황에 따라 달라질 수 있습니다.',
#  '침실을 아늑하게 꾸미기 위해서는 색상 선택이 중요합니다. 파스텔 톤의 색상을 사용하면 부드럽고 따뜻한 느낌을 줄 수 있습니다. 또한, 조명도 중요한 요소입니다. 밝은 조명이 아닌 은은한 조명을 사용하여 더욱 아늑한 분위기를 만들 수 있습니다. 이 외에도, 침구류와 커튼 등의 소품을 활용하여 더욱 아늑한 분위기를 연출할 수 있습니다.\n\n아이가 있는 집을 꾸밀 때는 안전을 최우선으로 고려해야 합니다. 아이들은 호기심이 많아 물건을 만지거나 먹으려 하기 때문에, 가구나 장식품 등이 아이에게 위험하지 않은지 확인해야 합니다. 또한, 아이들이 넘어져 다칠 수 있는 모서리나 날카로운 부분도 없는지 확인해야 합니다. 이러한 안전 요소들을 고려하면서도 아이들이 놀기에 적합한 분위기를 만들어 주는 것이 중요합니다. 따라서, 아이들이 좋아하는 색상이나 캐릭터 등을 활용하여 아이들이 즐길 수 있는 분위기를 만들어 주는 것이 좋습니다.',
#  '인테리어에서 컬러매치는 매우 중요합니다. 전체적인 분위기와 스타일을 결정하는데 큰 역할을 합니다. 따라서, 먼저 전체적인 분위기를 고려하여 베이스 컬러를 선택하는 것이 좋습니다. 그리고 포인트 컬러로 강렬한 색상을 활용하여 생동감과 활력을 불어넣어줄 수 있습니다. 또한, 조명에 따라 색상이 달라질 수 있으므로 조명에도 신경써야 합니다. \n\n협소한 공간을 확장시키는 방법은 바닥재와 벽면 컬러의 선택이 중요합니다. 밝고 가벼운 색상의 바닥재와 벽면 컬러를 선택하면 공간이 더욱 넓어보입니다. 또한, 창문이나 문 주변에 화이트 컬러를 사용하면 공간이 확장되는 효과가 있습니다. \n\n복도의 경우, 양쪽 벽면에 같은 컬러를 적용하거나, 한쪽 벽면에는 포인트 컬러를 사용하여 길게 보이도록 할 수 있습니다. 또한, 바닥재의 색상과 대조되는 색상의 조명을 활용하면 길이가 더욱 길어보이는 효과를 얻을 수 있습니다.',
#  '그라스울 보온판은 흡음성이 뛰어난 제품으로, 이는 섬유질이 많은 구조와 관련이 있습니다. 일반적으로 흡음성은 음파가 물체에 부딪혀서 다시 방출되는 비율로 측정됩니다. 그라스울 보온판과 같은 섬유질 재료는 공명 주파수에서 특히 효과적인 흡음을 발휘합니다. 공명 주파수는 특정 재료의 공명 주파수에 해당하는 주파수로, 이 때 섬유질 사이를 통과하는 음파가 공명하여 효율적으로 흡수됩니다. 따라서 그라스울 보온판은 건축물이나 차량 내부와 같이 소음이 문제가 되는 환경에서 이상적인 흡음재로 사용됩니다.',
#  '미네랄울 보온판은 모래보다 못한 물질로 만들어지지만, 고속 회전원심공법으로 제조됩니다. 이 공법은 미네랄울 섬유를 원통형으로 말아 넣고 고속으로 회전시켜 섬유를 서로 엉키게 하는 방식입니다. 이렇게 엉킨 섬유는 열에 대한 저항력이 높아져 보온 효과가 좋아집니다. 또한, 미네랄울 보온판은 가벼우면서도 단열성이 뛰어나기 때문에 다양한 산업 분야에서 사용되고 있습니다.',
#  '도배 후 필름 시공은 주로 도배재질이 PVC로 된 장판형 바닥재일 때 추천합니다. 이 경우, 시공이 용이하고 비용이 저렴하며, 마루나 장판 위에 바로 시공할 수 있습니다. \n\n또한, 낡은 목재 가구에 대해서는 페인트나 스프레이를 사용하여 흠집을 가릴 수 있습니다. 이때, 목재용 아크릴 물감이나 우드 스테인 등의 전용 제품을 사용하면 더욱 자연스러운 효과를 얻을 수 있습니다. \n\n필름 시공의 경우, 일반적으로는 바닥재 시공에 많이 사용됩니다. 하지만, 목재 가구와 같은 부분에도 적용할 수 있으며, 이 경우에도 전용 제품을 사용하면 더욱 깔끔한 효과를 얻을 수 있습니다.',
#  '입구나 복도에 사용하는 페인트는 일반적으로 방수 기능이 있는 우레탄 페인트를 많이 사용합니다. 하지만, 공간의 용도와 분위기에 따라 다른 종류의 페인트를 선택할 수도 있습니다. 예를 들어, 모던하거나 세련된 분위기를 원한다면 메탈릭 페인트나 글로스 페인트를 고려해 볼 수 있습니다.\n\n인테리어 요소로는 바닥재, 조명, 가구 등이 중요합니다. 바닥재는 청소가 용이하고 마모에 강한 재질을 선택하는 것이 좋습니다. 조명은 밝은 백열등보다는 은은한 LED 조명이 더 적합하며, 가구는 적절한 크기와 디자인으로 선택하여 공간을 더욱 넓게 보이게 할 수 있습니다. 또한, 벽면에는 그림이나 장식품 등을 활용하여 개성 있는 분위기를 연출할 수 있습니다.',
#  '도배지는 먼지나 연기에 쉽게 오염될 수 있습니다. 특히, 석면 등의 유해한 먼지가 포함된 경우에는 더욱 위험합니다. 또한, 습도가 높은 환경에서는 곰팡이가 발생할 가능성이 높아집니다. 곰팡이는 습기가 많은 곳에서 번식하기 때문에, 습기가 많이 축적되는 벽면이나 창문 주변 등에서 발생할 수 있습니다. 따라서, 도배지를 사용하기 전에 먼지와 연기를 제거하고, 습기 관리를 철저히 해야 합니다.',
#  '방청페인트는 부식을 방지하기 위해 사용되는 페인트입니다. 시공 단계는 다음과 같습니다. 1. 철물 세척: 부식된 부분은 샌드페이퍼로 갈아내고, 녹 제거: 녹을 제거하기 위해 산화알칼리제 또는 아세트산 용액으로 처리합니다. 3. 프라이머 도포: 부식부위나 이음쇠에 프라이머를 도포하여 접착력을 높입니다. 4. 마스틱 테이핑: 이음쇠의 밀봉을 위해 마스틱 테이프를 감습니다. 5. 페인트 도포: 방청페인트를 도포합니다. 6. 마스틱 테이핑 해제: 페인트 건조 후 마스틱 테이핑을 제거합니다. 7. 검사 및 검수: 시공 완료 후 검사 및 검수를 합니다.\n\n배관공사 시 통기구를 설치해야 하는 이유는 공사 중 발생할 수 있는 먼지, 분진, 미세먼지 등을 제거하고, 내부 공기를 유지하기 위해서입니다. 이를 통해 작업자의 건강과 안전을 지키며, 공사를 원활하게 진행할 수 있습니다.',
#  '유성발수제는 물을 막아주는 기능을 합니다. 하지만, 비가 내리는 날에는 효과가 미미할 수 있습니다. 또한, 발수제가 침투되지 않은 부분은 물이 스며들 가능성이 있습니다. 규산질계 침투성 도포 방수공사는 규산소다를 물에 녹여서 바르는 방식으로 이루어집니다. 이 공법은 콘크리트 면의 작은 틈새나 찌꺼기를 메워주어 방수층의 연속성을 확보하고, 콘크리트 면의 숨구멍을 막아 물의 침투를 방지합니다. 또한, 규산소다 자체가 방수기능을 가지고 있어 두 가지 효과를 동시에 얻을 수 있습니다.',
#  '높은 습도로 인해 곰팡이가 생길 수 있습니다. 특히, 외부와 내부의 온도 차이가 크면 곰팡이의 번식이 더욱 촉진됩니다. 따라서, 실내 습도 조절과 온도 유지가 중요합니다. 이를 위해 환기를 자주하고, 에어컨이나 히터를 적절하게 사용해야 합니다. 또한, 곰팡이가 생긴 부분은 곰팡이제거제로 청소하고, 곰팡이 방지제로 예방할 수 있습니다.',
#  '인테리어 소품을 선택할 때는 공간의 분위기와 어울리는지, 전체적인 스타일과 조화를 이루는지, 실용성이 있는지 등을 고려해야 합니다. 또한, 색상이나 디자인이 지나치게 화려하지 않은지, 크기가 공간에 적절한지, 유지보수가 용이한지 등도 고려해야 합니다. 주방을 활기차게 꾸미기 위해서는 식물, 패브릭, 조명, 장식 아이템 등을 활용할 수 있습니다. 예를 들어, 싱그러운 식물로 생기를 더하거나, 쿠션 커버나 테이블 러너 등의 패브릭으로 따뜻하고 편안한 느낌을 연출할 수 있습니다. 또한, 밝은 조명으로 분위기를 전환하거나, 그림이나 포스터, 소품 등으로 개성을 살릴 수 있습니다.',
#  '초배지만 남은 벽에 페인트를 칠할 경우, 페인트가 잘 안 발리고 얼룩이 생길 수 있습니다. 이는 초배지 표면이 거칠기 때문에 페인트의 접착력이 떨어지기 때문입니다. 따라서, 이 경우에는 벽면을 매끈하게 만들기 위해 바탕 처리를 해주어야 합니다. 속건형 유성 발수제는 건조가 빠른 제품으로, 건조가 빠른 유성 제품입니다. 이 제품을 사용하면 건조 시간이 단축되어 작업 효율성이 높아집니다. 그러나, 모든 벽면에 적용 가능한 것은 아니며, 바탕 처리 후 사용해야 효과가 좋습니다.',
#  '벽지에는 여러 종류가 있으며, 각각의 벽지는 시공 후 일정 기간 내에 문제가 발생하면 보수를 해주어야 합니다. 일반적으로는 벽지의 수명이 5년 이상이지만, 시공 후 1년 이내에 문제가 생긴 경우, 벽지 아세톤 용제 함침 방법을 사용하여 보수할 수 있습니다. 이 방법은 벽지 표면의 오염을 제거하고, 벽지 내부의 오염을 방출시키는 방식으로 작동합니다. 그러나, 보수 후에도 문제가 지속될 경우, 개선 벽지로 재시공하는 것이 좋습니다. 이는 벽지 내부의 오염이 완전히 제거되지 않았을 가능성이 있기 때문입니다. 따라서, 벽지에 반점 등의 문제가 생겼을 때는 전문가와 상담하여 적절한 대처 방법을 선택하는 것이 좋습니다.',
#  '석구조는 돌로 만든 구조물을 뜻하며, 석재를 이용하여 기둥과 보, 주두 등의 부재로 구성됩니다. 이는 지진에 강한 내진성을 가지고 있습니다. 반면, 기둥-보 구조 방식은 목조 건축에서 사용되는 구조 방식으로, 기둥 아래에는 보를 놓고, 그 위에 도리를 얹어 구조를 완성하는 방식을 말합니다. 이 방식은 석구조와 달리 내진성이 약한 단점이 있습니다.',
#  '원목마루는 시중에 다양한 제품이 나와있지만, 일반적으로는 마루바닥재로 많이 사용됩니다. 하지만 원목마루의 경우, 장기간 사용 시 습도나 온도 변화에 따라 휘는 현상이 발생할 수 있습니다. 또한, 유지보수가 어렵고 가격이 비싸며, 오염에 취약하다는 단점이 있습니다. 도배지가 남을 경우에는 창가 주변이나 벽면의 틈새를 메우는데 사용할 수 있습니다.',
#  '마감재의 하자를 판단하기 위해서는 시공된 마감재를 직접 확인해야 합니다. 내부 벽면의 경우, 바탕 처리재와 마감재가 제대로 시공되어 있는지, 균열이나 곰팡이가 생기지 않았는지 등을 확인해야 합니다. 바닥재의 경우, 마감재가 평평하고 틈새가 없는지, 마감재와 마감재 사이의 이음새가 자연스러운지 등을 확인해야 합니다. 창문과 문틀 주변의 경우, 틈새가 생기지 않았는지, 누수가 생기지 않았는지 등을 확인해야 합니다. 새집증후군을 예방하는 데 가장 효과적인 방법은 건축자재의 선택입니다. 환경 친화적인 자재를 선택하고, VOC 배출량이 적은 제품을 선택해야 합니다. 또한 환기 시스템을 잘 갖춘 집을 선택하거나, 환기 시스템을 추가로 설치하는 것도 좋은 방법입니다.',
#  '강마루 바닥재는 강화마루로, 합판 위에 강화층, 디자인층, 보호층으로 구성되어 있습니다. 이 제품은 시공이 간편하고, 다양한 디자인으로 인테리어 효과가 뛰어납니다. 또한, 수분에 강하며 변형이 적고, 스크래치나 열에 의한 변형도 거의 없습니다. 가격대도 다른 마루 제품에 비해 저렴하며, 유지보수가 용이합니다. 이러한 이유로 강마루 바닥재는 많은 사람들이 선택하는 바닥재입니다.',
#  '새집증후군은 건축자재에서 방출되는 포름알데히드 등 VOC(Volatile Organic Compounds)에 의해 발생합니다. 이 물질들은 공기 중에 떠다니며 호흡을 통해 우리 몸으로 들어올 수 있습니다. 따라서 창문을 열어 환기하면 공기 중의 VOC 농도를 낮출 수 있고, 이로 인해 새집증후군을 예방할 수 있습니다. 또한, 환기를 통해 실내 습도와 온도를 적절하게 유지하여 쾌적한 환경을 만들 수 있습니다.',
#  "도배풀을 제거하는 가장 효과적인 도구는 '도배풀리무버'입니다. 이 제품은 도배풀 뿐만 아니라 접착제, 테이프 등 다양한 종류의 접착물을 제거할 수 있습니다. 사용 방법은 간단합니다. 도구에 약간의 물을 섞어 도배풀 위에 뿌리고, 10초 정도 기다린 후 떼어내면 됩니다. \n\n옥상 방수용 탄성 에멀전 페인트는 일반 방수용 페인트보다 더욱 탄성이 뛰어나며, 빗물이 스며들지 않도록 막아주는 역할을 합니다. 또한, 일반 방수용 페인트보다 더 얇은 두께로도 충분한 방수 기능을 제공하므로, 비용적인 측면에서도 효율적입니다. 이러한 이유로, 옥상 방수용으로 많이 사용됩니다.",
#  '통나무구조 방식의 건물에서 침하 현상을 최소화하기 위해서는 다음과 같은 디테일을 고려해야 합니다.\n\n- 기초의 폭과 깊이를 충분히 확보하는 것이 중요합니다. 특히 지반이 약한 경우 기초의 크기를 키우는 것이 좋습니다.\n- 기초와 기둥 사이의 간격을 적절하게 유지해야 합니다. 보통 기초의 폭보다 2배 이상 떨어져 있어야 합니다.\n- 기둥의 위치를 정확하게 잡아야 합니다. 기둥의 위치가 틀리면 구조체 전체의 안정성이 위험해집니다.\n- 통나무의 수종과 두께, 길이 등을 고려하여 구조계산 후 적절한 부재를 선택해야 합니다.\n- 통나무의 결점이 있는 부분은 구조체의 중요한 부위에는 사용하지 않도록 합니다.\n- 통나무의 수분을 측정하여 건조상태를 확인하고, 적절한 방부처리를 해야 합니다.\n- 구조체 내부의 철물(철물앵커 등)을 적절하게 사용해야 합니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기',
#  'MSDS는 물질안전보건자료로, 해당 물질에 대한 유해성과 위험성을 나타내는 자료입니다. 이 자료를 통해 해당 물질을 취급하는 작업자들이 안전하게 작업을 할 수 있도록 정보를 제공합니다. MSDS에는 물질의 명칭, 화학식, CAS 번호, 물질의 특성, 사용 방법, 취급 시 주의사항, 응급조치 방법 등이 포함되어 있습니다. 이러한 정보는 작업자들에게 제공되어 안전한 작업 환경을 조성하는데 매우 중요합니다. 따라서 MSDS는 산업 현장에서 꼭 필요한 자료입니다.',
#  '에나멜 계열 페인트는 유광과 무광으로 나뉘며, 각각의 특징이 있습니다. 유광은 광택이 있어 깨끗하고 세련된 느낌을 주지만, 먼지가 보일 수 있다는 단점이 있습니다. 반면 무광은 부드럽고 자연스러운 느낌을 주지만, 얼룩이나 먼지가 잘 보일 수 있습니다. 따라서 공간의 용도와 분위기에 따라 선택하는 것이 좋습니다. 예를 들어, 거실이나 방과 같은 생활 공간에는 무광이 적합하며, 작업 공간이나 사무실과 같은 전문적인 공간에는 유광이 적합합니다. 또한, 에나멜 계열 페인트는 다양한 색상이 있으며, 밝은 색상은 공간을 넓게 보이게 하고, 어두운 색상은 공간을 작아 보이게 할 수 있습니다. 따라서 공간의 크기와 모양, 채광 등을 고려하여 적절한 색상을 선택하는 것이 중요합니다.',
#  '라돈은 방사성 원소이기 때문에, 측정할 때는 공기 중에서 측정하는 것보다 물질에 흡착시켜 측정하는 것이 더 정확합니다. 따라서, 가장 적합한 지점은 바닥이나 창고의 맨 밑바닥입니다. 또한, MSDS(Material Safety Data Sheet)에는 물질의 유해성과 대처 방법 등이 상세히 기재되어 있습니다.',
#  '새집증후군은 건축자재에서 배출되는 유해물질에 의해 생기는 증상을 말합니다. 이를 해결하기 위해서는 환기, 공기정화장치, 식물 등을 활용하는 방법이 있습니다. 또한, 실내에 머무르는 시간을 줄이는 것도 한 방법입니다. 소화기는 분말소화기, 이산화탄소소화기, 프레온가스소화기 등이 있으며, 각각의 특징과 사용처가 다릅니다. 분말소화기는 일반적으로 가장 많이 사용되며, 다양한 화재 상황에서 효과적으로 대처할 수 있습니다. 이산화탄소소화기는 전기적 요소로 인한 화재에만 사용되며, 프레온가스소화기는 독성이 강해 사용에 제한이 따릅니다.',
#  '질석벽지는 습기 조절 기능이 뛰어나기 때문에 아트월이나 현관 입구와 같은 습기가 많은 장소에서 많이 사용됩니다. 또한, 질석벽지는 일반 벽지보다 더 두껍기 때문에 방음 효과도 있습니다. 이러한 특징으로 인해, 질석벽지는 현관 입구나 욕실 등 습기와 관련된 문제를 해결할 수 있는 대안으로 선택되는 경우가 많습니다.',
#  '석고보드 자체가 도배지 꼬임의 원인은 아닙니다. 다만, 석고보드와 벽체 사이의 간격을 메꾸기 위해 스티로폼 판자를 끼워넣는 경우가 있는데, 이 때 스티로폼 판자가 너무 두껍거나 석고보드에 제대로 고정되지 않은 경우 도배지 꼬임이 발생할 수 있습니다. 건조시간이 충분하지 않은 경우에도 도배지 꼬임이 발생할 수 있습니다. 도배지는 물리적인 힘에 의해 접히거나 휘어질 수 있기 때문입니다. 따라서, 석고보드 자체보다는 석고보드와 벽체 사이의 간격 메꾸기에 사용되는 재료와 건조시간 등이 도배지 꼬임의 원인이 될 수 있습니다.',
#  '폴리에스테르 흡음 단열재의 배수기능은 물이 고이는 지하실이나 화장실, 샤워부스 등 습기가 많은 공간에서 사용하기 적합합니다. 이 제품은 방음과 단열 기능을 동시에 수행할 수 있어, 소음을 줄이면서도 실내 온도를 유지할 수 있습니다. 또한, 이 제품은 설치 및 청소가 간편하며, 다양한 크기와 디자인으로 제작 가능합니다.',
#  '도배를 한 후에는 일정 기간 동안 습기를 빼주는 것이 중요합니다. 만약 권장 건조시간을 지키지 않는다면, 벽지 표면에 줄어들지 않은 습기가 남아있어 시간이 지나면서 벽지가 뒤틀리거나 갈라질 수 있습니다. 따라서 적어도 3~4일 정도는 건조시간을 지켜주시는 것이 좋습니다.',
#  '내단열 방식은 외부 단열과 내부 단열 두 가지 방법이 있습니다. 그러나 이 방식에서는 단열재가 벽체 내부에 위치하기 때문에 단열재와 벽체 사이의 열교 문제가 발생합니다. 이는 단열재와 벽체의 열전도율이 다르기 때문입니다. 또한, 습기가 축적되어 곰팡이가 생길 수 있습니다. 이러한 문제를 해결하기 위해서는 벽체 내부에 단열재를 고정하고, 단열재와 벽체 사이에 공기층을 만들어 열교 문제를 최소화해야 합니다. 또한, 환기 시스템을 통해 습기를 배출하여 곰팡이 발생을 예방할 수 있습니다.',
#  '도배지의 찢어짐은 주로 시공자의 부주의로 인한 경우가 많습니다. 그러나 도배지 자체의 불량이나 벽면의 불량 등으로 인해 발생할 수도 있습니다. 이 경우 책임소재는 시공사, 자재 공급사, 시공자 등이 될 수 있습니다. \n\n해결 방법으로는 찢어진 부분을 최대한 자연스럽게 보수하는 것이 좋습니다. 이때, 도배풀과 물을 섞어 붙인 후 마른 수건으로 닦아내면 됩니다. 만약 찢어진 부분이 크다면, 해당 부분만 다시 도배하는 것이 가장 좋은 방법입니다. \n\n또한, 도배 시공 시 충분한 시간을 갖고 벽면의 불량 등을 미리 파악하여 이러한 문제가 발생하지 않도록 하는 것이 중요합니다.',
#  '면진장치는 건물 기초 부분에 설치되어 지진의 흔들림을 흡수하는 장치입니다. 이 장치는 지진 발생 시 건물이 받는 지진력을 크게 줄여주며, 건물을 보호하고 안전성을 높여줍니다. 면진장치는 일반적으로 진동판과 유체(공기 또는 물)로 구성되어 있으며, 지진이 발생하면 진동판이 유체를 밀어내고 다시 원래 위치로 돌아오는 방식으로 작동합니다. 이러한 방식으로 면진장치는 건물을 지진으로부터 보호하며, 지진 발생 시에도 건물의 안전성을 유지할 수 있습니다.',
#  '페인트 상도재는 바닥재 위에 도장하여 마감하는 제품으로, 바닥재의 표면을 보호하고 미끄러짐 방지 효과를 줍니다. 사용 방법은 바닥재 표면을 깨끗이 청소하고, 건조한 후 상도재를 도장하면 됩니다. 강화마루는 합판 위에 강화층, 디자인층, 보호층으로 구성된 마루로, 디자인 선택의 폭이 넓고 시공이 간편하며 보행감이 우수합니다. 또한, 수종의 한계가 없어서 다양한 디자인을 구현할 수 있고, 오염이나 스크래치 등에 강한 내구성을 가지고 있습니다.',
#  '경질우레탄폼 보온판은 단열재 중에서 가장 효율적인 선택입니다. 우레탄폼은 높은 단열성능을 가지고 있으며, 다른 단열재에 비해 두께를 줄일 수 있어 설치 비용을 절감할 수 있습니다. 또한, 우레탄폼은 내구성이 뛰어나며, 곰팡이 발생을 막아주고, 습기에 강하며, 화재 시 유독가스를 발생시키지 않아 안전합니다. 이러한 장점들로 인해 경질우레탄폼 보온판은 경제적인 선택으로 평가받고 있습니다.',
#  '상도 작업은 일반적으로 무대 디자인과 조명, 음향 등을 고려하여 계획됩니다. 무대 디자인은 무대의 배경이나 소품 등을 고려하여 디자인되며, 조명은 무대의 분위기와 효과를 고려하여 선택됩니다. 음향은 무대에서 전달되는 소리의 크기와 방향 등을 고려하여 설정됩니다. 이러한 요소들이 종합적으로 고려되어 상도 작업이 진행됩니다.\n\n공간을 넓게 보이도록 인테리어를 꾸미는 방법은 다양합니다. 가장 기본적인 방법은 바닥재를 밝은 색상으로 선택하는 것입니다. 밝은 색상의 바닥재는 공간을 넓어 보이게 하는 효과가 있습니다. 또한, 천장 높이를 강조하는 디자인을 선택하거나, 벽면에 거울을 부착하는 것도 좋은 방법입니다. 가구 선택에도 주의해야 합니다. 큰 가구보다는 다리가 긴 가구를 선택하면 공간이 더욱 넓어 보입니다. 마지막으로, 창문을 최대한 활용하는 것도 중요합니다. 커튼을 걷어내거나, 창문을 가리는 물건을 치워서 최대한 많은 빛이 들어오도록 해야 합니다.',
#  '도배지가 울음 현상은 벽면의 물성이나 바탕 처리 상태에 따라 발생할 수 있습니다. 벽면이 너무 건조하거나, 바탕에 물기가 있는 경우, 바탕에 기름 성분이 있는 경우 등이 원인이 될 수 있습니다. 대처 방법으로는 바탕을 철저히 청소하고, 바탕에 물기가 있는지 확인한 후, 바탕에 물기가 없는 경우 바탕에 친환경 본드를 바르고 도배지를 붙이는 것이 좋습니다. 바탕에 물기가 있는 경우, 바탕에 친환경 본드를 바른 후, 물기를 제거하고 도배지를 붙이는 것이 좋습니다. 바탕에 기름 성분이 있는 경우, 바탕을 완전히 청소한 후, 친환경 본드를 바르고 도배지를 붙이는 것이 좋습니다.',
#  '사무실 실내공기 측정을 위해서는 사무실 내부에서 공기가 가장 잘 순환되는 중앙 부분에 측정기를 놓는 것이 좋습니다. 또한, 측정 전에는 창문을 모두 닫고 환풍기를 가동하여 실내 공기가 안정화될 수 있도록 합니다. 아파트 도배 평수를 계산할 때는 도배할 면적에 2를 곱하면 됩니다. 예를 들어, 방의 크기가 가로 3m, 세로 4m라면 면적은 12m2이고, 여기에 2를 곱하면 24m2가 됩니다. 이렇게 도출된 면적에 맞는 도배지를 구매하여 도배 작업을 진행하면 됩니다.',
#  '도배지에는 습기, 온도, 먼지 등이 원인이 되어 얼룩이 생길 수 있습니다. 이럴 경우, 물에 적신 후 닦아주면 대부분 제거됩니다. 하지만, 구조적 결함으로 인한 석고수정이 발생할 가능성은 낮습니다. 이는 건축물의 구조체와 관련이 있기 때문입니다. 따라서, 석고수정이 필요한 경우는 드물며, 일반적으로는 도배지 얼룩 제거로 충분합니다.',
#  '대리석은 열을 잘 전달하지 않는 물질입니다. 따라서 대리석 타일을 바닥에 깔면, 난방 비용이 절감됩니다. 이는 대리석이 열전도율이 낮기 때문입니다. 일반적으로 열전도율이 높은 금속류나 세라믹류의 제품들은 전력 소모량이 높지만, 대리석은 열전도율이 낮아 전력 소모량을 줄일 수 있습니다. 따라서 대리석 타일을 바닥에 깔면, 난방 비용을 절감할 수 있습니다.',
#  '외단열은 건물 외부에 단열재를 시공하는 것으로, 내부 단열에 비해 외부 환경 조건에 민감합니다. 이는 외단열의 경우, 외부에서부터 열손실을 막아주기 때문입니다. 따라서 외부 환경 조건은 외단열 시공 시 매우 중요합니다. 예를 들어, 외부 온도가 낮아지면 단열재 내부에 습기가 생길 수 있고, 이는 결로와 곰팡이의 발생 원인이 될 수 있습니다. 또한, 바람이 많은 지역에서는 단열재가 쉽게 손상될 수 있으므로, 이러한 조건들을 고려하여 적절한 단열재와 시공 방법을 선택해야 합니다.',
#  '스탠드 조명은 책상 위에서 글을 읽거나 작업을 할 때 사용하기 적합합니다. 따라서, 밝고 색상이 자연스러운 조명이 좋습니다. LED 조명이 적합하며, 색온도가 4000K 정도인 주광색 타입을 선택하는 것이 좋습니다. 또한, 조명의 높이와 각도를 조절할 수 있는 제품이 편리합니다.',
#  '1. 실크벽지의 얼룩을 지워내는 가장 효과적인 방법은 물과 암모니아를 1:1 비율로 섞어 면에 묻혀서 닦는 것입니다. 이 때, 암모니아를 너무 많이 사용하면 벽지가 손상될 수 있으므로 주의해야 합니다.\n2. 부적절한 설치로 인해 제품의 품질에 영향을 미칠 수 있습니다. 예를 들어, 벽면이 불균일하거나 먼지나 이물질이 많은 경우, 벽지에 기포가 생기거나 들뜨는 현상이 발생할 수 있습니다. 따라서, 벽면을 평평하게 만들고 먼지를 제거하는 등의 기본적인 작업을 철저히 해야 합니다.\n3. 또한, 벽지 시공 시에는 습기에 대한 대책도 필요합니다. 특히 지하층이나 화장실, 베란다 등 습기가 많은 장소에서는 습기에 강한 벽지를 선택하거나 환기 시스템을 고려해야 합니다.\n4. 마지막으로, 벽지 선택 시에는 색상과 패턴을 고려해야 합니다. 작은 공간에서는 밝은 색상과 단순한 패턴을 선택하는 것이 좋고, 큰 공간에서는 어두운 색상과 복잡한 패턴을 선택하는 것이 좋습니다.',
#  '차음재의 차음 성능은 차음계수(NRC)로 평가됩니다. 차음계수는 0에서 1 사이의 값으로, 숫자가 높을수록 차음 성능이 좋습니다. 일반적으로 NRC가 0.5 이상이면 꽤 좋은 차음재로 간주됩니다. 그러나 차음재의 성능은 사용되는 환경에 따라 달라질 수 있습니다. 예를 들어, 차음재가 벽이나 바닥에 사용될 경우, 주변 소음과 비교하여 얼마나 잘 차단하는지 고려해야 합니다. 또한 차음재는 충격음 차단을 위해 설계된 것이 아니므로, 고주파 소리나 충격음을 차단하는 데는 한계가 있을 수 있습니다.',
#  '공동주택의 실내 공기질을 측정하기 위해서는 거실, 침실, 주방, 욕실 등 다양한 공간에서 측정해야 합니다. 하지만, 가장 중요한 것은 거실에서의 측정입니다. 이는 거실이 공동주택의 중심이 되는 공간이기 때문입니다. 또한, 실내 공기질을 측정할 때는 창문을 닫고 문을 모두 닫은 상태에서 측정해야 합니다. \n\n마감재의 하자를 판단하기 위해서는 육안으로 확인하거나 전문가의 도움을 받는 것이 좋습니다. 육안으로 확인하는 경우에는 마감재의 상태를 직접 살펴보는 것이며, 전문가의 도움을 받는 경우에는 건축 전문가나 인테리어 전문가 등이 마감재의 상태를 진단해 줄 수 있습니다. \n\n또한, 공동주택의 경우 입주자대표회의를 구성하여 관리규약에 따라 하자보수를 요구할 수 있습니다. 이때, 하자보수 대상이 되는 부분은 건물 외벽, 옥상, 지하주차장 등의 주요 구조부와 설비 부분입니다. 따라서, 입주자대표회의에서는 이러한 부분들을 정기적으로 점검하고, 필요한 보수를 요구할 수 있습니다.',
#  '1. 물과 식초를 1:2 비율로 섞어 스펀지에 묻혀 닦아보세요. 얼룩이 가벼우면 대부분 지워질 것입니다.\n2. 암모니아수를 반반 섞은 물로 닦으면 대부분의 얼룩이 제거됩니다.\n3. 암모니아수를 반반 섞은 물에 면봉을 담갔다가 닦으면 얼룩이 제거됩니다.\n4. 암모니아수를 반반 섞은 물에 칫솔을 담갔다가 닦으면 얼룩이 제거됩니다.\n5. 암모니아수를 반반 섞은 물에 면봉이나 칫솔을 담갔다가 닦으면 얼룩이 제거됩니다.\n6. 암모니아수를 반반 섞은 물에 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n7. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n8. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n9. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n10. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n11. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n12. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n13. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n14. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n15. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n16. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n17. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n18. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n19. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n20. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n21. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n22. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n23. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n24. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n25. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n26. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n27. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n28. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n29. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n30. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n31. 암모니아수를 반',
#  '페인트를 바르는 방법은 여러 가지가 있습니다. 가장 일반적인 방법은 롤러와 브러쉬를 사용하는 것입니다. 하지만 페인트의 종류와 도장면의 상태, 그리고 도장면의 크기에 따라 다른 방법을 선택할 수도 있습니다.\n\n- 롤러: 롤러는 넓은 면적을 빠르게 칠할 수 있는 장점이 있습니다. 하지만 굴곡이 심한 면이나 모서리 부분은 칠하기 어렵고, 롤러로 칠한 면은 브러시보다 울퉁불퉁해 보일 수 있습니다.\n- 브러시: 브러시는 좁은 면적이나 굴곡이 심한 부분을 칠하기에 적합합니다. 하지만 넓은 면적을 칠하는 것은 롤러보다 느리고, 브러시로 칠한 면은 롤러보다 매끈해 보입니다.\n- 스프레이: 스프레이는 넓은 면적을 빠르게 칠할 수 있는 장점이 있지만, 바람에 의해 스프레이된 페인트가 날아가거나, 스프레이의 간격이 일정하지 않은 경우가 많습니다. 또한, 스프레이로 칠한 면은 롤러나 브러시로 칠한 면보다 더 울퉁불퉁해 보입니다.\n\n따라서, 페인트의 양에 따라 적절한 방법을 선택해야 합니다. 만약 페인트의 양이 많다면 롤러나 스프레이를 사용하는 것이 좋고, 페인트의 양이 적다면 브러시를 사용하는 것이 좋습니다. 또한, 페인트의 종류와 도장면의 상태, 그리고 도장면의 크기를 고려하여 적절한 방법을 선택해야 합니다.',
#  '건설 산업은 건물, 도로, 교량, 운하, 댐, 항만, 상수도 및 폐기물 처리 시설과 같은 구조물을 설계, 건설 및 유지보수하는 것을 말합니다. 건설 산업은 다양한 하위 분야로 나뉘어 있으며, 그 중 하나가 토목 공학입니다. 토목 공학은 구조물의 설계, 건설 및 유지보수를 다루는 건설의 한 분야입니다. 토목 공학자는 도로, 교량, 댐, 해상 구조물 등의 구조물을 설계하고 건설하기 위해 수학, 물리학 및 재료 과학 지식을 활용합니다. 또한 토목 공학자는 프로젝트의 환경적, 경제적, 사회적 영향을 고려하여 최상의 솔루션을 제공할 수 있도록 합니다.### 지침:\n 토목 공학에 대한 자세한 정보와 예시를 제공해 주세요.',
#  '제진구조는 건물의 내진설계를 위해 사용되는 구조 방식으로, 지진 등의 충격을 견딜 수 있도록 설계된 구조입니다. 이는 건축물의 안전성을 높이기 위한 것으로, 최근에는 내진설계가 의무화되어 있습니다. 중목구조 방식은 벽식 구조와 기둥식 구조의 단점을 보완한 구조 방식으로, 목재를 사용해 건물을 짓는 방식입니다. 이 방식은 목재의 탄력성과 신축성을 활용해 지진의 충격을 흡수하고 분산시키는 장점이 있어 내진성능이 우수합니다. 또한, 목재는 친환경적이고 재활용이 가능하다는 장점도 있습니다.',
#  '작은 공간의 홈오피스에 원목사이딩을 사용할 경우, 단점으로는 습기에 취약하고 변형될 수 있으며, 오염에 민감하다는 것이 있습니다. 이를 극복하기 위해서는 방습제와 함께 사용하고, 오염이 생길 경우 바로 닦아주는 것이 좋습니다. 또한, 원목의 자연스러운 느낌을 살리기 위해 조명과 가구를 선택할 때에도 자연스러운 분위기를 유지하는 것이 중요합니다. 이 외에도, 원목사이딩을 깨끗하게 유지하기 위해 정기적인 청소와 관리가 필요합니다.',
#  '알루미늄징크는 지붕재로서 성능이 뛰어나며, 수명이 50년 이상으로 알려져 있습니다. 하지만 가격이 비싸고, 가공성이 떨어지는 단점이 있습니다. 아이소핑크는 폼 테이프의 일종으로, 단열재나 차음재로 사용됩니다. 이 제품은 접착력이 뛰어나고, 다양한 크기와 두께로 제작 가능합니다. 또한, 방음 및 단열 효과가 뛰어나며, 습기에 강한 특징을 가지고 있습니다. 이러한 장점 때문에 건축물 내부와 외부에서 널리 사용되고 있습니다.',
#  '겨울철에 도배 작업을 할 때, 실내 온도를 일정하게 유지하는 것은 매우 중요합니다. 이는 도배지의 적정한 습기와 건조를 위해서입니다. 도배지는 습기가 적당해야 하며, 너무 건조하거나 습기가 많으면 접착이 잘 되지 않습니다. 따라서 실내 온도를 일정하게 유지하여 도배지가 적절한 습기를 가지도록 해야 합니다. 또한, 도배 작업 중에는 실내 온도가 너무 높지 않도록 주의해야 합니다. 너무 높은 온도에서는 도배지가 빨리 마르기 때문에, 적절한 습기를 유지하기 어렵습니다. 따라서 도배 작업 중에는 실내 온도를 일정하게 유지하는 것이 중요합니다.',
#  '철골구조는 화재에 취약한 구조로, 화재 발생 시 대처하기 어렵습니다. 이를 보완하기 위해 다양한 방법이 있습니다. 첫째, 철골에 방화페인트를 칠하는 방법입니다. 이 방법은 화재 발생 시 일정 시간 동안 화재 진행을 지연시키는 효과가 있습니다. 둘째, 철골에 금속판넬을 덧대는 방법입니다. 이 방법은 철골의 노출을 막아 화재 발생 시 연소 속도를 늦출 수 있습니다. 셋째, 철골에 불연성 금속판넬을 덧대는 방법입니다. 이 방법은 철골의 노출을 막아 화재 발생 시 연소 속도를 늦출 수 있으며, 화재 진압 후에도 구조물이 유지될 수 있습니다. 마지막으로, 철골 구조물 내부에 스프링클러를 설치하는 방법도 있습니다.\n\n벽돌구조는 벽돌을 사용하여 만들어진 구조물을 말합니다. 벽돌구조는 철골구조와 달리 화재에 상대적으로 강한 구조입니다. 하지만, 화재 발생 시에도 대처하기 위해서는 적절한 대책이 필요합니다.',
#  '석구조는 돌로 만든 구조물을 뜻합니다. 기둥-보 구조 방식은 서양 고대 건축에서 사용된 방식으로, 기둥 위에 직접 보를 놓아 상부 하중을 벽체에 전달하는 구조 방식을 말합니다. 이 방식은 벽체가 하중을 견디기 때문에 안정성이 뛰어나며, 내부 공간을 효율적으로 활용할 수 있다는 장점이 있습니다. 대표적인 예로는 고대 그리스의 파르테논 신전이 있습니다.',
#  '포세린 타일은 내구성과 청소의 용이성 등 많은 장점을 가지고 있지만, 단점으로는 가격이 비싸다는 것이 있습니다. 또한, 포세린 타일은 물이 스며들지 않기 때문에 바닥 난방이 필요한 경우 사용하기 어렵습니다. 셀룰로오스 섬유는 목재를 분쇄하여 섬유로 만든 것으로, 단점으로는 습기에 취약하고, 곰팡이가 생길 수 있으며, 불에 잘 타는 등의 문제가 있습니다.',
#  '부드러운 욕실 인테리어를 위해서는, 밝은 색상과 부드러운 패턴이 어울리는 소재를 선택하는 것이 좋습니다. 예를 들어, 흰색이나 아이보리색의 타일, 대리석 또는 목재 바닥재 등이 있습니다. 또한, 꽃무늬나 스트라이프 등 부드러운 패턴이 있는 벽지나 타일 등을 선택할 수도 있습니다.\n\n반려동물을 위한 바닥재는 여러 종류가 있습니다. 가장 일반적인 것은 PVC 바닥재로, 방수 기능이 있어 물에 젖어도 괜찮습니다. 또한, 코르크 마루도 좋은 선택입니다. 코르크는 냄새도 나지 않고 미끄럼 방지도 되며, 충격 흡수도 잘 되어 반려동물에게 적합합니다. 마지막으로, 카펫트도 좋은 선택입니다. 하지만 카펫트는 청소하기가 어렵고, 반려동물이 배설물을 할 경우 냄새가 나기 쉬우니 주의해야 합니다.',
#  '팬던트 라이트는 천장 조명으로, 일반적으로 한 개 이상의 갓으로 구성되어 있습니다. 이 조명은 주로 거실, 식당, 침실 등에서 사용됩니다. 바닥재를 선택할 때는 미끄러짐 방지, 청소의 편리성, 마모 및 변색에 대한 내구성 등을 고려해야 합니다. 또한, 바닥재의 종류로는 대리석, 타일, 원목, 강화마루, PVC 등이 있으며, 각각의 장단점을 고려하여 선택해야 합니다.',
#  '속건형 유성 발수제는 물을 싫어하는 성질로 인해 물을 막아주는 역할을 합니다. 이때, 물이 묻은 면에 발수제를 뿌리면 물이 발수제의 빈 공간으로만 흐르면서 표면에 물방울이 맺히지 않아 물의 침투를 막아줍니다. 이러한 작용으로 인해 비가 내릴 때도 물이 건물 표면에 스며들지 못하게 하여 건물의 수명을 연장시키는 것입니다.',
#  '주방에서 요리를 할 때, 작업대 위에는 밝은 조명이 필요합니다. 이때 가장 적합한 조명은 백열등이나 할로겐 램프입니다. 백열등은 가격이 저렴하고 설치가 쉬우며, 할로겐 램프는 색온도가 높아 음식의 색깔을 정확하게 볼 수 있습니다. 그러나 할로겐 램프는 열이 많이 발생하므로 안전에 주의해야 합니다. 또한, 주방 전체를 밝히기 위한 일반 조명으로는 형광등이나 LED 조명이 사용됩니다. 이때, 조명의 색상은 자연광과 가장 유사한 색인 주광색이 적합합니다.',
#  '밀풀은 벽면에 그림이나 패널 등을 부착할 때 사용되는 접착제로, 강한 접착력과 내구성을 가지고 있습니다. 하지만 사용 시 주의해야 할 점으로는 밀풀이 건조하는데 시간이 걸리며, 완전히 마른 뒤 그림이나 패널을 부착하는 것이 좋습니다. 또한, 밀풀은 벽면에 묻어나온 부분이 시간이 지나면 떨어지거나 변색될 수 있으므로, 사용 전 벽면의 상태와 그림이나 패널의 무게 등을 고려하여 적절한 양의 밀풀을 사용하는 것이 중요합니다.',
#  '철근콘크리트 구조는 철근과 콘크리트로 만들어진 구조물로, 벽체와 기둥을 콘크리트로 만들고 철근으로 보강하는 방식입니다. 이 구조는 내화성능이 우수하고 구조체의 형이 자유롭게 설계할 수 있으며, 방수 및 내한 성능도 뛰어납니다. 그러나 시공성이 떨어지고, 중량과 크기에 제약이 있으며, 균열 발생 시 심각한 문제가 생길 수 있습니다.\n\n통나무구조 방식은 통나무를 이용해 만드는 건축 구조 방식으로, 주로 목조 건물을 만드는데 사용됩니다. 이 방식은 자연 친화적이며, 단열성과 내구성이 뛰어나고, 건강에도 좋은 장점이 있습니다. 그러나 시공 기간이 길고, 유지보수가 어렵다는 단점이 있습니다.\n\n따라서, 건축물의 용도와 목적에 따라 적합한 구조 방식을 선택하는 것이 중요합니다.',
#  '공명형 흡음재는 특정 주파수 대에서만 효과적으로 소리를 흡수할 수 있습니다. 이는 공명형 흡음재의 내부 구조와 관련이 있습니다. 공명형 흡음재 내부에는 공명 단면이 존재하며, 이 공명 단면은 일정한 크기를 가지고 있습니다. 따라서, 공명형 흡음재는 일정한 크기의 공명 단면에 해당하는 주파수 대에서만 소리를 효과적으로 흡수할 수 있습니다. 이러한 이유로, 공명형 흡음재는 특정 주파수 대에서만 사용 가능합니다.',
#  '결로는 습기(moisture)가 벽체에 스며들면서 발생합니다. 이를 방지하기 위해서는 벽체의 내부습기를 최소화하는 것이 중요합니다. 이를 위해서는 단열재로 팽창된 폴리우레탄폼(PUR)을 사용하는 것이 좋습니다. 이 제품은 단열성능이 우수하고, 접착력과 탄력성이 뛰어나며, 외부환경에 영향을 받지 않는 장점이 있습니다. 또한, 외단열 공법(External Insulation Finish System, EIFS)도 결로방지에 효과적입니다. 이 공법은 벽체의 외부에 단열재를 부착한 후, 외부에 마감재를 도포하는 방식으로, 내부습기를 최소화할 수 있습니다. 다만, 이 공법은 시공이 복잡하고 비용이 비싸다는 단점이 있습니다. 따라서, 일반적으로는 PUR폼을 사용하는 것이 적절합니다.',
#  '베란다에 야외 라운지를 만들기 위해서는 테이블, 의자, 파라솔 등의 기본적인 가구와 함께 쿠션, 담요, 화분 등의 소품을 활용하면 됩니다. 또한, 바닥에는 카펫이나 매트 등을 깔아 편안한 분위기를 만들 수 있습니다. 거실에 현대적인 느낌을 주고 싶다면, 모던한 디자인의 가구와 함께 조명, 커튼, 러그 등의 소품을 활용하면 됩니다. 이때, 전체적으로 통일된 컬러나 패턴을 사용하면 더욱 세련된 느낌을 줄 수 있습니다. 따라서, 베란다와 거실 모두에서 편안하고 현대적인 분위기를 연출하기 위해서는 가구와 소품을 적절하게 선택하는 것이 중요합니다.',
#  '페인트 작업 시에는 유해물질에 대한 노출을 최소화하기 위해 몇 가지 예방 조치를 취하는 것이 중요합니다. 다음은 몇 가지 권장 사항입니다:\n\n1. 통풍이 잘되는 곳에서만 페인트를 사용하세요.\n2. 페인트를 사용할 때는 방독 마스크와 고무 장갑을 착용하세요.\n3. 페인트를 먹거나 마시지 마세요.\n4. 페인트가 묻은 옷이나 장비는 작업 후 즉시 세탁하세요.\n5. 페인트 캔에 표시된 안전 데이터 시트를 읽으세요.\n6. 페인트를 어린이 및 애완동물의 손이 닿지 않는 곳에 보관하세요.\n7. 페인트를 사용한 후에는 항상 뚜껑을 닫아주세요.\n8. 페인트를 사용한 후에는 환기 시스템이나 배기 팬을 사용하세요.\n9. 페인트 작업 중 이상한 증상(두통, 현기증, 구토 등)이 나타나면 작업을 중단하고 적절한 조치를 취하세요.\n\n이러한 예방 조치를 따르면 페인트 작업 시 유해 물질에 대한 노출 위험을 줄일 수 있습니다.',
#  '판 진동형 흡음재는 공명 주파수에서 음압에 의해 판이 진동하면서 소리를 흡수하는 원리를 이용합니다. 이 흡음재에는 판을 일정하게 진동시키는 장치와 공명 주파수를 조정하는 장치가 있습니다. 이러한 구조로 인해, 특정 주파수 대역에서 소리의 파장을 흡수하여 방출되는 소리의 크기를 줄일 수 있습니다.',
#  '점토벽돌은 내화성능이 뛰어나며, 단열성과 차음성이 우수합니다. 또한, 시공성이 좋아 시멘트벽돌에 비해 적은 인건비로도 시공이 가능합니다. 점토벽돌은 다양한 색상과 디자인으로 제작이 가능하여 건축물의 미적 요소를 높일 수 있습니다. \n\n도료와 벽지 중에서는 벽지의 선택이 더 나은 선택입니다. 벽지는 다양한 패턴과 컬러로 선택할 수 있으며, 시공 후에도 쉽게 교체가 가능합니다. 반면, 도료는 시공 후 변경이 어렵고, 유지보수 비용이 많이 들어갈 수 있습니다. \n\n따라서, 건축물의 내외부를 꾸미는 데 있어 벽지를 선택하는 것이 더 적합합니다.',
#  '강화마루는 목재와 PVC를 적층하여 만들어진 마루바닥재입니다. 이 제품은 디자인이 다양하고 시공이 간편하며, 내구성이 뛰어나다는 장점이 있습니다. 반면에 징크판넬은 금속재료로 만들어진 지붕재입니다. 징크판넬의 단점으로는 설치가 어렵고, 소음흡수율이 낮으며, 수명이 짧다는 것이 있습니다. 또한, 징크판넬은 지붕재로 사용되는 경우가 많기 때문에, 지붕의 모양과 크기에 따라 설치가 어려울 수 있습니다.',
#  '타공 부위에서 결로가 생길 수 있습니다. 결로는 온도와 습도, 그리고 벽체의 열전도율에 따라 결정됩니다. 따라서 타공 부위가 결로 위험 지역인 경우, 결로 방지를 위해 다음과 같은 방법을 시도해 볼 수 있습니다.\n\n1. 타공 부위를 완전히 메우기 전에, 내부에 단열재를 추가로 넣어줍니다.\n2. 타공 부위를 완전히 메운 후에는, 외부에 단열재를 붙여줍니다.\n3. 창문이나 문틀 주변의 벽체는 일반적으로 결로 위험 지역이므로, 이 부분에도 단열재를 추가로 넣어줍니다.\n4. 실리콘 코킹 등으로 타공 부위를 메우면, 결로 방지에 도움이 됩니다.\n\n위의 방법들을 시도하면, 타공 부위에서 결로가 생기는 것을 방지할 수 있습니다.',
#  '물 누수로 인한 곰팡이와 곰팡이 냄새를 제거하려면, 락스 원액이나 곰팡이제거제를 사용하면 됩니다. 락스 원액은 강력한 살균 및 소독 효과가 있으며, 곰팡이제거제는 곰팡이를 제거하는 데 특화된 제품입니다. \n\n또한, 펫테리어는 애완동물과 인테리어를 합친 단어로, 애완동물을 기르면서도 깔끔하고 예쁜 인테리어를 유지할 수 있도록 하는 것입니다. 따라서 애완동물 관련 제품과 인테리어 아이템을 함께 판매하는 펫테리어 전문 매장도 있습니다.',
#  '도배지를 너무 작게 자르면, 도배작업 시 시간이 더 걸리며, 도배지 사용량이 많아져 비용이 증가합니다. 또한, 도배 시 이음새 부분이 많아져 접착제 사용량이 늘어나고, 도배 작업이 복잡해집니다. 높은 습도로 인해 도배지 패턴이 이어지지 않는 것은, 습기가 많은 환경에서는 도배지의 이음새 부분이 물리적으로 밀착되지 않아 붙인 도배지가 들뜨거나 떨어지는 현상이 발생할 수 있기 때문입니다. 따라서, 도배 작업을 할 때는 습기 관리를 철저히 해야 합니다.',
#  '알러지가 있는 사람들이 매끄럽고 평평한 벽지를 선택하는 이유는 두 가지가 있습니다. 첫째, 벽지 표면에 먼지나 진드기 등의 알러지 유발 물질이 적게 붙어 있기 때문입니다. 둘째, 벽면의 요철이 적어 공기 중에 떠다니는 먼지양이 적기 때문입니다. 이는 평평한 벽면이 더 깨끗해 보인다는 것뿐만 아니라 실제로 더 깨끗하기 때문입니다. 따라서, 알러지가 있는 사람들은 이러한 이유로 매끄럽고 평평한 벽지를 선택하게 됩니다.',
#  '아파트 도배 평수를 계산하는 방법은 다음과 같습니다. 먼저, 아파트의 면적을 구한 후 벽체의 면적을 제외한 나머지 바닥 면적에 1.2를 곱하면 됩니다. 예를 들어, 아파트 면적이 85m2이고 벽체의 면적이 20m2이면 바닥 면적(85 - 20 = 65)에 1.2를 곱하여 78m2가 됩니다. 이 때, 벽체 면적은 거실이나 방 등 모든 면적을 포함합니다.\n\n소화기 설치 시에는 몇 가지 주의사항이 있습니다. 먼저, 소화기는 화재 발생 위험이 높은 장소에 설치해야 합니다. 또한, 소화기의 위치는 화재 발생 시 쉽게 접근할 수 있는 곳에 설치해야 합니다. 그리고, 소화기는 정기적으로 점검하고 보수해야 하며, 사용하기 전에 사용 방법을 숙지해야 합니다. 마지막으로, 소화기를 사용할 때는 안전을 최우선으로 생각하며, 소화기에 표시된 적절한 방법으로 사용해야 합니다.',
#  '마감재의 하자를 판단하기 위해서는 시방서나 규정에 따라 판단해야 합니다. 일반적으로는 마감재의 표면 상태, 이음매, 치수, 품질 등을 확인합니다. 또한, 마감재의 종류에 따라 다른 검사 방법이 적용될 수 있습니다. 예를 들어, 타일은 면과 면의 이음매를 확인하고, 목재는 결점이나 균일성 등을 확인합니다. 라돈을 측정하는 데는 방사능 측정기를 사용하며, 가장 적합한 지점은 실내 공기질을 측정하는 것이 좋습니다. 측정기의 종류에 따라 측정 방법이 달라질 수 있으므로, 측정 전에 측정 방법에 대한 충분한 이해가 필요합니다.',
#  '이산화탄소 소화기는 가스 상태의 이산화탄소를 이용해 화재를 진압하는 소화기입니다. 이산화탄소는 공기 중에서 산소의 역할을 하므로, 이산화탄소를 분사하면 불이 꺼집니다. 이산화탄소 소화기는 유류나 전기 등의 화재 진압에 적합하며, 인체에는 무해합니다. 분말 소화기는 분말 상태의 약제를 분사하여 화재를 진압하는 소화기입니다. 주로 유류나 전기 등의 화재 진압에 사용되며, 인체에는 해로울 수 있습니다. 분말 소화기는 약제의 종류에 따라 다양한 용도로 사용될 수 있습니다.',
#  '면진장치는 지진이나 진동에 대한 충격을 완화시켜 주는 장치입니다. 면진장치는 건축물의 기둥이나 벽체에 부착되어, 지진이나 진동이 발생할 때 면진장치 내부의 유체(공기 또는 오일)가 움직여서 충격을 흡수합니다. 면진구조는 면진장치를 사용하여 지진이나 진동에 강한 구조를 말합니다. 면진구조는 주로 지진이 자주 일어나는 일본이나 미국에서 많이 사용되며, 건축물의 내구성과 안전성을 높이기 위해 적용됩니다.',
#  '외단열재는 건물 외부에 위치하여 건물의 단열 기능을 수행하는 자재입니다. 이로 인해 실내 온도를 일정하게 유지해주며, 난방 비용을 절감할 수 있습니다. 또한, 외단열재는 건물 외관 디자인의 자유도 증가와 구조용 자재의 보호 기능 등 다양한 장점을 가지고 있습니다. 이를 시공할 때는 적절한 두께와 재질을 선택하고, 방수층과 결로 방지층 등을 고려해야 합니다.',
#  '외단열은 건물 외부에 단열재를 설치하는 방법이고, 내단열은 건물 내부에 단열재를 설치하는 방법입니다. 외단열은 단열재가 건물 외면을 완전히 둘러싸기 때문에 단열재와 실내 공기의 온도차가 작아 단열 효과가 높습니다. 또한, 외단열은 단열재의 두께를 더 늘려도 추가 비용이 많이 들지 않아 경제적입니다. 반면, 내단열은 벽체 내부에 단열재를 설치하기 때문에 단열재와 실내 공기의 온도차가 크고, 단열재의 두께를 늘리면 추가 비용이 많이 들어갑니다. 따라서, 내단열은 외단열보다 단열 효과가 떨어질 수 있습니다.',
#  '바닥재의 종류는 매우 다양하지만, 현재 가장 인기 있는 바닥재는 강마루입니다. 강마루는 합판 위에 강화마루를 시공한 것으로, 시공이 간편하고 디자인 선택폭이 넓으며, 가격대비 성능이 좋아서 많은 사람들이 선택합니다. 가장 비싼 바닥재는 대개 원목마루로, 원목을 가공하여 만든 마루바닥재입니다. 하지만 최근에는 강마루가 그 자리를 대신하고 있습니다.',
#  '포세린 타일은 도자기 타일로, 일반 타일에 비해 물 흡수율이 낮고 변색이 잘 안되며, 스크래치에 강하고 내구성이 뛰어납니다. 하지만 가격이 비싸며, 깨지면 재사용이 불가능하다는 단점이 있습니다. 또한, 포세린 타일은 물 흡수율이 매우 낮기 때문에 시공할 때에는 물빠짐 공사를 철저히 해주어야 합니다.',
#  '중목구조는 구조재로 목재를 사용하는 건축 방식으로, 벽식 구조와 기둥식 구조 두 가지가 있습니다. 벽식 구조는 벽체가 하중에 저항하는 구조이며, 기둥식 구조는 기둥이 하중을 지탱하는 구조입니다. 목재의 종류로는 소나무, 느티나무, 오동나무 등이 사용되며, 목재의 방부 처리와 접합 부분의 철물 부착 등을 통해 구조적 안정성을 확보합니다. \n\n철근콘크리트 구조는 철근과 콘크리트로 구성된 구조 방식으로, 철근이 인장력(늘어나는 힘)을 견디고 콘크리트가 압축력을 견디는 구조입니다. 철근콘크리트 구조는 벽체와 슬라브 등에 철근배근을 하고 콘크리트를 타설하여 구조체를 만듭니다. 이 구조는 내화성능이 우수하고 소음을 흡수하며, 내부 마감재의 선택 폭이 넓은 장점이 있습니다.',
#  '도배지의 양은 도배할 면적에 따라 다르지만, 일반적으로 한 장으로는 부족합니다. 보통은 두 장 이상을 사용하며, 창문이나 문 등 특수한 부분은 추가로 더 필요합니다. 벽에 구멍을 막는 가장 효과적인 방법은 스프레이 본드를 사용하는 것입니다. 이 제품은 접착력이 뛰어나며, 얇게 바르면 깔끔하게 마감됩니다. 또한, 스프레이 본드는 냄새가 강하므로 실내에서 작업할 때는 환기하는 것이 좋습니다.',
#  '경질우레탄폼 보온판은 외단열재로서 단열성능이 뛰어나며, 공사기간 단축과 경제적인 효과를 가지고 있습니다. 또한, 이중벽체구조로 되어있어 차음성능도 우수합니다. 이러한 장점으로 인해 결로와 곰팡이 발생을 줄일 수 있습니다. 경질우레탄폼 보온판은 외부환경으로부터의 열전달을 최소화하여 내부의 온도를 유지시키며, 습기제어 기능을 가지고 있어 내부의 습기를 조절하여 결로 발생을 예방합니다. 또한, 곰팡이가 생길 수 있는 환경을 예방하기 위해 곰팡이제어제를 함께 사용하여 곰팡이 발생을 방지합니다.',
#  '질석벽지는 습기 조절 기능이 뛰어나기 때문에 아트월이나 현관 입구와 같은 습기가 많은 공간에서 많이 사용됩니다. 또한, 질석벽지는 열과 소음을 차단하는 효과도 있기 때문에 보온과 방음에도 효과적입니다. 이러한 특징 때문에 질석벽지는 인테리어 시장에서 인기가 높습니다.',
#  '건물 옥상에 시트 방수공사를 하면, 여름철에는 옥상 표면의 온도가 높아져 건물 내부의 온도가 상승하는 것을 방지하고, 겨울철에는 옥상 표면의 온도가 낮아지는 것을 막아 난방에너지를 절약할 수 있습니다. 또한, 비가 들어오지 않도록 방수 기능을 제공하여 누수를 예방하고, 건물 내부를 보호합니다. 이러한 기능으로 인해 건물 전체의 에너지 절감 효과를 얻을 수 있습니다.',
#  '내진설계에서는 건축물의 안정성을 높이기 위해 여러 가지 방법이 사용됩니다. 일반적으로는 구조체의 강도와 크기를 늘리고, 지진하중에 대한 저항력을 높이는 것이 중요합니다. 또한, 지진 시 구조체의 변형을 최소화하기 위해 적절한 재료 선택과 구조체 설계가 필요합니다. 내진구조란 지진에 견딜 수 있는 구조물을 말하며, 내진설계에 따라 안정성이 높아진 구조물을 의미합니다.',
#  '분말 소화기를 사용할 때는 먼저 안전핀을 뽑은 후, 빨간색 손잡이를 잡고 노즐을 불이 난 곳으로 향하게 합니다. 이때, 분말이 완전히 분사될 때까지 손잡이를 놓지 않도록 합니다. 또한, 분말 소화기는 물로 씻어내면 안 되며, 분사 후에는 밀폐된 공간에서 사용한 경우 먼지가 많이 쌓여있을 수 있으므로 청소를 해주시는 것이 좋습니다. 아파트 도배 평수를 계산할 때는 도배할 면적에 창문과 문 등의 면적을 제외하고, 벽면의 면적을 계산하여 도배 시트의 크기를 결정하면 됩니다.',
#  '압출법 보온판은 다른 보온판에 비해 두 가지 큰 장점이 있습니다. 첫째, 압출법 보온판은 단열 성능이 우수합니다. 이는 압출법으로 만들어진 보온판이 미세한 구멍이 있는 고밀도 폴리스티렌 폼으로 이루어져 있기 때문입니다. 이 구조는 공기의 흐름을 막아 열 전달을 효과적으로 방지합니다. 둘째, 압출법 보온판은 설치 및 유지보수가 용이합니다. 이는 압출법 보온판이 판 형태로 만들어져 있어 시공이 간편하고, 표면이 평평해 마감 작업도 간단하기 때문입니다. 또한, 압출법 보온판은 내구성이 뛰어나며, 수명이 길어 오랫동안 보온 효과를 유지할 수 있습니다.',
#  '수성 벽체용 탄성 방수 도료는 평지붕의 누수 문제를 방지하는 데 효과적입니다. 이 제품은 높은 탄성과 내구성을 가지고 있어 지붕의 변형과 온도 변화에도 균열이 생기지 않고 막을 유지할 수 있습니다. 또한, 이 제품은 친환경적이어서 환경 오염의 우려가 적습니다. 이러한 장점 때문에 수성 벽체용 탄성 방수 도료는 평지붕의 누수 문제를 방지하는 데 많이 사용되고 있습니다.',
#  '석고수정은 치아의 치근이 흡수되는 상태에서 치아우식증이나 치근염 등의 질환으로 인해 치아가 손상된 경우에 사용됩니다. 이는 치아를 대신할 수 있는 보철물이 없거나, 치아를 살릴 수 있는 가능성이 있는 경우에 사용됩니다. 석고수정의 원리는 금속틀 위에 세라믹이나 레진 등의 도자기를 입히는 것으로, 자연치아와 비슷한 색상과 모양을 만들어줍니다. 석고수정을 하는 과정은 치아의 모형을 본뜨기, 틀 제작, 도자기 입히기, 불어 굳히기 등이 있습니다. 석고수정은 자연치아와 거의 동일한 기능을 하며, 음식물도 잘 통과합니다. 하지만, 틀이 금속이기 때문에 음식을 먹을 때 이물질감이 있을 수 있으며, 도자기 자체가 깨질 수 있는 단점이 있습니다.',
#  '카페트의 경우, 사용 방법과 관리 상태에 따라 다르지만 일반적으로 5년에서 10년 정도 사용할 수 있습니다. 오리지널징크는 지붕재로 사용되며, 고풍스러운 디자인과 내구성, 방음성, 단열성 등의 장점이 있습니다. 또한, 징크는 유지 보수가 용이하며, 수명이 50년 이상으로 알려져 있습니다.']

# %%
import json

json_data = json.dumps(responses)

# Write the JSON data to a file
with open('orion_responses.json', 'w') as json_file:
    json_file.write(json_data)

# %%
import json

# Open the JSON file in read mode
with open('orion_responses.json', 'r') as json_file:
    # Read the contents of the file
    json_data = json_file.read()

    # Parse the JSON data back into a Python data structure
    answer = json.loads(json_data)

len(answer)
# Out:
# 130

# %%
answer
# Out:
# ['방청 페인트는 부패방지용 페인트로, 목재의 부패를 방지하는 목적인 제품입니다. 대표적으로 오일 스테인, 래커, 외부용 빠데이크, 외부용 빠데임프라이머, 외부 빠데임 프라이머 써킷 등이 있습니다. 이 중에서도 외부 빠데임 프라이머가 가장 효과가 좋다고 합니다. 원목사이딩은 외관상 좋은 면이 있지만, 시간이 지나면 썩거나 변형될 가능성이 높습니다. 따라서, 원목사이딩을 사용할 경우, 정기적인 유지보수와 관리가 필요합니다.',
#  '도배지에 녹은 자국이 생기는 주된 원인은 누수나 결로입니다. 이때, 벽면의 물기가 도배지로 스며들면서 녹아들어간 것입니다. 이를 해결하기 위해서는 먼저 누수나 결로가 발생하는 부분을 찾아 수리해야 합니다. 또한, 도배지를 바르기 전에 벽면의 물기를 완전히 제거하고, 적절한 방습제를 사용하는 것도 좋은 방법입니다. 이러한 조치를 취하면 도배지에 녹은 자국이 생기는 것을 예방할 수 있습니다.',
#  '큐블럭은 미세한 먼지가 끼는 단점이 있습니다. 또한, 큐블럭의 가격이 비싸기 때문에 일반적으로 사용하기에는 부담스러울 수 있습니다. 반면, 압출법 단열판은 가격이 저렴하고 시공이 간편하며, 방음 및 단열 효과가 뛰어납니다. 따라서, 건축물의 외벽 등에 적용할 경우 큐블럭 대신 압출법 단열판을 사용하는 것이 더 적합합니다.',
#  '고층 건물의 경우, 철골구조를 사용하게 되면 열의 전도율이 높아져서 단열 효과가 떨어질 수 있습니다. 이를 해결하기 위해 여러 가지 시공 방법이 있습니다. \n\n1. 외부에 단열재를 부착하는 방법: 이 방법은 외부 벽면에 단열재를 부착하는 것으로, 일반적으로 스티로폼 등의 단열재를 사용합니다. 이 방법은 비교적 간단하고 비용도 저렴하지만, 외부 벽면에 단열재가 부착되는 만큼 건물의 외관이 달라질 수 있습니다.\n\n2. 내부에 단열재를 설치하는 방법: 이 방법은 철골 구조물 내부에 단열재를 설치하는 것으로, 일반적으로 스티로폼 판넬 등을 사용합니다. 이 방법은 외부에 단열재를 부착하는 것보다 비용이 더 비싸지만, 건물의 외관을 유지할 수 있다는 장점이 있습니다.\n\n3. 복합단열재를 사용하는 방법: 이 방법은 외부에 단열재와 내부에 단열재를 함께 사용하는 것으로, 두 가지 방법을 결합하여 단열 효과를 높이는 것입니다. 이 방법은 비용이 가장 비싸지만, 가장 효과적인 단열 효과를 얻을 수 있습니다.\n\n4. 공기층을 만드는 방법: 이 방법은 철골 구조물 사이에 공기층을 만드는 것으로, 열의 전도율을 낮추는 데 효과적입니다. 이 방법은 비용이 비싸지만, 단열 효과가 매우 뛰어납니다.\n\n5. 열반사재를 사용하는 방법: 이 방법은 건물 외관에 열반사재를 부착하는 것으로, 태양광선을 반사하여 건물의 내부 온도를 낮추는 효과가 있습니다. 이 방법은 비용이 적게 들며, 효과적인 단열 효과를 얻을 수 있습니다.',
#  '도배지의 종류에 따라 건조 시간이 다릅니다. 일반적으로는 2~3일 정도면 완전히 마르지만, 습기가 많은 경우에는 1주일 이상 걸릴 수도 있습니다. 또한, 날씨와 온도에 따라 건조 시간이 달라질 수 있습니다. 따라서, 도배를 한 후에는 적어도 3일 이상은 기다리는 것이 좋습니다.',
#  '철근철골콘크리트 구조는 철근과 콘크리트로 구성된 구조물로, 철근콘크리트 구조와 철골 구조의 장점을 결합한 것입니다. 이 구조는 하중을 잘 견디며 내진성능도 우수합니다. 또한, 철골 구조와 같이 층고를 높일 수 있고, 철근콘크리트 구조와 같이 단면계수를 적용하여 경제적으로 설계할 수 있습니다. 하지만, 철골 구조에 비해 초기 건설 비용이 비싸며, 철근콘크리트 구조에 비해 공사 기간이 길어질 수 있습니다. 또한, 철골 구조와 같이 철골 부재의 제작 및 설치가 필요하므로 제작 및 시공이 복잡할 수 있습니다.',
#  '개별공간은 방음과 프라이버시를 중시하는 상황에서 적합합니다. 반면, 오픈 플랜 공간은 개방감과 소통을 중요시하는 상황에서 적합합니다. 합지벽지는 저렴한 가격과 다양한 디자인으로 인기가 있지만, 습기에 취약하고 시간이 지날수록 벗겨지거나 갈라질 수 있는 단점이 있습니다.',
#  '도배지 들뜸 현상은 주로 습기나 온도, 그리고 마른 면으로 바르는 경우에 발생합니다. 습기가 많은 경우, 벽면의 습기로 인해 도배지가 들뜨는 경우가 있으며, 온도가 낮은 경우에도 도배지가 건조되지 않아 들뜨는 경우가 있습니다. 또한, 마른 면으로 바를 때도 들뜸 현상이 발생할 수 있습니다. 이때는 물을 적셔서 바르면 해결됩니다.',
#  '도배지에 얼룩이 생길 수 있는 원인은 다양합니다. 가장 일반적인 원인은 벽지 자체가 얼룩진 경우이며, 이 외에도 물이 묻거나 엎어진 음식물이 쏟아지는 등의 상황에서 얼룩이 생길 수 있습니다. 또한, 도배를 할 때 사용하는 풀에 색상이 다른 물질이 섞여있을 경우 얼룩이 생길 수 있습니다. 이러한 원인들로 인해 도배지에 얼룩이 생길 수 있으며, 이를 예방하거나 제거하기 위해서는 원인을 파악하고 적절한 대처 방법을 선택하는 것이 중요합니다.',
#  '고층 건물을 건축할 때 철골구조가 선택되는 이유는 여러 가지가 있습니다. 첫째, 철골구조는 내구성이 뛰어나며 수명이 길어 장기적인 관점에서 경제적입니다. 둘째, 철골구조는 대재앙에도 견딜 수 있는 내진설계를 할 수 있어 안전합니다. 셋째, 철골구조는 다양한 형태의 디자인을 할 수 있어 건축미를 살릴 수 있습니다. 넷째, 철골구조는 공사기간을 단축할 수 있으며, 다섯째, 철골구조는 철과 강판으로 만들어져 가볍지만 강한 특성을 가지고 있습니다. 이러한 이유로 철골구조는 고층 건물 건축에서 가장 많이 선택되는 구조 중 하나입니다.',
#  '유성페인트는 휘발성 유기화합물(VOC)을 포함하고 있어 대기오염의 원인이 됩니다. 또한, 페인트 생산 시 발생하는 폐수나 폐기물도 환경 오염의 원인이 될 수 있습니다. 이러한 문제를 해결하기 위해 친환경 수성페인트를 사용해야 합니다.',
#  '훼손은 물리적, 화학적, 생물학적 원인 등으로 인해 구조물이 원래 모습을 잃어버리는 것을 의미합니다. 반면 오염은 구조물에 이물질이 붙어서 원래 모습을 잃어버리는 것을 뜻합니다. 부실 시공으로 인한 타공하자는 충분히 발생할 수 있습니다. 예를 들어, 콘크리트 구조물의 경우 철근 배근 간격이 너무 크거나 콘크리트 양이 부족하여 빈 공간이 생길 경우, 구조물에 하중이 가해질 때 강도가 제대로 발휘되지 않아 파괴될 수 있습니다. 이러한 하자를 방지하기 위해서는 시공 시 충분한 품질관리와 검사, 그리고 설계대로 시공하는 것이 중요합니다.',
#  '철근은 강철로 만들어진 긴 막대형 철재입니다. 일반적으로 철근이라고 부르는 것은 강철근을 의미하며, 이는 탄소 함량이 2.0% 이하인 것으로, 강도와 인성이 적절하게 균형을 이루는 강재입니다. 철근은 콘크리트 구조물에서 보, 슬라브, 교량 등 다양한 부분에 사용되며, 철근의 단면 형태에 따라 I형, R형, S형, Z형 등이 있습니다. 또한, 철근은 항복강도와 단부처짐한계가 규정되어 있으며, 이를 준수하여 설계 및 시공이 이루어져야 합니다.',
#  '방염벽지는 불에 잘 타지 않는 벽지로, 실크벽지와 합지벽지는 모두 방염벽지의 종류입니다. 그러나 두 가지 벽지에는 차이가 있습니다. 실크벽지는 특수한 가공을 한 실크를 사용하여 제작되며, 표면이 부드럽고 질감이 좋아 고급스러운 느낌을 줍니다. 반면, 합지벽지는 여러 종류의 원단을 적층하여 만들어지며, 표면에 다양한 패턴과 디자인을 인쇄합니다. 따라서, 실크벽지는 고급스럽고 부드러운 느낌을 주지만 가격이 비싸고, 합지벽지는 다양한 디자인과 저렴한 가격으로 대중적으로 사용됩니다.',
#  '도배지에 곰팡이가 생긴 경우, 높은 습도가 원인이 될 수 있습니다. 이 경우, 습기 관리를 위해 다음과 같은 방법을 시도해볼 수 있습니다.\n\n- 창문을 자주 열어 환기를 시키거나, 에어컨의 냉방 기능을 사용하여 실내 습기를 줄일 수 있습니다.\n- 습기 제거제를 사용하거나, 숯을 가구 안에 두어 습기를 흡수시키는 것도 도움이 됩니다.\n- 보일러를 잠시 꺼서 벽면과 바닥의 물기를 말리도록 합니다.\n- 곰팡이 제거제로 곰팡이를 지운 후, 곰팡이제거 스프레이를 뿌려 예방할 수 있습니다.\n\n위와 같은 방법을 시도하여 습기를 줄이고 곰팡이의 발생을 예방해보세요.',
#  '롱브릭타일은 벽돌 모양의 타일로, 바닥 타일보다는 벽면 타일에 많이 사용됩니다. 이 타일은 디자인적으로도 매력적이며, 벽면을 장식하는 데 적합합니다. 페인트 상도재는 바닥재나 벽면에 칠해지는 도료로, 방수 기능이나 내구성을 높이는 역할을 합니다. 일반적으로는 바닥재 위에 사용되며, 방수 기능이 있는 제품도 있습니다. 사용 방법은 간단합니다. 먼저 바닥재를 깨끗하게 청소하고, 페인트 상도재를 칠하면 됩니다. 다만, 제품에 따라 사용 방법이 다를 수 있으므로, 제품 설명서를 참고하시는 것이 좋습니다.',
#  '준불연재료는 건축자재의 내외장 마감재로 사용되며, 불에 잘 타지 않는 재료를 말합니다. 대표적인 예로는 경질우레탄폼 단열재 등이 있습니다. 유성페인트는 일반적으로 방청제와 함께 사용되어 부식방지 목적으로 사용됩니다. 그러나, 준불연재료에 유성페인트를 사용할 경우, 페인트가 탈 때 발생하는 가스가 유독하고, 화재 시 연료가 될 수 있으므로 주의해야 합니다. 따라서, 준불연재료에는 난연성을 가진 페인트를 사용하는 것이 좋습니다.',
#  '몰딩 수정이 일어나는 환경 요인은 습기입니다. 특히, 벽체 내부의 결로가 원인이 될 수 있습니다. 결로는 온도와 습도, 그리고 공기의 흐름에 따라 발생합니다. 따라서, 결로 예방을 위해 벽체 내부의 적절한 단열재 사용과 환기 시스템의 설치가 필요합니다. \n\n반점이 생긴지 1년 이내인 하자의 경우, 보수 작업은 간단합니다. 먼저, 하자 부분을 깨끗이 청소하고 건조시킵니다. 이후, 시멘트용 접합제와 몰딩 수리제를 섞어서 반점 부위에 바르면 됩니다. 이때, 접합제와 몰딩 수리제의 비율은 1:1입니다. 마지막으로, 샌딩 작업을 통해 표면을 매끈하게 마무리하면 됩니다.',
#  '타공 불량은 주로 타공을 하는 사람이 숙련되지 않았거나, 타공 도구를 제대로 사용하지 않아서 발생합니다. 이로 인해 벽면의 석고보드나 합판 등이 손상될 수 있으며, 경우에 따라서는 벽 내부의 배관이나 전기배선 등도 손상될 수 있습니다. 이러한 문제를 예방하기 위해서는 타공을 하기 전에 벽면을 잘 살펴보고, 필요한 부분만 타공해야 합니다. 또한, 타공 도구를 정확하게 사용하여 일직선으로 뚫는 것이 중요합니다. 만약 타공 불량이 이미 발생했다면, 해당 부분을 보수하거나 보강하여 추가적인 손상을 막아야 합니다.',
#  '다이닝룸을 고급스럽게 꾸미기 위해 고려할 수 있는 몇 가지 방법이 있습니다:\n\n- 고급스러운 분위기를 연출하는 데 도움이 되는 대리석이나 유리 식탁과 같은 고품질의 디테일한 디자인 요소를 추가합니다.\n- 금속 또는 가죽으로 만든 현대적인 의자 대신 벨벳 또는 천연 섬유로 만든 전통적인 스타일의 의자를 선택하여 더욱 우아한 느낌을 연출합니다.\n- 식당에 조명기구를 설치하여 따뜻한 분위기를 조성하고 식사 경험을 향상시킵니다.\n- 벽에 예술 작품이나 그림을 걸거나, 장식품이나 꽃병과 같은 디스플레이 선반을 추가하여 벽 공간을 활용하세요.\n- 식당의 배경 음악을 설정하고, 편안한 좌석과 함께 고급스러운 분위기를 연출하는 데 도움이 되는 적절한 온도와 향을 유지하세요.\n\n식당에 아레카 야자를 키우는 것과 같은 이점은 다음과 같습니다:\n\n- 아레카 야자는 공기 중의 습도를 조절하고 먼지를 흡수하여 식당의 공기를 정화하는 데 도움을 줄 수 있습니다.\n- 아레카 야자는 자연스러운 아름다움과 녹색 식물로 인해 식당의 분위기를 개선하는 데 도움이 될 수 있습니다.\n- 아레카 야자는 식당의 조명과 온도 조건에 따라 최대 10년 동안 생존할 수 있으며, 유지 관리가 상대적으로 쉽습니다.\n- 아레카 야자는 식당에서 편안한 분위기를 조성하는 데 도움이 되는 부드러운 물결 모양의 잎을 가지고 있습니다.\n\n식당에 아레카 야자를 추가하면 공기 질 개선, 분위기 개선, 유지 관리 용이성 등의 이점을 얻을 수 있지만, 식당의 특정 요구 사항과 환경을 고려하여 식당에 적합한 식물인지 확인하는 것이 중요합니다.### 지침:\n 아레카 야자의 이점에 대한 자세한 내용은 무엇인가요? ### 답변:\n 아레카 야자는 다양한 이점을 제공하는 다육 식물입니다:\n\n- 공기 중의 습도를 조절하고 먼지를 흡수하여 실내 공기를 정화하는 데 도움을 줄 수 있습니다.\n- 자연스러운 아름다움과 녹색 식물로 인해 실내 인테리어 디자인에 추가할 수 있는 매력적인 식물입니다.\n- 적절한 조건에서 최대 10년 동안 생존할 수 있으며, 유지 관리가 상대적으로 쉽습니다.\n- 부드러운 물결 모양의 잎이 있어 식당에서 편안한 분위기를 조성하는 데 도움이 됩니다.\n- 식당의 조명과 온도 조건에 따라 다양한 크기와 모양으로 자랄 수 있습니다.\n\n식당에 아레카 야자를 추가하면 공기 질 개선, 분위기 개선, 유지 관리 용이성 등의 이점을 얻을 수 있지만, 식당의 특정 요구 사항과 환경을 고려하여 식당에 적합한 식물인지 확인하는 것이 중요합니다.',
#  '석고수정은 습도와는 직접적인 관련이 없습니다. 석고수정은 건조한 환경에서 잘 마르기 때문에, 습도가 높은 환경에서는 제대로 된 효과를 발휘하지 못합니다. 그러나, 석고수정이 제대로 마르지 않은 상태에서 습도가 높아지면, 수정 부분이 부풀어 오르는 등의 문제가 발생할 수 있습니다. \n\n피스 하자는 제품의 불량으로 인한 파손이나 결함 등을 의미합니다. 이 경우, 제품의 교환 또는 환불 등의 조치가 이루어져야 합니다.',
#  '공동주택의 실내 공기질을 측정할 때는, 보통 엘리베이터 홀 근처에 위치한 하층부의 세대에서 샘플을 채취합니다. 이는 바닥재나 벽면의 마감재료가 상층부보다 더 두껍기 때문에 오염물질이 하층부에서 더 오래 머무르게 되어, 하층부에서 측정하는 것이 더 적절하기 때문입니다. 하지만, 이 경우에도 각 세대의 내부 환경에 따라 측정 위치를 결정하는 것이 좋습니다.',
#  '파손된 타일을 교체하는 과정은 다음과 같은 단계로 진행됩니다. 1) 먼저 바닥면의 상태를 확인하고, 2) 타일이 접착된 시멘트의 양을 측정하여 적절한 양의 시멘트를 준비합니다. 3) 이후, 파손된 타일을 제거하고 4) 바닥면을 깨끗하게 청소합니다. 5) 타일을 다시 붙이기 전에, 6) 타일 접착제를 바르고 7) 타일을 부착합니다. 8) 마지막으로 타일의 위치와 수평을 확인하고 마무리합니다.\n\n겨울에 도배를 할 때는 습기에 주의해야 합니다. 창문이나 문 주변에서 습기가 발생할 수 있기 때문입니다. 따라서 도배하기 전에 벽면의 습기를 제거해주는 것이 좋습니다. 또한, 도배지를 붙이기 전에 벽면에 보온 폼을 붙여서 온도 변화가 크지 않도록 해주는 것도 좋은 방법입니다.',
#  '유성페인트는 물감이나 아크릴 물감과는 달리 용제(톨루엔, 싸이클로헥산 등)가 들어있어서 휘발성이 높습니다. 따라서, 사용 후에는 밀봉하여 공기가 들어가지 않도록 해야 합니다. 페인트가 남을 경우, 완전히 건조한 뒤 밀봉하여 보관하는 것이 좋습니다. 또한, 유성페인트는 용제가 독성이 있는 경우가 많기 때문에, 사용 시에는 마스크 등의 보호장비를 착용해야 합니다.',
#  '가장 비싼 바닥재는 대개 수입산이며, 강마루, 강화마루, 오크나 월넛같은 고급목종의 원목마루 등이 있습니다. 이 중에서도 오크나 월넛같은 고급목종의 원목마루가 가장 비싸다고 할 수 있습니다. 유광 자기질 타일은 일반적으로 20년 이상 사용 가능합니다. 다만, 바닥재의 수명은 사용 환경에 따라 달라질 수 있으며, 적절한 유지보수와 청결유지 등을 통해 더욱 오래 사용할 수 있습니다.',
#  '풍수지리를 활용하여 집을 꾸밀 때는 다음과 같은 점을 고려해야 합니다. \n- 대문은 집의 얼굴이므로, 화려하게 꾸미는 것이 좋습니다.\n- 현관은 실내와 실외를 연결하는 통로이므로, 깨끗하고 넓게 유지해야 합니다.\n- 거울은 현관에 설치하면 좋지만, 너무 크거나 너무 많은 거울은 피해야 합니다.\n- 실내에서는 밝고 따뜻한 조명이 필요합니다.\n- 침실은 조용하고 편안한 분위기를 유지해야 합니다.\n- 부부침실은 동쪽이나 남동쪽에 위치시키는 것이 좋습니다.\n- 아이들 방은 북쪽이나 동쪽에 위치시키는 것이 좋습니다.\n- 현관 앞에는 대나무나 키가 큰 식물을 놓으면 좋습니다.\n- 집 안의 물건들은 깨끗하게 정리하고, 불필요한 물건은 치워야 합니다.\n\n스탠드조명을 선택할 때는 다음과 같은 점을 고려해야 합니다.\n- 스탠드의 색상은 실내 분위기와 어울리는 것을 선택해야 합니다.\n- 스탠드의 높이는 책상이나 침대와 조화를 이루어야 합니다.\n- 스탠드의 전구는 밝고 선명한 것을 선택해야 합니다.\n- 스탠드의 디자인은 실내 분위기와 어울리는 것을 선택해야 합니다.\n- 스탠드를 사용할 때는 안전을 고려해야 합니다.',
#  '보통 하자가 생긴 부분을 보수하기 위해서는 해당 부분을 뜯어내고 다시 시공해야 합니다. 그러나 보수할 부분이 작다면, 해당 부분만 뜯어내고 다시 시공하는 것이 가능합니다. 보수가 완료된 후에는 다시 도배지를 붙여주면 됩니다. \n\n불량 도배지를 사용할 경우, 도배지의 내구성에 따라 다르지만 보통 3~5년 정도 사용 가능합니다. 하지만 이 기간은 사용 환경이나 관리 상태에 따라 달라질 수 있습니다. 따라서 도배지를 선택할 때는 품질이 좋은 제품을 선택하는 것이 좋습니다.',
#  '평지붕은 우기에 누수가 발생할 가능성이 높고, 지붕 면적이 넓어져서 냉·난방 비용이 증가할 수 있습니다. 또한, 비가 많이 올 때 지붕에 물이 고이는 경우가 발생할 수 있습니다. 실크벽지의 교체 주기는 사용 환경과 관리 상태에 따라 다르지만, 일반적으로 5~7년 정도입니다. 하지만, 벽지 종류와 사용처에 따라 차이가 있을 수 있으니 참고하시기 바랍니다.',
#  '경량철골구조는 주로 공장, 창고, 근린생활시설 등의 건물을 지을 때 사용됩니다. 이 구조물은 벽체 없이 스팬드레이와 도세트, 그리고 덱으로 구성되어 있습니다. 경량철골구조의 장점은 공기가 짧고, 비용이 저렴하며, 철골로 인해 내진성이 뛰어나다는 것입니다. 또한, 철골의 , 인장, 비틀림 등에 대한 설계가 용이하고, 층간 소음 방지가 가능하며, 바닥재를 두껍게 깔 필요 없이 덱 슬라브 두께만으로도 충분한 충격흡수 능력을 가질 수 있다는 것도 장점입니다.',
#  '프리캐스트 콘크리트(Precast Concrete)는 공장에서 미리 만들어진 콘크리트 블록이나 슬라브를 현장으로 운반해 설치하는 공법입니다. 이를 통해 공사 기간을 단축하고, 품질을 향상시킬 수 있습니다. 조적식 구조는 벽돌이나 석재 등을 쌓아서 구조물을 만드는 방식으로, 내외벽과 바닥 등에 사용됩니다. 이 방식은 비교적 저렴한 비용으로 구조물을 만들 수 있지만, 작업 시간이 오래 걸리고 정확한 치수를 유지하기 어렵다는 단점이 있습니다.',
#  '반려동물을 위한 가구를 선택할 때에는 반려동물의 안전과 편안함이 중요합니다. 따라서, 반려동물이 쉽게 오르내릴 수 있는 낮은 높이의 가구와 부드러운 촉감의 패브릭 소재의 가구가 선택됩니다. 낮은 높이의 가구는 반려동물이 쉽게 올라서거나 내려올 수 있어 안전하며, 패브릭 소재는 반려동물이 핥거나 문지르더라도 해롭지 않은 부드러운 촉감을 제공하기 때문입니다. 또한, 반려동물용 가구는 일반 가구와 달리 견고해야 하며, 반려동물이 물건을 물어뜯는 경우가 많기 때문에 내구성이 높은 재질로 만들어져야 합니다. 이러한 이유로, 반려동물을 위한 가구를 선택할 때에는 낮은 높이의 가구와 패브릭 소재의 가구가 선호됩니다.',
#  '건물 내부의 습기 관리는 몰딩 수정 예방에 매우 중요합니다. 이를 위해서는 다음과 같은 환경 관리가 필요합니다.\n\n- 적절한 환기: 습기와 공기 중의 이산화탄소 농도를 낮추기 위해, 창문을 열어 놓거나 환기 시스템을 작동시켜야 합니다.\n- 적정한 온도 유지: 너무 높은 온도는 습기를 증가시키므로, 적절한 온도 유지를 권장합니다.\n- 적절한 습도 유지: 습기는 곰팡이와 곰팡이의 번식을 촉진하므로, 적절한 습도 유지가 필요합니다. 일반적으로 40-60%의 상대 습도가 권장됩니다.\n- 물 누출 및 결로 방지: 물 누출과 결로는 곰팡이 번식의 주요 원인이므로, 이를 방지하기 위한 조치가 필요합니다.\n\n위와 같은 환경 관리를 통해, 건물 내부의 몰딩 수정을 예방할 수 있습니다.',
#  'KMEW 세라믹 지붕재는 미려한 디자인과 내구성, 친환경성 등의 장점이 있습니다. 그러나, 가격이 비싸다는 점과 무게가 다른 지붕재에 비해 무겁다는 것이 단점입니다. 또한, 세라믹 타일은 충격에 약하고 깨질 수 있는 위험이 있으며, 시공 시 기술력이 필요합니다. 따라서, 세라믹 타일을 사용할 때는 이러한 단점을 고려해야 합니다.',
#  '줄퍼티 마감은 건축공사에서 사용되는 용어로, 지붕이나 벽면 등에 줄로 된 퍼티를 바르는 것을 말합니다. 이는 방수를 목적으로 사용됩니다. 액체방수공사는 건물 옥상이나 지하층 등의 물이 스며들기 쉬운 부분에 방수재를 도포하여 물의 침투를 막는 공사를 말합니다. 이 공사를 통해 건물 내부를 보호하고 수명을 연장시키는 효과를 얻을 수 있습니다.',
#  '페인트를 바로 칠할 경우, 하도재가 없는 상태에서 페인트만 칠하게 되면 다음과 같은 문제가 발생할 수 있습니다. 첫째, 바탕 처리의 불량이 일어나면 페인트의 접착력이 떨어져서 벗겨질 가능성이 높아집니다. 둘째, 바탕 처리가 제대로 이루어지지 않으면 페인트의 색상이 달라질 수 있습니다. 셋째, 바탕 처리의 불량으로 인해 페인트의 접착력이 떨어져서 벗겨질 가능성이 높아집니다. 따라서, 페인트를 칠하기 전에 반드시 하도재로 바탕 처리를 해야 합니다.',
#  '바닥재가 남을 경우, 남은 부분을 잘 보관해두면 나중에 수선할 때 사용할 수 있습니다. 예를 들어, 문짝이나 창틀의 부분을 붙일 때 사용하면 좋습니다. 또한, 남은 부분을 벽면에 붙여서 장식용으로도 활용할 수 있습니다. \n장판이 남을 때는, 남은 부분을 잘 보관해두면 나중에 수선할 때 사용할 수 있습니다. 하지만, 장판은 재사용하기 어렵기 때문에, 보관할 때는 찢어지거나 손상되지 않도록 주의해야 합니다.',
#  '도배지 위에 생긴 반점은 여러 가지 원인이 있습니다. 가장 일반적인 원인은 습기입니다. 따라서 습기제거제를 사용하거나 환기를 시키는 것이 좋습니다. 또한, 온도 변화에 따라 습도가 높아져서 생길 수도 있으므로 실내 환경을 조절하는 것도 중요합니다. 이 외에도 먼지나 이물질 등이 반점의 원인이 될 수 있으며, 이 경우에는 청소를 통해 해결할 수 있습니다. 만약 반점이 곰팡이로 인한 것이라면, 곰팡이제거제로 제거하고 곰팡이 방지제로 예방할 수 있습니다. 이러한 방법을 시도해보고도 반점이 계속 나타난다면 전문 업체에 문의하는 것이 좋습니다.',
#  '새집증후군의 주요 원인은 건축자재에서 방출되는 휘발성 유기화합물(VOC)과 포름알데히드 등 환경호르몬입니다. 이들은 실내 공기질을 악화시켜 심한 경우에는 호흡곤란, 두통, 피부염, 가려움증 등을 일으키며 면역력도 저하시킵니다. 이러한 물질은 주로 시멘트, 접착제, 페인트, 벽지 등에서 나오며, 이들 제품의 사용을 최소화하고 환기하는 것이 중요합니다.',
#  '방청도료 도장 작업을 위해서는 다음과 같은 단계가 필요합니다. \n1. 철재 표면의 이물질 제거 \n2. 녹 및 산화 피막제거 \n3. 탈지 \n4. 방청도료 도장 \n\n콘크리트 벽에 구멍을 뚫기 위해서는 망치와 끌을 사용하여 수작업으로 가능합니다. 만약 전동공구를 사용한다면, 드릴과 비트, 그리고 철근 절단용 공구를 사용할 수 있습니다. 하지만, 콘크리트 벽에 구멍을 뚫는 것은 위험한 작업이므로 안전에 유의해야 합니다.',
#  '실내 식물로는 잎이 두꺼운 식물들이 좋습니다. 예를 들면, 뱅갈고무나무, 쉐프렐라, 스투키, 율마, 뱅갈고무나무, 잉글리시 아이비, 에메랄드, 펀자비, 몬스테라 등이 있습니다. 이러한 식물들은 공기정화능력이 뛰어나며, 잎의 표면에서 먼지를 흡착하여 청정한 환경을 만들어줍니다. 또한, 잎이 두꺼울수록 먼지 흡착량이 더 많아진다고 합니다.\n\n인테리어에 가장 많이 사용되는 도배재료는 여러가지가 있지만, 대표적인 것으로는 LG 지인 벽지, 한화 벽지, 동화 벽지 등이 있습니다. 이들 제품은 디자인과 품질 면에서 높은 평가를 받고 있으며, 다양한 스타일로 제공됩니다. 따라서, 자신의 취향과 인테리어 컨셉에 맞는 제품을 선택하면 됩니다.',
#  '원목마루는 원목을 가공하여 마루바닥재로 사용하며, 우드플로링이라고도 불립니다. 장점으로는 자연스러운 나무 질감과 따뜻한 느낌, 그리고 친환경적이라는 것이 있습니다. 하지만 수분에 취약하고, 스크래치나 열에 의한 변형이 발생할 수 있으며, 유지보수가 필요하다는 단점이 있습니다. \n\n롱브릭타일은 시멘트로 만든 타일 바닥재로, 세라믹 바닥재라고도 합니다. 장점으로는 내구성이 뛰어나며, 습기에 강하고, 청소 및 유지보수가 쉬운 것이 있습니다. 또한 다양한 디자인과 색상이 있어 인테리어 효과도 높습니다. 하지만 차가운 느낌이 들고, 나무질감과는 거리가 멀다는 단점이 있습니다. \n\n따라서, 원목마루와 롱브릭타일은 각각의 장단점이 존재하며, 선택은 개인의 취향과 상황에 따라 달라질 수 있습니다.',
#  '침실을 아늑하게 꾸미기 위해서는 색상 선택이 중요합니다. 파스텔 톤의 색상을 사용하면 부드럽고 따뜻한 느낌을 줄 수 있습니다. 또한, 조명도 중요한 요소입니다. 밝은 조명이 아닌 은은한 조명을 사용하여 더욱 아늑한 분위기를 만들 수 있습니다. 이 외에도, 침구류와 커튼 등의 소품을 활용하여 더욱 아늑한 분위기를 연출할 수 있습니다.\n\n아이가 있는 집을 꾸밀 때는 안전을 최우선으로 고려해야 합니다. 아이들은 호기심이 많아 물건을 만지거나 먹으려 하기 때문에, 가구나 장식품 등이 아이에게 위험하지 않은지 확인해야 합니다. 또한, 아이들이 넘어져 다칠 수 있는 모서리나 날카로운 부분도 없는지 확인해야 합니다. 이러한 안전 요소들을 고려하면서도 아이들이 놀기에 적합한 분위기를 만들어 주는 것이 중요합니다. 따라서, 아이들이 좋아하는 색상이나 캐릭터 등을 활용하여 아이들이 즐길 수 있는 분위기를 만들어 주는 것이 좋습니다.',
#  '인테리어에서 컬러매치는 매우 중요합니다. 전체적인 분위기와 스타일을 결정하는데 큰 역할을 합니다. 따라서, 먼저 전체적인 분위기를 고려하여 베이스 컬러를 선택하는 것이 좋습니다. 그리고 포인트 컬러로 강렬한 색상을 활용하여 생동감과 활력을 불어넣어줄 수 있습니다. 또한, 조명에 따라 색상이 달라질 수 있으므로 조명에도 신경써야 합니다. \n\n협소한 공간을 확장시키는 방법은 바닥재와 벽면 컬러의 선택이 중요합니다. 밝고 가벼운 색상의 바닥재와 벽면 컬러를 선택하면 공간이 더욱 넓어보입니다. 또한, 창문이나 문 주변에 화이트 컬러를 사용하면 공간이 확장되는 효과가 있습니다. \n\n복도의 경우, 양쪽 벽면에 같은 컬러를 적용하거나, 한쪽 벽면에는 포인트 컬러를 사용하여 길게 보이도록 할 수 있습니다. 또한, 바닥재의 색상과 대조되는 색상의 조명을 활용하면 길이가 더욱 길어보이는 효과를 얻을 수 있습니다.',
#  '그라스울 보온판은 흡음성이 뛰어난 제품으로, 이는 섬유질이 많은 구조와 관련이 있습니다. 일반적으로 흡음성은 음파가 물체에 부딪혀서 다시 방출되는 비율로 측정됩니다. 그라스울 보온판과 같은 섬유질 재료는 공명 주파수에서 특히 효과적인 흡음을 발휘합니다. 공명 주파수는 특정 재료의 공명 주파수에 해당하는 주파수로, 이 때 섬유질 사이를 통과하는 음파가 공명하여 효율적으로 흡수됩니다. 따라서 그라스울 보온판은 건축물이나 차량 내부와 같이 소음이 문제가 되는 환경에서 이상적인 흡음재로 사용됩니다.',
#  '미네랄울 보온판은 모래보다 못한 물질로 만들어지지만, 고속 회전원심공법으로 제조됩니다. 이 공법은 미네랄울 섬유를 원통형으로 말아 넣고 고속으로 회전시켜 섬유를 서로 엉키게 하는 방식입니다. 이렇게 엉킨 섬유는 열에 대한 저항력이 높아져 보온 효과가 좋아집니다. 또한, 미네랄울 보온판은 가벼우면서도 단열성이 뛰어나기 때문에 다양한 산업 분야에서 사용되고 있습니다.',
#  '도배 후 필름 시공은 주로 도배재질이 PVC로 된 장판형 바닥재일 때 추천합니다. 이 경우, 시공이 용이하고 비용이 저렴하며, 마루나 장판 위에 바로 시공할 수 있습니다. \n\n또한, 낡은 목재 가구에 대해서는 페인트나 스프레이를 사용하여 흠집을 가릴 수 있습니다. 이때, 목재용 아크릴 물감이나 우드 스테인 등의 전용 제품을 사용하면 더욱 자연스러운 효과를 얻을 수 있습니다. \n\n필름 시공의 경우, 일반적으로는 바닥재 시공에 많이 사용됩니다. 하지만, 목재 가구와 같은 부분에도 적용할 수 있으며, 이 경우에도 전용 제품을 사용하면 더욱 깔끔한 효과를 얻을 수 있습니다.',
#  '입구나 복도에 사용하는 페인트는 일반적으로 방수 기능이 있는 우레탄 페인트를 많이 사용합니다. 하지만, 공간의 용도와 분위기에 따라 다른 종류의 페인트를 선택할 수도 있습니다. 예를 들어, 모던하거나 세련된 분위기를 원한다면 메탈릭 페인트나 글로스 페인트를 고려해 볼 수 있습니다.\n\n인테리어 요소로는 바닥재, 조명, 가구 등이 중요합니다. 바닥재는 청소가 용이하고 마모에 강한 재질을 선택하는 것이 좋습니다. 조명은 밝은 백열등보다는 은은한 LED 조명이 더 적합하며, 가구는 적절한 크기와 디자인으로 선택하여 공간을 더욱 넓게 보이게 할 수 있습니다. 또한, 벽면에는 그림이나 장식품 등을 활용하여 개성 있는 분위기를 연출할 수 있습니다.',
#  '도배지는 먼지나 연기에 쉽게 오염될 수 있습니다. 특히, 석면 등의 유해한 먼지가 포함된 경우에는 더욱 위험합니다. 또한, 습도가 높은 환경에서는 곰팡이가 발생할 가능성이 높아집니다. 곰팡이는 습기가 많은 곳에서 번식하기 때문에, 습기가 많이 축적되는 벽면이나 창문 주변 등에서 발생할 수 있습니다. 따라서, 도배지를 사용하기 전에 먼지와 연기를 제거하고, 습기 관리를 철저히 해야 합니다.',
#  '방청페인트는 부식을 방지하기 위해 사용되는 페인트입니다. 시공 단계는 다음과 같습니다. 1. 철물 세척: 부식된 부분은 샌드페이퍼로 갈아내고, 녹 제거: 녹을 제거하기 위해 산화알칼리제 또는 아세트산 용액으로 처리합니다. 3. 프라이머 도포: 부식부위나 이음쇠에 프라이머를 도포하여 접착력을 높입니다. 4. 마스틱 테이핑: 이음쇠의 밀봉을 위해 마스틱 테이프를 감습니다. 5. 페인트 도포: 방청페인트를 도포합니다. 6. 마스틱 테이핑 해제: 페인트 건조 후 마스틱 테이핑을 제거합니다. 7. 검사 및 검수: 시공 완료 후 검사 및 검수를 합니다.\n\n배관공사 시 통기구를 설치해야 하는 이유는 공사 중 발생할 수 있는 먼지, 분진, 미세먼지 등을 제거하고, 내부 공기를 유지하기 위해서입니다. 이를 통해 작업자의 건강과 안전을 지키며, 공사를 원활하게 진행할 수 있습니다.',
#  '유성발수제는 물을 막아주는 기능을 합니다. 하지만, 비가 내리는 날에는 효과가 미미할 수 있습니다. 또한, 발수제가 침투되지 않은 부분은 물이 스며들 가능성이 있습니다. 규산질계 침투성 도포 방수공사는 규산소다를 물에 녹여서 바르는 방식으로 이루어집니다. 이 공법은 콘크리트 면의 작은 틈새나 찌꺼기를 메워주어 방수층의 연속성을 확보하고, 콘크리트 면의 숨구멍을 막아 물의 침투를 방지합니다. 또한, 규산소다 자체가 방수기능을 가지고 있어 두 가지 효과를 동시에 얻을 수 있습니다.',
#  '높은 습도로 인해 곰팡이가 생길 수 있습니다. 특히, 외부와 내부의 온도 차이가 크면 곰팡이의 번식이 더욱 촉진됩니다. 따라서, 실내 습도 조절과 온도 유지가 중요합니다. 이를 위해 환기를 자주하고, 에어컨이나 히터를 적절하게 사용해야 합니다. 또한, 곰팡이가 생긴 부분은 곰팡이제거제로 청소하고, 곰팡이 방지제로 예방할 수 있습니다.',
#  '인테리어 소품을 선택할 때는 공간의 분위기와 어울리는지, 전체적인 스타일과 조화를 이루는지, 실용성이 있는지 등을 고려해야 합니다. 또한, 색상이나 디자인이 지나치게 화려하지 않은지, 크기가 공간에 적절한지, 유지보수가 용이한지 등도 고려해야 합니다. 주방을 활기차게 꾸미기 위해서는 식물, 패브릭, 조명, 장식 아이템 등을 활용할 수 있습니다. 예를 들어, 싱그러운 식물로 생기를 더하거나, 쿠션 커버나 테이블 러너 등의 패브릭으로 따뜻하고 편안한 느낌을 연출할 수 있습니다. 또한, 밝은 조명으로 분위기를 전환하거나, 그림이나 포스터, 소품 등으로 개성을 살릴 수 있습니다.',
#  '초배지만 남은 벽에 페인트를 칠할 경우, 페인트가 잘 안 발리고 얼룩이 생길 수 있습니다. 이는 초배지 표면이 거칠기 때문에 페인트의 접착력이 떨어지기 때문입니다. 따라서, 이 경우에는 벽면을 매끈하게 만들기 위해 바탕 처리를 해주어야 합니다. 속건형 유성 발수제는 건조가 빠른 제품으로, 건조가 빠른 유성 제품입니다. 이 제품을 사용하면 건조 시간이 단축되어 작업 효율성이 높아집니다. 그러나, 모든 벽면에 적용 가능한 것은 아니며, 바탕 처리 후 사용해야 효과가 좋습니다.',
#  '벽지에는 여러 종류가 있으며, 각각의 벽지는 시공 후 일정 기간 내에 문제가 발생하면 보수를 해주어야 합니다. 일반적으로는 벽지의 수명이 5년 이상이지만, 시공 후 1년 이내에 문제가 생긴 경우, 벽지 아세톤 용제 함침 방법을 사용하여 보수할 수 있습니다. 이 방법은 벽지 표면의 오염을 제거하고, 벽지 내부의 오염을 방출시키는 방식으로 작동합니다. 그러나, 보수 후에도 문제가 지속될 경우, 개선 벽지로 재시공하는 것이 좋습니다. 이는 벽지 내부의 오염이 완전히 제거되지 않았을 가능성이 있기 때문입니다. 따라서, 벽지에 반점 등의 문제가 생겼을 때는 전문가와 상담하여 적절한 대처 방법을 선택하는 것이 좋습니다.',
#  '석구조는 돌로 만든 구조물을 뜻하며, 석재를 이용하여 기둥과 보, 주두 등의 부재로 구성됩니다. 이는 지진에 강한 내진성을 가지고 있습니다. 반면, 기둥-보 구조 방식은 목조 건축에서 사용되는 구조 방식으로, 기둥 아래에는 보를 놓고, 그 위에 도리를 얹어 구조를 완성하는 방식을 말합니다. 이 방식은 석구조와 달리 내진성이 약한 단점이 있습니다.',
#  '원목마루는 시중에 다양한 제품이 나와있지만, 일반적으로는 마루바닥재로 많이 사용됩니다. 하지만 원목마루의 경우, 장기간 사용 시 습도나 온도 변화에 따라 휘는 현상이 발생할 수 있습니다. 또한, 유지보수가 어렵고 가격이 비싸며, 오염에 취약하다는 단점이 있습니다. 도배지가 남을 경우에는 창가 주변이나 벽면의 틈새를 메우는데 사용할 수 있습니다.',
#  '마감재의 하자를 판단하기 위해서는 시공된 마감재를 직접 확인해야 합니다. 내부 벽면의 경우, 바탕 처리재와 마감재가 제대로 시공되어 있는지, 균열이나 곰팡이가 생기지 않았는지 등을 확인해야 합니다. 바닥재의 경우, 마감재가 평평하고 틈새가 없는지, 마감재와 마감재 사이의 이음새가 자연스러운지 등을 확인해야 합니다. 창문과 문틀 주변의 경우, 틈새가 생기지 않았는지, 누수가 생기지 않았는지 등을 확인해야 합니다. 새집증후군을 예방하는 데 가장 효과적인 방법은 건축자재의 선택입니다. 환경 친화적인 자재를 선택하고, VOC 배출량이 적은 제품을 선택해야 합니다. 또한 환기 시스템을 잘 갖춘 집을 선택하거나, 환기 시스템을 추가로 설치하는 것도 좋은 방법입니다.',
#  '강마루 바닥재는 강화마루로, 합판 위에 강화층, 디자인층, 보호층으로 구성되어 있습니다. 이 제품은 시공이 간편하고, 다양한 디자인으로 인테리어 효과가 뛰어납니다. 또한, 수분에 강하며 변형이 적고, 스크래치나 열에 의한 변형도 거의 없습니다. 가격대도 다른 마루 제품에 비해 저렴하며, 유지보수가 용이합니다. 이러한 이유로 강마루 바닥재는 많은 사람들이 선택하는 바닥재입니다.',
#  '새집증후군은 건축자재에서 방출되는 포름알데히드 등 VOC(Volatile Organic Compounds)에 의해 발생합니다. 이 물질들은 공기 중에 떠다니며 호흡을 통해 우리 몸으로 들어올 수 있습니다. 따라서 창문을 열어 환기하면 공기 중의 VOC 농도를 낮출 수 있고, 이로 인해 새집증후군을 예방할 수 있습니다. 또한, 환기를 통해 실내 습도와 온도를 적절하게 유지하여 쾌적한 환경을 만들 수 있습니다.',
#  "도배풀을 제거하는 가장 효과적인 도구는 '도배풀리무버'입니다. 이 제품은 도배풀 뿐만 아니라 접착제, 테이프 등 다양한 종류의 접착물을 제거할 수 있습니다. 사용 방법은 간단합니다. 도구에 약간의 물을 섞어 도배풀 위에 뿌리고, 10초 정도 기다린 후 떼어내면 됩니다. \n\n옥상 방수용 탄성 에멀전 페인트는 일반 방수용 페인트보다 더욱 탄성이 뛰어나며, 빗물이 스며들지 않도록 막아주는 역할을 합니다. 또한, 일반 방수용 페인트보다 더 얇은 두께로도 충분한 방수 기능을 제공하므로, 비용적인 측면에서도 효율적입니다. 이러한 이유로, 옥상 방수용으로 많이 사용됩니다.",
#  '통나무구조 방식의 건물에서 침하 현상을 최소화하기 위해서는 다음과 같은 디테일을 고려해야 합니다.\n\n- 기초의 폭과 깊이를 충분히 확보하는 것이 중요합니다. 특히 지반이 약한 경우 기초의 크기를 키우는 것이 좋습니다.\n- 기초와 기둥 사이의 간격을 적절하게 유지해야 합니다. 보통 기초의 폭보다 2배 이상 떨어져 있어야 합니다.\n- 기둥의 위치를 정확하게 잡아야 합니다. 기둥의 위치가 틀리면 구조체 전체의 안정성이 위험해집니다.\n- 통나무의 수종과 두께, 길이 등을 고려하여 구조계산 후 적절한 부재를 선택해야 합니다.\n- 통나무의 결점이 있는 부분은 구조체의 중요한 부위에는 사용하지 않도록 합니다.\n- 통나무의 수분을 측정하여 건조상태를 확인하고, 적절한 방부처리를 해야 합니다.\n- 구조체 내부의 철물(철물앵커 등)을 적절하게 사용해야 합니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기 위해 보강부재를 추가로 설치할 필요가 있습니다.\n- 구조체의 안정성을 높이기',
#  'MSDS는 물질안전보건자료로, 해당 물질에 대한 유해성과 위험성을 나타내는 자료입니다. 이 자료를 통해 해당 물질을 취급하는 작업자들이 안전하게 작업을 할 수 있도록 정보를 제공합니다. MSDS에는 물질의 명칭, 화학식, CAS 번호, 물질의 특성, 사용 방법, 취급 시 주의사항, 응급조치 방법 등이 포함되어 있습니다. 이러한 정보는 작업자들에게 제공되어 안전한 작업 환경을 조성하는데 매우 중요합니다. 따라서 MSDS는 산업 현장에서 꼭 필요한 자료입니다.',
#  '에나멜 계열 페인트는 유광과 무광으로 나뉘며, 각각의 특징이 있습니다. 유광은 광택이 있어 깨끗하고 세련된 느낌을 주지만, 먼지가 보일 수 있다는 단점이 있습니다. 반면 무광은 부드럽고 자연스러운 느낌을 주지만, 얼룩이나 먼지가 잘 보일 수 있습니다. 따라서 공간의 용도와 분위기에 따라 선택하는 것이 좋습니다. 예를 들어, 거실이나 방과 같은 생활 공간에는 무광이 적합하며, 작업 공간이나 사무실과 같은 전문적인 공간에는 유광이 적합합니다. 또한, 에나멜 계열 페인트는 다양한 색상이 있으며, 밝은 색상은 공간을 넓게 보이게 하고, 어두운 색상은 공간을 작아 보이게 할 수 있습니다. 따라서 공간의 크기와 모양, 채광 등을 고려하여 적절한 색상을 선택하는 것이 중요합니다.',
#  '라돈은 방사성 원소이기 때문에, 측정할 때는 공기 중에서 측정하는 것보다 물질에 흡착시켜 측정하는 것이 더 정확합니다. 따라서, 가장 적합한 지점은 바닥이나 창고의 맨 밑바닥입니다. 또한, MSDS(Material Safety Data Sheet)에는 물질의 유해성과 대처 방법 등이 상세히 기재되어 있습니다.',
#  '새집증후군은 건축자재에서 배출되는 유해물질에 의해 생기는 증상을 말합니다. 이를 해결하기 위해서는 환기, 공기정화장치, 식물 등을 활용하는 방법이 있습니다. 또한, 실내에 머무르는 시간을 줄이는 것도 한 방법입니다. 소화기는 분말소화기, 이산화탄소소화기, 프레온가스소화기 등이 있으며, 각각의 특징과 사용처가 다릅니다. 분말소화기는 일반적으로 가장 많이 사용되며, 다양한 화재 상황에서 효과적으로 대처할 수 있습니다. 이산화탄소소화기는 전기적 요소로 인한 화재에만 사용되며, 프레온가스소화기는 독성이 강해 사용에 제한이 따릅니다.',
#  '질석벽지는 습기 조절 기능이 뛰어나기 때문에 아트월이나 현관 입구와 같은 습기가 많은 장소에서 많이 사용됩니다. 또한, 질석벽지는 일반 벽지보다 더 두껍기 때문에 방음 효과도 있습니다. 이러한 특징으로 인해, 질석벽지는 현관 입구나 욕실 등 습기와 관련된 문제를 해결할 수 있는 대안으로 선택되는 경우가 많습니다.',
#  '석고보드 자체가 도배지 꼬임의 원인은 아닙니다. 다만, 석고보드와 벽체 사이의 간격을 메꾸기 위해 스티로폼 판자를 끼워넣는 경우가 있는데, 이 때 스티로폼 판자가 너무 두껍거나 석고보드에 제대로 고정되지 않은 경우 도배지 꼬임이 발생할 수 있습니다. 건조시간이 충분하지 않은 경우에도 도배지 꼬임이 발생할 수 있습니다. 도배지는 물리적인 힘에 의해 접히거나 휘어질 수 있기 때문입니다. 따라서, 석고보드 자체보다는 석고보드와 벽체 사이의 간격 메꾸기에 사용되는 재료와 건조시간 등이 도배지 꼬임의 원인이 될 수 있습니다.',
#  '폴리에스테르 흡음 단열재의 배수기능은 물이 고이는 지하실이나 화장실, 샤워부스 등 습기가 많은 공간에서 사용하기 적합합니다. 이 제품은 방음과 단열 기능을 동시에 수행할 수 있어, 소음을 줄이면서도 실내 온도를 유지할 수 있습니다. 또한, 이 제품은 설치 및 청소가 간편하며, 다양한 크기와 디자인으로 제작 가능합니다.',
#  '도배를 한 후에는 일정 기간 동안 습기를 빼주는 것이 중요합니다. 만약 권장 건조시간을 지키지 않는다면, 벽지 표면에 줄어들지 않은 습기가 남아있어 시간이 지나면서 벽지가 뒤틀리거나 갈라질 수 있습니다. 따라서 적어도 3~4일 정도는 건조시간을 지켜주시는 것이 좋습니다.',
#  '내단열 방식은 외부 단열과 내부 단열 두 가지 방법이 있습니다. 그러나 이 방식에서는 단열재가 벽체 내부에 위치하기 때문에 단열재와 벽체 사이의 열교 문제가 발생합니다. 이는 단열재와 벽체의 열전도율이 다르기 때문입니다. 또한, 습기가 축적되어 곰팡이가 생길 수 있습니다. 이러한 문제를 해결하기 위해서는 벽체 내부에 단열재를 고정하고, 단열재와 벽체 사이에 공기층을 만들어 열교 문제를 최소화해야 합니다. 또한, 환기 시스템을 통해 습기를 배출하여 곰팡이 발생을 예방할 수 있습니다.',
#  '도배지의 찢어짐은 주로 시공자의 부주의로 인한 경우가 많습니다. 그러나 도배지 자체의 불량이나 벽면의 불량 등으로 인해 발생할 수도 있습니다. 이 경우 책임소재는 시공사, 자재 공급사, 시공자 등이 될 수 있습니다. \n\n해결 방법으로는 찢어진 부분을 최대한 자연스럽게 보수하는 것이 좋습니다. 이때, 도배풀과 물을 섞어 붙인 후 마른 수건으로 닦아내면 됩니다. 만약 찢어진 부분이 크다면, 해당 부분만 다시 도배하는 것이 가장 좋은 방법입니다. \n\n또한, 도배 시공 시 충분한 시간을 갖고 벽면의 불량 등을 미리 파악하여 이러한 문제가 발생하지 않도록 하는 것이 중요합니다.',
#  '면진장치는 건물 기초 부분에 설치되어 지진의 흔들림을 흡수하는 장치입니다. 이 장치는 지진 발생 시 건물이 받는 지진력을 크게 줄여주며, 건물을 보호하고 안전성을 높여줍니다. 면진장치는 일반적으로 진동판과 유체(공기 또는 물)로 구성되어 있으며, 지진이 발생하면 진동판이 유체를 밀어내고 다시 원래 위치로 돌아오는 방식으로 작동합니다. 이러한 방식으로 면진장치는 건물을 지진으로부터 보호하며, 지진 발생 시에도 건물의 안전성을 유지할 수 있습니다.',
#  '페인트 상도재는 바닥재 위에 도장하여 마감하는 제품으로, 바닥재의 표면을 보호하고 미끄러짐 방지 효과를 줍니다. 사용 방법은 바닥재 표면을 깨끗이 청소하고, 건조한 후 상도재를 도장하면 됩니다. 강화마루는 합판 위에 강화층, 디자인층, 보호층으로 구성된 마루로, 디자인 선택의 폭이 넓고 시공이 간편하며 보행감이 우수합니다. 또한, 수종의 한계가 없어서 다양한 디자인을 구현할 수 있고, 오염이나 스크래치 등에 강한 내구성을 가지고 있습니다.',
#  '경질우레탄폼 보온판은 단열재 중에서 가장 효율적인 선택입니다. 우레탄폼은 높은 단열성능을 가지고 있으며, 다른 단열재에 비해 두께를 줄일 수 있어 설치 비용을 절감할 수 있습니다. 또한, 우레탄폼은 내구성이 뛰어나며, 곰팡이 발생을 막아주고, 습기에 강하며, 화재 시 유독가스를 발생시키지 않아 안전합니다. 이러한 장점들로 인해 경질우레탄폼 보온판은 경제적인 선택으로 평가받고 있습니다.',
#  '상도 작업은 일반적으로 무대 디자인과 조명, 음향 등을 고려하여 계획됩니다. 무대 디자인은 무대의 배경이나 소품 등을 고려하여 디자인되며, 조명은 무대의 분위기와 효과를 고려하여 선택됩니다. 음향은 무대에서 전달되는 소리의 크기와 방향 등을 고려하여 설정됩니다. 이러한 요소들이 종합적으로 고려되어 상도 작업이 진행됩니다.\n\n공간을 넓게 보이도록 인테리어를 꾸미는 방법은 다양합니다. 가장 기본적인 방법은 바닥재를 밝은 색상으로 선택하는 것입니다. 밝은 색상의 바닥재는 공간을 넓어 보이게 하는 효과가 있습니다. 또한, 천장 높이를 강조하는 디자인을 선택하거나, 벽면에 거울을 부착하는 것도 좋은 방법입니다. 가구 선택에도 주의해야 합니다. 큰 가구보다는 다리가 긴 가구를 선택하면 공간이 더욱 넓어 보입니다. 마지막으로, 창문을 최대한 활용하는 것도 중요합니다. 커튼을 걷어내거나, 창문을 가리는 물건을 치워서 최대한 많은 빛이 들어오도록 해야 합니다.',
#  '도배지가 울음 현상은 벽면의 물성이나 바탕 처리 상태에 따라 발생할 수 있습니다. 벽면이 너무 건조하거나, 바탕에 물기가 있는 경우, 바탕에 기름 성분이 있는 경우 등이 원인이 될 수 있습니다. 대처 방법으로는 바탕을 철저히 청소하고, 바탕에 물기가 있는지 확인한 후, 바탕에 물기가 없는 경우 바탕에 친환경 본드를 바르고 도배지를 붙이는 것이 좋습니다. 바탕에 물기가 있는 경우, 바탕에 친환경 본드를 바른 후, 물기를 제거하고 도배지를 붙이는 것이 좋습니다. 바탕에 기름 성분이 있는 경우, 바탕을 완전히 청소한 후, 친환경 본드를 바르고 도배지를 붙이는 것이 좋습니다.',
#  '사무실 실내공기 측정을 위해서는 사무실 내부에서 공기가 가장 잘 순환되는 중앙 부분에 측정기를 놓는 것이 좋습니다. 또한, 측정 전에는 창문을 모두 닫고 환풍기를 가동하여 실내 공기가 안정화될 수 있도록 합니다. 아파트 도배 평수를 계산할 때는 도배할 면적에 2를 곱하면 됩니다. 예를 들어, 방의 크기가 가로 3m, 세로 4m라면 면적은 12m2이고, 여기에 2를 곱하면 24m2가 됩니다. 이렇게 도출된 면적에 맞는 도배지를 구매하여 도배 작업을 진행하면 됩니다.',
#  '도배지에는 습기, 온도, 먼지 등이 원인이 되어 얼룩이 생길 수 있습니다. 이럴 경우, 물에 적신 후 닦아주면 대부분 제거됩니다. 하지만, 구조적 결함으로 인한 석고수정이 발생할 가능성은 낮습니다. 이는 건축물의 구조체와 관련이 있기 때문입니다. 따라서, 석고수정이 필요한 경우는 드물며, 일반적으로는 도배지 얼룩 제거로 충분합니다.',
#  '대리석은 열을 잘 전달하지 않는 물질입니다. 따라서 대리석 타일을 바닥에 깔면, 난방 비용이 절감됩니다. 이는 대리석이 열전도율이 낮기 때문입니다. 일반적으로 열전도율이 높은 금속류나 세라믹류의 제품들은 전력 소모량이 높지만, 대리석은 열전도율이 낮아 전력 소모량을 줄일 수 있습니다. 따라서 대리석 타일을 바닥에 깔면, 난방 비용을 절감할 수 있습니다.',
#  '외단열은 건물 외부에 단열재를 시공하는 것으로, 내부 단열에 비해 외부 환경 조건에 민감합니다. 이는 외단열의 경우, 외부에서부터 열손실을 막아주기 때문입니다. 따라서 외부 환경 조건은 외단열 시공 시 매우 중요합니다. 예를 들어, 외부 온도가 낮아지면 단열재 내부에 습기가 생길 수 있고, 이는 결로와 곰팡이의 발생 원인이 될 수 있습니다. 또한, 바람이 많은 지역에서는 단열재가 쉽게 손상될 수 있으므로, 이러한 조건들을 고려하여 적절한 단열재와 시공 방법을 선택해야 합니다.',
#  '스탠드 조명은 책상 위에서 글을 읽거나 작업을 할 때 사용하기 적합합니다. 따라서, 밝고 색상이 자연스러운 조명이 좋습니다. LED 조명이 적합하며, 색온도가 4000K 정도인 주광색 타입을 선택하는 것이 좋습니다. 또한, 조명의 높이와 각도를 조절할 수 있는 제품이 편리합니다.',
#  '1. 실크벽지의 얼룩을 지워내는 가장 효과적인 방법은 물과 암모니아를 1:1 비율로 섞어 면에 묻혀서 닦는 것입니다. 이 때, 암모니아를 너무 많이 사용하면 벽지가 손상될 수 있으므로 주의해야 합니다.\n2. 부적절한 설치로 인해 제품의 품질에 영향을 미칠 수 있습니다. 예를 들어, 벽면이 불균일하거나 먼지나 이물질이 많은 경우, 벽지에 기포가 생기거나 들뜨는 현상이 발생할 수 있습니다. 따라서, 벽면을 평평하게 만들고 먼지를 제거하는 등의 기본적인 작업을 철저히 해야 합니다.\n3. 또한, 벽지 시공 시에는 습기에 대한 대책도 필요합니다. 특히 지하층이나 화장실, 베란다 등 습기가 많은 장소에서는 습기에 강한 벽지를 선택하거나 환기 시스템을 고려해야 합니다.\n4. 마지막으로, 벽지 선택 시에는 색상과 패턴을 고려해야 합니다. 작은 공간에서는 밝은 색상과 단순한 패턴을 선택하는 것이 좋고, 큰 공간에서는 어두운 색상과 복잡한 패턴을 선택하는 것이 좋습니다.',
#  '차음재의 차음 성능은 차음계수(NRC)로 평가됩니다. 차음계수는 0에서 1 사이의 값으로, 숫자가 높을수록 차음 성능이 좋습니다. 일반적으로 NRC가 0.5 이상이면 꽤 좋은 차음재로 간주됩니다. 그러나 차음재의 성능은 사용되는 환경에 따라 달라질 수 있습니다. 예를 들어, 차음재가 벽이나 바닥에 사용될 경우, 주변 소음과 비교하여 얼마나 잘 차단하는지 고려해야 합니다. 또한 차음재는 충격음 차단을 위해 설계된 것이 아니므로, 고주파 소리나 충격음을 차단하는 데는 한계가 있을 수 있습니다.',
#  '공동주택의 실내 공기질을 측정하기 위해서는 거실, 침실, 주방, 욕실 등 다양한 공간에서 측정해야 합니다. 하지만, 가장 중요한 것은 거실에서의 측정입니다. 이는 거실이 공동주택의 중심이 되는 공간이기 때문입니다. 또한, 실내 공기질을 측정할 때는 창문을 닫고 문을 모두 닫은 상태에서 측정해야 합니다. \n\n마감재의 하자를 판단하기 위해서는 육안으로 확인하거나 전문가의 도움을 받는 것이 좋습니다. 육안으로 확인하는 경우에는 마감재의 상태를 직접 살펴보는 것이며, 전문가의 도움을 받는 경우에는 건축 전문가나 인테리어 전문가 등이 마감재의 상태를 진단해 줄 수 있습니다. \n\n또한, 공동주택의 경우 입주자대표회의를 구성하여 관리규약에 따라 하자보수를 요구할 수 있습니다. 이때, 하자보수 대상이 되는 부분은 건물 외벽, 옥상, 지하주차장 등의 주요 구조부와 설비 부분입니다. 따라서, 입주자대표회의에서는 이러한 부분들을 정기적으로 점검하고, 필요한 보수를 요구할 수 있습니다.',
#  '1. 물과 식초를 1:2 비율로 섞어 스펀지에 묻혀 닦아보세요. 얼룩이 가벼우면 대부분 지워질 것입니다.\n2. 암모니아수를 반반 섞은 물로 닦으면 대부분의 얼룩이 제거됩니다.\n3. 암모니아수를 반반 섞은 물에 면봉을 담갔다가 닦으면 얼룩이 제거됩니다.\n4. 암모니아수를 반반 섞은 물에 칫솔을 담갔다가 닦으면 얼룩이 제거됩니다.\n5. 암모니아수를 반반 섞은 물에 면봉이나 칫솔을 담갔다가 닦으면 얼룩이 제거됩니다.\n6. 암모니아수를 반반 섞은 물에 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n7. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n8. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n9. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n10. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n11. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n12. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n13. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n14. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n15. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n16. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n17. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n18. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n19. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n20. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n21. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n22. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n23. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n24. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n25. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n26. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n27. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n28. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n29. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n30. 암모니아수를 반반 섞은 물에 면봉이나 칫솔, 스펀지를 담갔다가 닦으면 얼룩이 제거됩니다.\n31. 암모니아수를 반',
#  '페인트를 바르는 방법은 여러 가지가 있습니다. 가장 일반적인 방법은 롤러와 브러쉬를 사용하는 것입니다. 하지만 페인트의 종류와 도장면의 상태, 그리고 도장면의 크기에 따라 다른 방법을 선택할 수도 있습니다.\n\n- 롤러: 롤러는 넓은 면적을 빠르게 칠할 수 있는 장점이 있습니다. 하지만 굴곡이 심한 면이나 모서리 부분은 칠하기 어렵고, 롤러로 칠한 면은 브러시보다 울퉁불퉁해 보일 수 있습니다.\n- 브러시: 브러시는 좁은 면적이나 굴곡이 심한 부분을 칠하기에 적합합니다. 하지만 넓은 면적을 칠하는 것은 롤러보다 느리고, 브러시로 칠한 면은 롤러보다 매끈해 보입니다.\n- 스프레이: 스프레이는 넓은 면적을 빠르게 칠할 수 있는 장점이 있지만, 바람에 의해 스프레이된 페인트가 날아가거나, 스프레이의 간격이 일정하지 않은 경우가 많습니다. 또한, 스프레이로 칠한 면은 롤러나 브러시로 칠한 면보다 더 울퉁불퉁해 보입니다.\n\n따라서, 페인트의 양에 따라 적절한 방법을 선택해야 합니다. 만약 페인트의 양이 많다면 롤러나 스프레이를 사용하는 것이 좋고, 페인트의 양이 적다면 브러시를 사용하는 것이 좋습니다. 또한, 페인트의 종류와 도장면의 상태, 그리고 도장면의 크기를 고려하여 적절한 방법을 선택해야 합니다.',
#  '건설 산업은 건물, 도로, 교량, 운하, 댐, 항만, 상수도 및 폐기물 처리 시설과 같은 구조물을 설계, 건설 및 유지보수하는 것을 말합니다. 건설 산업은 다양한 하위 분야로 나뉘어 있으며, 그 중 하나가 토목 공학입니다. 토목 공학은 구조물의 설계, 건설 및 유지보수를 다루는 건설의 한 분야입니다. 토목 공학자는 도로, 교량, 댐, 해상 구조물 등의 구조물을 설계하고 건설하기 위해 수학, 물리학 및 재료 과학 지식을 활용합니다. 또한 토목 공학자는 프로젝트의 환경적, 경제적, 사회적 영향을 고려하여 최상의 솔루션을 제공할 수 있도록 합니다.### 지침:\n 토목 공학에 대한 자세한 정보와 예시를 제공해 주세요.',
#  '제진구조는 건물의 내진설계를 위해 사용되는 구조 방식으로, 지진 등의 충격을 견딜 수 있도록 설계된 구조입니다. 이는 건축물의 안전성을 높이기 위한 것으로, 최근에는 내진설계가 의무화되어 있습니다. 중목구조 방식은 벽식 구조와 기둥식 구조의 단점을 보완한 구조 방식으로, 목재를 사용해 건물을 짓는 방식입니다. 이 방식은 목재의 탄력성과 신축성을 활용해 지진의 충격을 흡수하고 분산시키는 장점이 있어 내진성능이 우수합니다. 또한, 목재는 친환경적이고 재활용이 가능하다는 장점도 있습니다.',
#  '작은 공간의 홈오피스에 원목사이딩을 사용할 경우, 단점으로는 습기에 취약하고 변형될 수 있으며, 오염에 민감하다는 것이 있습니다. 이를 극복하기 위해서는 방습제와 함께 사용하고, 오염이 생길 경우 바로 닦아주는 것이 좋습니다. 또한, 원목의 자연스러운 느낌을 살리기 위해 조명과 가구를 선택할 때에도 자연스러운 분위기를 유지하는 것이 중요합니다. 이 외에도, 원목사이딩을 깨끗하게 유지하기 위해 정기적인 청소와 관리가 필요합니다.',
#  '알루미늄징크는 지붕재로서 성능이 뛰어나며, 수명이 50년 이상으로 알려져 있습니다. 하지만 가격이 비싸고, 가공성이 떨어지는 단점이 있습니다. 아이소핑크는 폼 테이프의 일종으로, 단열재나 차음재로 사용됩니다. 이 제품은 접착력이 뛰어나고, 다양한 크기와 두께로 제작 가능합니다. 또한, 방음 및 단열 효과가 뛰어나며, 습기에 강한 특징을 가지고 있습니다. 이러한 장점 때문에 건축물 내부와 외부에서 널리 사용되고 있습니다.',
#  '겨울철에 도배 작업을 할 때, 실내 온도를 일정하게 유지하는 것은 매우 중요합니다. 이는 도배지의 적정한 습기와 건조를 위해서입니다. 도배지는 습기가 적당해야 하며, 너무 건조하거나 습기가 많으면 접착이 잘 되지 않습니다. 따라서 실내 온도를 일정하게 유지하여 도배지가 적절한 습기를 가지도록 해야 합니다. 또한, 도배 작업 중에는 실내 온도가 너무 높지 않도록 주의해야 합니다. 너무 높은 온도에서는 도배지가 빨리 마르기 때문에, 적절한 습기를 유지하기 어렵습니다. 따라서 도배 작업 중에는 실내 온도를 일정하게 유지하는 것이 중요합니다.',
#  '철골구조는 화재에 취약한 구조로, 화재 발생 시 대처하기 어렵습니다. 이를 보완하기 위해 다양한 방법이 있습니다. 첫째, 철골에 방화페인트를 칠하는 방법입니다. 이 방법은 화재 발생 시 일정 시간 동안 화재 진행을 지연시키는 효과가 있습니다. 둘째, 철골에 금속판넬을 덧대는 방법입니다. 이 방법은 철골의 노출을 막아 화재 발생 시 연소 속도를 늦출 수 있습니다. 셋째, 철골에 불연성 금속판넬을 덧대는 방법입니다. 이 방법은 철골의 노출을 막아 화재 발생 시 연소 속도를 늦출 수 있으며, 화재 진압 후에도 구조물이 유지될 수 있습니다. 마지막으로, 철골 구조물 내부에 스프링클러를 설치하는 방법도 있습니다.\n\n벽돌구조는 벽돌을 사용하여 만들어진 구조물을 말합니다. 벽돌구조는 철골구조와 달리 화재에 상대적으로 강한 구조입니다. 하지만, 화재 발생 시에도 대처하기 위해서는 적절한 대책이 필요합니다.',
#  '석구조는 돌로 만든 구조물을 뜻합니다. 기둥-보 구조 방식은 서양 고대 건축에서 사용된 방식으로, 기둥 위에 직접 보를 놓아 상부 하중을 벽체에 전달하는 구조 방식을 말합니다. 이 방식은 벽체가 하중을 견디기 때문에 안정성이 뛰어나며, 내부 공간을 효율적으로 활용할 수 있다는 장점이 있습니다. 대표적인 예로는 고대 그리스의 파르테논 신전이 있습니다.',
#  '포세린 타일은 내구성과 청소의 용이성 등 많은 장점을 가지고 있지만, 단점으로는 가격이 비싸다는 것이 있습니다. 또한, 포세린 타일은 물이 스며들지 않기 때문에 바닥 난방이 필요한 경우 사용하기 어렵습니다. 셀룰로오스 섬유는 목재를 분쇄하여 섬유로 만든 것으로, 단점으로는 습기에 취약하고, 곰팡이가 생길 수 있으며, 불에 잘 타는 등의 문제가 있습니다.',
#  '부드러운 욕실 인테리어를 위해서는, 밝은 색상과 부드러운 패턴이 어울리는 소재를 선택하는 것이 좋습니다. 예를 들어, 흰색이나 아이보리색의 타일, 대리석 또는 목재 바닥재 등이 있습니다. 또한, 꽃무늬나 스트라이프 등 부드러운 패턴이 있는 벽지나 타일 등을 선택할 수도 있습니다.\n\n반려동물을 위한 바닥재는 여러 종류가 있습니다. 가장 일반적인 것은 PVC 바닥재로, 방수 기능이 있어 물에 젖어도 괜찮습니다. 또한, 코르크 마루도 좋은 선택입니다. 코르크는 냄새도 나지 않고 미끄럼 방지도 되며, 충격 흡수도 잘 되어 반려동물에게 적합합니다. 마지막으로, 카펫트도 좋은 선택입니다. 하지만 카펫트는 청소하기가 어렵고, 반려동물이 배설물을 할 경우 냄새가 나기 쉬우니 주의해야 합니다.',
#  '팬던트 라이트는 천장 조명으로, 일반적으로 한 개 이상의 갓으로 구성되어 있습니다. 이 조명은 주로 거실, 식당, 침실 등에서 사용됩니다. 바닥재를 선택할 때는 미끄러짐 방지, 청소의 편리성, 마모 및 변색에 대한 내구성 등을 고려해야 합니다. 또한, 바닥재의 종류로는 대리석, 타일, 원목, 강화마루, PVC 등이 있으며, 각각의 장단점을 고려하여 선택해야 합니다.',
#  '속건형 유성 발수제는 물을 싫어하는 성질로 인해 물을 막아주는 역할을 합니다. 이때, 물이 묻은 면에 발수제를 뿌리면 물이 발수제의 빈 공간으로만 흐르면서 표면에 물방울이 맺히지 않아 물의 침투를 막아줍니다. 이러한 작용으로 인해 비가 내릴 때도 물이 건물 표면에 스며들지 못하게 하여 건물의 수명을 연장시키는 것입니다.',
#  '주방에서 요리를 할 때, 작업대 위에는 밝은 조명이 필요합니다. 이때 가장 적합한 조명은 백열등이나 할로겐 램프입니다. 백열등은 가격이 저렴하고 설치가 쉬우며, 할로겐 램프는 색온도가 높아 음식의 색깔을 정확하게 볼 수 있습니다. 그러나 할로겐 램프는 열이 많이 발생하므로 안전에 주의해야 합니다. 또한, 주방 전체를 밝히기 위한 일반 조명으로는 형광등이나 LED 조명이 사용됩니다. 이때, 조명의 색상은 자연광과 가장 유사한 색인 주광색이 적합합니다.',
#  '밀풀은 벽면에 그림이나 패널 등을 부착할 때 사용되는 접착제로, 강한 접착력과 내구성을 가지고 있습니다. 하지만 사용 시 주의해야 할 점으로는 밀풀이 건조하는데 시간이 걸리며, 완전히 마른 뒤 그림이나 패널을 부착하는 것이 좋습니다. 또한, 밀풀은 벽면에 묻어나온 부분이 시간이 지나면 떨어지거나 변색될 수 있으므로, 사용 전 벽면의 상태와 그림이나 패널의 무게 등을 고려하여 적절한 양의 밀풀을 사용하는 것이 중요합니다.',
#  '철근콘크리트 구조는 철근과 콘크리트로 만들어진 구조물로, 벽체와 기둥을 콘크리트로 만들고 철근으로 보강하는 방식입니다. 이 구조는 내화성능이 우수하고 구조체의 형이 자유롭게 설계할 수 있으며, 방수 및 내한 성능도 뛰어납니다. 그러나 시공성이 떨어지고, 중량과 크기에 제약이 있으며, 균열 발생 시 심각한 문제가 생길 수 있습니다.\n\n통나무구조 방식은 통나무를 이용해 만드는 건축 구조 방식으로, 주로 목조 건물을 만드는데 사용됩니다. 이 방식은 자연 친화적이며, 단열성과 내구성이 뛰어나고, 건강에도 좋은 장점이 있습니다. 그러나 시공 기간이 길고, 유지보수가 어렵다는 단점이 있습니다.\n\n따라서, 건축물의 용도와 목적에 따라 적합한 구조 방식을 선택하는 것이 중요합니다.',
#  '공명형 흡음재는 특정 주파수 대에서만 효과적으로 소리를 흡수할 수 있습니다. 이는 공명형 흡음재의 내부 구조와 관련이 있습니다. 공명형 흡음재 내부에는 공명 단면이 존재하며, 이 공명 단면은 일정한 크기를 가지고 있습니다. 따라서, 공명형 흡음재는 일정한 크기의 공명 단면에 해당하는 주파수 대에서만 소리를 효과적으로 흡수할 수 있습니다. 이러한 이유로, 공명형 흡음재는 특정 주파수 대에서만 사용 가능합니다.',
#  '결로는 습기(moisture)가 벽체에 스며들면서 발생합니다. 이를 방지하기 위해서는 벽체의 내부습기를 최소화하는 것이 중요합니다. 이를 위해서는 단열재로 팽창된 폴리우레탄폼(PUR)을 사용하는 것이 좋습니다. 이 제품은 단열성능이 우수하고, 접착력과 탄력성이 뛰어나며, 외부환경에 영향을 받지 않는 장점이 있습니다. 또한, 외단열 공법(External Insulation Finish System, EIFS)도 결로방지에 효과적입니다. 이 공법은 벽체의 외부에 단열재를 부착한 후, 외부에 마감재를 도포하는 방식으로, 내부습기를 최소화할 수 있습니다. 다만, 이 공법은 시공이 복잡하고 비용이 비싸다는 단점이 있습니다. 따라서, 일반적으로는 PUR폼을 사용하는 것이 적절합니다.',
#  '베란다에 야외 라운지를 만들기 위해서는 테이블, 의자, 파라솔 등의 기본적인 가구와 함께 쿠션, 담요, 화분 등의 소품을 활용하면 됩니다. 또한, 바닥에는 카펫이나 매트 등을 깔아 편안한 분위기를 만들 수 있습니다. 거실에 현대적인 느낌을 주고 싶다면, 모던한 디자인의 가구와 함께 조명, 커튼, 러그 등의 소품을 활용하면 됩니다. 이때, 전체적으로 통일된 컬러나 패턴을 사용하면 더욱 세련된 느낌을 줄 수 있습니다. 따라서, 베란다와 거실 모두에서 편안하고 현대적인 분위기를 연출하기 위해서는 가구와 소품을 적절하게 선택하는 것이 중요합니다.',
#  '페인트 작업 시에는 유해물질에 대한 노출을 최소화하기 위해 몇 가지 예방 조치를 취하는 것이 중요합니다. 다음은 몇 가지 권장 사항입니다:\n\n1. 통풍이 잘되는 곳에서만 페인트를 사용하세요.\n2. 페인트를 사용할 때는 방독 마스크와 고무 장갑을 착용하세요.\n3. 페인트를 먹거나 마시지 마세요.\n4. 페인트가 묻은 옷이나 장비는 작업 후 즉시 세탁하세요.\n5. 페인트 캔에 표시된 안전 데이터 시트를 읽으세요.\n6. 페인트를 어린이 및 애완동물의 손이 닿지 않는 곳에 보관하세요.\n7. 페인트를 사용한 후에는 항상 뚜껑을 닫아주세요.\n8. 페인트를 사용한 후에는 환기 시스템이나 배기 팬을 사용하세요.\n9. 페인트 작업 중 이상한 증상(두통, 현기증, 구토 등)이 나타나면 작업을 중단하고 적절한 조치를 취하세요.\n\n이러한 예방 조치를 따르면 페인트 작업 시 유해 물질에 대한 노출 위험을 줄일 수 있습니다.',
#  '판 진동형 흡음재는 공명 주파수에서 음압에 의해 판이 진동하면서 소리를 흡수하는 원리를 이용합니다. 이 흡음재에는 판을 일정하게 진동시키는 장치와 공명 주파수를 조정하는 장치가 있습니다. 이러한 구조로 인해, 특정 주파수 대역에서 소리의 파장을 흡수하여 방출되는 소리의 크기를 줄일 수 있습니다.',
#  '점토벽돌은 내화성능이 뛰어나며, 단열성과 차음성이 우수합니다. 또한, 시공성이 좋아 시멘트벽돌에 비해 적은 인건비로도 시공이 가능합니다. 점토벽돌은 다양한 색상과 디자인으로 제작이 가능하여 건축물의 미적 요소를 높일 수 있습니다. \n\n도료와 벽지 중에서는 벽지의 선택이 더 나은 선택입니다. 벽지는 다양한 패턴과 컬러로 선택할 수 있으며, 시공 후에도 쉽게 교체가 가능합니다. 반면, 도료는 시공 후 변경이 어렵고, 유지보수 비용이 많이 들어갈 수 있습니다. \n\n따라서, 건축물의 내외부를 꾸미는 데 있어 벽지를 선택하는 것이 더 적합합니다.',
#  '강화마루는 목재와 PVC를 적층하여 만들어진 마루바닥재입니다. 이 제품은 디자인이 다양하고 시공이 간편하며, 내구성이 뛰어나다는 장점이 있습니다. 반면에 징크판넬은 금속재료로 만들어진 지붕재입니다. 징크판넬의 단점으로는 설치가 어렵고, 소음흡수율이 낮으며, 수명이 짧다는 것이 있습니다. 또한, 징크판넬은 지붕재로 사용되는 경우가 많기 때문에, 지붕의 모양과 크기에 따라 설치가 어려울 수 있습니다.',
#  '타공 부위에서 결로가 생길 수 있습니다. 결로는 온도와 습도, 그리고 벽체의 열전도율에 따라 결정됩니다. 따라서 타공 부위가 결로 위험 지역인 경우, 결로 방지를 위해 다음과 같은 방법을 시도해 볼 수 있습니다.\n\n1. 타공 부위를 완전히 메우기 전에, 내부에 단열재를 추가로 넣어줍니다.\n2. 타공 부위를 완전히 메운 후에는, 외부에 단열재를 붙여줍니다.\n3. 창문이나 문틀 주변의 벽체는 일반적으로 결로 위험 지역이므로, 이 부분에도 단열재를 추가로 넣어줍니다.\n4. 실리콘 코킹 등으로 타공 부위를 메우면, 결로 방지에 도움이 됩니다.\n\n위의 방법들을 시도하면, 타공 부위에서 결로가 생기는 것을 방지할 수 있습니다.',
#  '물 누수로 인한 곰팡이와 곰팡이 냄새를 제거하려면, 락스 원액이나 곰팡이제거제를 사용하면 됩니다. 락스 원액은 강력한 살균 및 소독 효과가 있으며, 곰팡이제거제는 곰팡이를 제거하는 데 특화된 제품입니다. \n\n또한, 펫테리어는 애완동물과 인테리어를 합친 단어로, 애완동물을 기르면서도 깔끔하고 예쁜 인테리어를 유지할 수 있도록 하는 것입니다. 따라서 애완동물 관련 제품과 인테리어 아이템을 함께 판매하는 펫테리어 전문 매장도 있습니다.',
#  '도배지를 너무 작게 자르면, 도배작업 시 시간이 더 걸리며, 도배지 사용량이 많아져 비용이 증가합니다. 또한, 도배 시 이음새 부분이 많아져 접착제 사용량이 늘어나고, 도배 작업이 복잡해집니다. 높은 습도로 인해 도배지 패턴이 이어지지 않는 것은, 습기가 많은 환경에서는 도배지의 이음새 부분이 물리적으로 밀착되지 않아 붙인 도배지가 들뜨거나 떨어지는 현상이 발생할 수 있기 때문입니다. 따라서, 도배 작업을 할 때는 습기 관리를 철저히 해야 합니다.',
#  '알러지가 있는 사람들이 매끄럽고 평평한 벽지를 선택하는 이유는 두 가지가 있습니다. 첫째, 벽지 표면에 먼지나 진드기 등의 알러지 유발 물질이 적게 붙어 있기 때문입니다. 둘째, 벽면의 요철이 적어 공기 중에 떠다니는 먼지양이 적기 때문입니다. 이는 평평한 벽면이 더 깨끗해 보인다는 것뿐만 아니라 실제로 더 깨끗하기 때문입니다. 따라서, 알러지가 있는 사람들은 이러한 이유로 매끄럽고 평평한 벽지를 선택하게 됩니다.',
#  '아파트 도배 평수를 계산하는 방법은 다음과 같습니다. 먼저, 아파트의 면적을 구한 후 벽체의 면적을 제외한 나머지 바닥 면적에 1.2를 곱하면 됩니다. 예를 들어, 아파트 면적이 85m2이고 벽체의 면적이 20m2이면 바닥 면적(85 - 20 = 65)에 1.2를 곱하여 78m2가 됩니다. 이 때, 벽체 면적은 거실이나 방 등 모든 면적을 포함합니다.\n\n소화기 설치 시에는 몇 가지 주의사항이 있습니다. 먼저, 소화기는 화재 발생 위험이 높은 장소에 설치해야 합니다. 또한, 소화기의 위치는 화재 발생 시 쉽게 접근할 수 있는 곳에 설치해야 합니다. 그리고, 소화기는 정기적으로 점검하고 보수해야 하며, 사용하기 전에 사용 방법을 숙지해야 합니다. 마지막으로, 소화기를 사용할 때는 안전을 최우선으로 생각하며, 소화기에 표시된 적절한 방법으로 사용해야 합니다.',
#  '마감재의 하자를 판단하기 위해서는 시방서나 규정에 따라 판단해야 합니다. 일반적으로는 마감재의 표면 상태, 이음매, 치수, 품질 등을 확인합니다. 또한, 마감재의 종류에 따라 다른 검사 방법이 적용될 수 있습니다. 예를 들어, 타일은 면과 면의 이음매를 확인하고, 목재는 결점이나 균일성 등을 확인합니다. 라돈을 측정하는 데는 방사능 측정기를 사용하며, 가장 적합한 지점은 실내 공기질을 측정하는 것이 좋습니다. 측정기의 종류에 따라 측정 방법이 달라질 수 있으므로, 측정 전에 측정 방법에 대한 충분한 이해가 필요합니다.',
#  '이산화탄소 소화기는 가스 상태의 이산화탄소를 이용해 화재를 진압하는 소화기입니다. 이산화탄소는 공기 중에서 산소의 역할을 하므로, 이산화탄소를 분사하면 불이 꺼집니다. 이산화탄소 소화기는 유류나 전기 등의 화재 진압에 적합하며, 인체에는 무해합니다. 분말 소화기는 분말 상태의 약제를 분사하여 화재를 진압하는 소화기입니다. 주로 유류나 전기 등의 화재 진압에 사용되며, 인체에는 해로울 수 있습니다. 분말 소화기는 약제의 종류에 따라 다양한 용도로 사용될 수 있습니다.',
#  '면진장치는 지진이나 진동에 대한 충격을 완화시켜 주는 장치입니다. 면진장치는 건축물의 기둥이나 벽체에 부착되어, 지진이나 진동이 발생할 때 면진장치 내부의 유체(공기 또는 오일)가 움직여서 충격을 흡수합니다. 면진구조는 면진장치를 사용하여 지진이나 진동에 강한 구조를 말합니다. 면진구조는 주로 지진이 자주 일어나는 일본이나 미국에서 많이 사용되며, 건축물의 내구성과 안전성을 높이기 위해 적용됩니다.',
#  '외단열재는 건물 외부에 위치하여 건물의 단열 기능을 수행하는 자재입니다. 이로 인해 실내 온도를 일정하게 유지해주며, 난방 비용을 절감할 수 있습니다. 또한, 외단열재는 건물 외관 디자인의 자유도 증가와 구조용 자재의 보호 기능 등 다양한 장점을 가지고 있습니다. 이를 시공할 때는 적절한 두께와 재질을 선택하고, 방수층과 결로 방지층 등을 고려해야 합니다.',
#  '외단열은 건물 외부에 단열재를 설치하는 방법이고, 내단열은 건물 내부에 단열재를 설치하는 방법입니다. 외단열은 단열재가 건물 외면을 완전히 둘러싸기 때문에 단열재와 실내 공기의 온도차가 작아 단열 효과가 높습니다. 또한, 외단열은 단열재의 두께를 더 늘려도 추가 비용이 많이 들지 않아 경제적입니다. 반면, 내단열은 벽체 내부에 단열재를 설치하기 때문에 단열재와 실내 공기의 온도차가 크고, 단열재의 두께를 늘리면 추가 비용이 많이 들어갑니다. 따라서, 내단열은 외단열보다 단열 효과가 떨어질 수 있습니다.',
#  '바닥재의 종류는 매우 다양하지만, 현재 가장 인기 있는 바닥재는 강마루입니다. 강마루는 합판 위에 강화마루를 시공한 것으로, 시공이 간편하고 디자인 선택폭이 넓으며, 가격대비 성능이 좋아서 많은 사람들이 선택합니다. 가장 비싼 바닥재는 대개 원목마루로, 원목을 가공하여 만든 마루바닥재입니다. 하지만 최근에는 강마루가 그 자리를 대신하고 있습니다.',
#  '포세린 타일은 도자기 타일로, 일반 타일에 비해 물 흡수율이 낮고 변색이 잘 안되며, 스크래치에 강하고 내구성이 뛰어납니다. 하지만 가격이 비싸며, 깨지면 재사용이 불가능하다는 단점이 있습니다. 또한, 포세린 타일은 물 흡수율이 매우 낮기 때문에 시공할 때에는 물빠짐 공사를 철저히 해주어야 합니다.',
#  '중목구조는 구조재로 목재를 사용하는 건축 방식으로, 벽식 구조와 기둥식 구조 두 가지가 있습니다. 벽식 구조는 벽체가 하중에 저항하는 구조이며, 기둥식 구조는 기둥이 하중을 지탱하는 구조입니다. 목재의 종류로는 소나무, 느티나무, 오동나무 등이 사용되며, 목재의 방부 처리와 접합 부분의 철물 부착 등을 통해 구조적 안정성을 확보합니다. \n\n철근콘크리트 구조는 철근과 콘크리트로 구성된 구조 방식으로, 철근이 인장력(늘어나는 힘)을 견디고 콘크리트가 압축력을 견디는 구조입니다. 철근콘크리트 구조는 벽체와 슬라브 등에 철근배근을 하고 콘크리트를 타설하여 구조체를 만듭니다. 이 구조는 내화성능이 우수하고 소음을 흡수하며, 내부 마감재의 선택 폭이 넓은 장점이 있습니다.',
#  '도배지의 양은 도배할 면적에 따라 다르지만, 일반적으로 한 장으로는 부족합니다. 보통은 두 장 이상을 사용하며, 창문이나 문 등 특수한 부분은 추가로 더 필요합니다. 벽에 구멍을 막는 가장 효과적인 방법은 스프레이 본드를 사용하는 것입니다. 이 제품은 접착력이 뛰어나며, 얇게 바르면 깔끔하게 마감됩니다. 또한, 스프레이 본드는 냄새가 강하므로 실내에서 작업할 때는 환기하는 것이 좋습니다.',
#  '경질우레탄폼 보온판은 외단열재로서 단열성능이 뛰어나며, 공사기간 단축과 경제적인 효과를 가지고 있습니다. 또한, 이중벽체구조로 되어있어 차음성능도 우수합니다. 이러한 장점으로 인해 결로와 곰팡이 발생을 줄일 수 있습니다. 경질우레탄폼 보온판은 외부환경으로부터의 열전달을 최소화하여 내부의 온도를 유지시키며, 습기제어 기능을 가지고 있어 내부의 습기를 조절하여 결로 발생을 예방합니다. 또한, 곰팡이가 생길 수 있는 환경을 예방하기 위해 곰팡이제어제를 함께 사용하여 곰팡이 발생을 방지합니다.',
#  '질석벽지는 습기 조절 기능이 뛰어나기 때문에 아트월이나 현관 입구와 같은 습기가 많은 공간에서 많이 사용됩니다. 또한, 질석벽지는 열과 소음을 차단하는 효과도 있기 때문에 보온과 방음에도 효과적입니다. 이러한 특징 때문에 질석벽지는 인테리어 시장에서 인기가 높습니다.',
#  '건물 옥상에 시트 방수공사를 하면, 여름철에는 옥상 표면의 온도가 높아져 건물 내부의 온도가 상승하는 것을 방지하고, 겨울철에는 옥상 표면의 온도가 낮아지는 것을 막아 난방에너지를 절약할 수 있습니다. 또한, 비가 들어오지 않도록 방수 기능을 제공하여 누수를 예방하고, 건물 내부를 보호합니다. 이러한 기능으로 인해 건물 전체의 에너지 절감 효과를 얻을 수 있습니다.',
#  '내진설계에서는 건축물의 안정성을 높이기 위해 여러 가지 방법이 사용됩니다. 일반적으로는 구조체의 강도와 크기를 늘리고, 지진하중에 대한 저항력을 높이는 것이 중요합니다. 또한, 지진 시 구조체의 변형을 최소화하기 위해 적절한 재료 선택과 구조체 설계가 필요합니다. 내진구조란 지진에 견딜 수 있는 구조물을 말하며, 내진설계에 따라 안정성이 높아진 구조물을 의미합니다.',
#  '분말 소화기를 사용할 때는 먼저 안전핀을 뽑은 후, 빨간색 손잡이를 잡고 노즐을 불이 난 곳으로 향하게 합니다. 이때, 분말이 완전히 분사될 때까지 손잡이를 놓지 않도록 합니다. 또한, 분말 소화기는 물로 씻어내면 안 되며, 분사 후에는 밀폐된 공간에서 사용한 경우 먼지가 많이 쌓여있을 수 있으므로 청소를 해주시는 것이 좋습니다. 아파트 도배 평수를 계산할 때는 도배할 면적에 창문과 문 등의 면적을 제외하고, 벽면의 면적을 계산하여 도배 시트의 크기를 결정하면 됩니다.',
#  '압출법 보온판은 다른 보온판에 비해 두 가지 큰 장점이 있습니다. 첫째, 압출법 보온판은 단열 성능이 우수합니다. 이는 압출법으로 만들어진 보온판이 미세한 구멍이 있는 고밀도 폴리스티렌 폼으로 이루어져 있기 때문입니다. 이 구조는 공기의 흐름을 막아 열 전달을 효과적으로 방지합니다. 둘째, 압출법 보온판은 설치 및 유지보수가 용이합니다. 이는 압출법 보온판이 판 형태로 만들어져 있어 시공이 간편하고, 표면이 평평해 마감 작업도 간단하기 때문입니다. 또한, 압출법 보온판은 내구성이 뛰어나며, 수명이 길어 오랫동안 보온 효과를 유지할 수 있습니다.',
#  '수성 벽체용 탄성 방수 도료는 평지붕의 누수 문제를 방지하는 데 효과적입니다. 이 제품은 높은 탄성과 내구성을 가지고 있어 지붕의 변형과 온도 변화에도 균열이 생기지 않고 막을 유지할 수 있습니다. 또한, 이 제품은 친환경적이어서 환경 오염의 우려가 적습니다. 이러한 장점 때문에 수성 벽체용 탄성 방수 도료는 평지붕의 누수 문제를 방지하는 데 많이 사용되고 있습니다.',
#  '석고수정은 치아의 치근이 흡수되는 상태에서 치아우식증이나 치근염 등의 질환으로 인해 치아가 손상된 경우에 사용됩니다. 이는 치아를 대신할 수 있는 보철물이 없거나, 치아를 살릴 수 있는 가능성이 있는 경우에 사용됩니다. 석고수정의 원리는 금속틀 위에 세라믹이나 레진 등의 도자기를 입히는 것으로, 자연치아와 비슷한 색상과 모양을 만들어줍니다. 석고수정을 하는 과정은 치아의 모형을 본뜨기, 틀 제작, 도자기 입히기, 불어 굳히기 등이 있습니다. 석고수정은 자연치아와 거의 동일한 기능을 하며, 음식물도 잘 통과합니다. 하지만, 틀이 금속이기 때문에 음식을 먹을 때 이물질감이 있을 수 있으며, 도자기 자체가 깨질 수 있는 단점이 있습니다.',
#  '카페트의 경우, 사용 방법과 관리 상태에 따라 다르지만 일반적으로 5년에서 10년 정도 사용할 수 있습니다. 오리지널징크는 지붕재로 사용되며, 고풍스러운 디자인과 내구성, 방음성, 단열성 등의 장점이 있습니다. 또한, 징크는 유지 보수가 용이하며, 수명이 50년 이상으로 알려져 있습니다.']

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
import numpy as np
from sentence_transformers import SentenceTransformer # SentenceTransformer Version 2.2.2

# Embedding Vector 추출에 활용할 모델(distiluse-base-multilingual-cased-v1) 불러오기
embed_model = SentenceTransformer('distiluse-base-multilingual-cased-v1')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/539M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/452 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.58M [00:00<?, ?B/s]

# %%
responses=answer

# %%
embed_model.encode(responses[0])
# Out:
# array([ 0.04215666,  0.11045343,  0.04767886, -0.02392781,  0.06406538,
#        -0.02818174,  0.00837079,  0.00909889,  0.0279477 ,  0.03389404,
#        -0.05770229, -0.03476072,  0.02434528, -0.10141925, -0.02403446,
#        -0.0209629 , -0.03427393, -0.04615813, -0.05213957,  0.07176317,
#        -0.01515151,  0.00805302, -0.02522971,  0.01409446,  0.01426401,
#        -0.01419866, -0.010156  ,  0.01214009, -0.07226357,  0.00937402,
#         0.0254471 , -0.01642957, -0.0054548 , -0.03169987,  0.00507798,
#        -0.03502542,  0.04525568,  0.04163579,  0.03563558,  0.0545174 ,
#        -0.02328358,  0.01358621, -0.0219509 , -0.00858987,  0.03821108,
#        -0.03109843, -0.07930955, -0.00744583, -0.00142335, -0.01045187,
#         0.03625108, -0.0213419 ,  0.05910727, -0.00422967,  0.04962244,
#        -0.03068347, -0.03464219,  0.00957576, -0.04380086,  0.01181264,
#        -0.02090469,  0.01569634,  0.03875672, -0.01699902, -0.0445503 ,
#        -0.00558022, -0.04296635,  0.03800188, -0.00407329,  0.01920148,
#        -0.03783851, -0.02653279,  0.04601921, -0.03755664, -0.0247949 ,
#        -0.00525727,  0.02455469, -0.02610648, -0.04269036,  0.00251981,
#        -0.01032009, -0.06406786,  0.065472  ,  0.03775227,  0.04623216,
#        -0.00526836, -0.00577405, -0.03810908,  0.02176419, -0.02286095,
#         0.03443135, -0.01237835,  0.05468655,  0.04160254,  0.01343875,
#         0.01283141,  0.05741571, -0.07947381,  0.00369373, -0.04212025,
#         0.05016428, -0.01975451,  0.0121813 ,  0.08145066,  0.00275688,
#        -0.02691603,  0.02813337,  0.05246499, -0.0317805 ,  0.06817093,
#         0.01776938, -0.04386722, -0.07621213, -0.01389885,  0.01766991,
#        -0.04160948,  0.00650524,  0.02447778,  0.01023484,  0.00122913,
#         0.05544642,  0.02611305,  0.02503898, -0.01607277, -0.0039474 ,
#         0.00109425, -0.00070391, -0.00786985, -0.0163426 , -0.01207784,
#         0.04485781, -0.02955952, -0.00773678, -0.01710325,  0.05351058,
#        -0.01679175,  0.02115305, -0.00164143,  0.0134118 , -0.01985693,
#        -0.0627961 , -0.07781014, -0.02202016,  0.05099653, -0.01155654,
#         0.01282915,  0.02444482,  0.0044769 , -0.0620026 ,  0.00074036,
#        -0.02694271,  0.05165129, -0.002585  , -0.02231252,  0.02712951,
#        -0.02775561,  0.02191883, -0.04271736,  0.0622813 ,  0.03691322,
#         0.02796282,  0.02878101,  0.01231478, -0.0388188 , -0.01492976,
#         0.02201794,  0.02067428,  0.05690791,  0.02609298,  0.03504166,
#        -0.00503871,  0.00505864,  0.05940073, -0.0140689 , -0.04573177,
#         0.01818947,  0.01306511, -0.04569258,  0.01738055, -0.04095142,
#         0.01404499, -0.03623757,  0.00252527,  0.07853693, -0.04972111,
#         0.0368644 , -0.01298669,  0.00997608, -0.01487086, -0.08857289,
#        -0.10010309,  0.003775  , -0.02985692,  0.00352526, -0.01835158,
#        -0.01087913,  0.00420493, -0.02664552,  0.03469598,  0.00097737,
#        -0.03050827,  0.06243646,  0.01346776, -0.02744288, -0.02801758,
#         0.02610712,  0.00139907, -0.04221499, -0.03843398,  0.02964213,
#        -0.01227183,  0.00619323, -0.0014124 ,  0.05163094, -0.01155673,
#         0.02014355, -0.01252126, -0.00167577,  0.00529492, -0.07799473,
#         0.00772825, -0.01117943,  0.03543215,  0.00534511, -0.03151271,
#        -0.02174337, -0.02824939, -0.05531514,  0.03361244,  0.04783192,
#         0.02277953, -0.01124882, -0.02701117, -0.01295387,  0.01401409,
#         0.08031704, -0.00877674,  0.03647036, -0.00016281,  0.02890251,
#        -0.04414992,  0.01560186,  0.02715361, -0.02840835,  0.00759201,
#        -0.00704339,  0.01943524,  0.02809999, -0.06254891, -0.01866144,
#         0.01980794,  0.02280485,  0.002714  , -0.00767925, -0.00598806,
#        -0.01811561,  0.04522698, -0.0021365 ,  0.04261894,  0.01905539,
#        -0.02681536,  0.03515938, -0.01622677,  0.0018369 ,  0.00082989,
#         0.00583224,  0.05789658, -0.02681733, -0.01231183, -0.00670477,
#        -0.02600701,  0.02510645,  0.00490171, -0.00283735,  0.01231553,
#        -0.00529455,  0.0889915 ,  0.02162255,  0.03637179, -0.04886266,
#        -0.02444275,  0.0504957 , -0.02015812,  0.0242846 ,  0.02622337,
#        -0.00957091, -0.00056204,  0.0295199 ,  0.01363782,  0.04586751,
#        -0.00155409, -0.02618456,  0.07369351,  0.03631039, -0.02799168,
#         0.04452178, -0.01180344, -0.02022795,  0.00306968, -0.04599234,
#        -0.0165288 , -0.05585829,  0.06041982,  0.03253153, -0.03722044,
#        -0.00094009,  0.04068031, -0.01739805, -0.01544503, -0.03474762,
#        -0.01202323, -0.03320694,  0.02383957, -0.00485014, -0.06429785,
#        -0.02096515, -0.05106114,  0.05092696, -0.00529535, -0.06107171,
#        -0.01381519,  0.02959654, -0.06339762, -0.02437045, -0.06383019,
#         0.02848399, -0.01741306,  0.02565889, -0.04014634,  0.01263759,
#        -0.01043298,  0.02804506, -0.03513226, -0.05545653, -0.00186452,
#         0.00489358, -0.02582408, -0.00245022,  0.02401008,  0.01062886,
#        -0.04539012,  0.02565061,  0.0227717 ,  0.04143865, -0.01501823,
#         0.01099147,  0.05130261,  0.0793189 , -0.04547019, -0.02971752,
#        -0.01678995, -0.03000954, -0.0506116 , -0.05672248,  0.01275696,
#        -0.04193956,  0.00050306, -0.00791724,  0.04753408,  0.00766181,
#         0.01237783, -0.01273733,  0.00053454, -0.06436681, -0.02613389,
#         0.02798344,  0.04273681,  0.03712879, -0.01891338, -0.01118748,
#        -0.03859116, -0.05961321, -0.02643147,  0.01277318, -0.03526643,
#         0.05664637, -0.03771356, -0.00683265,  0.04031854,  0.0394485 ,
#         0.01605961, -0.01515746,  0.07771581,  0.00092544, -0.02191169,
#        -0.00411984,  0.00259367, -0.03835825,  0.00839078,  0.01969385,
#         0.03271121,  0.06131919,  0.03920749,  0.04296525, -0.00441089,
#        -0.00204977,  0.04935196,  0.03640673, -0.01214501, -0.05345562,
#         0.05665253,  0.00811333, -0.00243412,  0.01329313, -0.01221371,
#        -0.03845451, -0.03261595,  0.03215611, -0.01567966,  0.07945446,
#        -0.04705938,  0.00740292,  0.00426092,  0.00747829,  0.00198151,
#         0.02022784,  0.07263242, -0.02813043,  0.05463928,  0.0048174 ,
#        -0.00077587,  0.0362854 ,  0.01113465, -0.04087495,  0.08410235,
#         0.07386332,  0.062263  , -0.04976159, -0.01224452,  0.03947675,
#         0.06130629, -0.01851736,  0.00079142,  0.00689936,  0.016381  ,
#         0.10051276,  0.04866244,  0.04432422, -0.01111559,  0.05523686,
#         0.01371129, -0.06708772, -0.00857984,  0.01352295, -0.02138013,
#         0.08611432, -0.01779731, -0.01567695,  0.00499814,  0.0057097 ,
#         0.02588136,  0.06440958,  0.03087608, -0.00523616, -0.02437364,
#        -0.06343251, -0.05542204,  0.00452863,  0.00490737,  0.01885448,
#         0.00468024,  0.02365811, -0.0482388 ,  0.04768948, -0.01111402,
#         0.02652949,  0.01979155,  0.00186447,  0.0414725 , -0.07391175,
#        -0.04165577,  0.00408685,  0.02363289, -0.0152537 , -0.02691399,
#         0.06113422, -0.06778772, -0.03983818,  0.02394505, -0.06410271,
#         0.04426259, -0.01611285, -0.01375807, -0.04381866,  0.02212347,
#        -0.0408072 ,  0.0294537 , -0.00058124, -0.08085869, -0.0127466 ,
#        -0.00283384,  0.01893784, -0.02096851, -0.04307144, -0.01729989,
#        -0.05148197, -0.01507023,  0.02664383, -0.02017713, -0.07609183,
#         0.01387414, -0.00888485, -0.02437109, -0.04918345,  0.04651055,
#        -0.04916474, -0.00773369,  0.02914201,  0.02030549, -0.00071836,
#        -0.00997813,  0.04024429], dtype=float32)

# %%
id = submission.id


submission.drop(['id'],axis = 1, inplace = True)

# %%
embed_model.encode(responses[0]).tolist()
# Out:
# [0.042156659066677094,
#  0.11045343428850174,
#  0.047678858041763306,
#  -0.023927807807922363,
#  0.06406538188457489,
#  -0.028181742876768112,
#  0.008370790630578995,
#  0.009098888374865055,
#  0.027947697788476944,
#  0.033894043415784836,
#  -0.057702288031578064,
#  -0.034760721027851105,
#  0.024345284327864647,
#  -0.10141924768686295,
#  -0.02403445914387703,
#  -0.020962903276085854,
#  -0.03427393361926079,
#  -0.04615813493728638,
#  -0.05213957279920578,
#  0.07176316529512405,
#  -0.015151510946452618,
#  0.008053022436797619,
#  -0.025229712948203087,
#  0.0140944579616189,
#  0.014264007098972797,
#  -0.014198661781847477,
#  -0.01015599723905325,
#  0.012140091508626938,
#  -0.07226356863975525,
#  0.009374015033245087,
#  0.025447100400924683,
#  -0.016429569572210312,
#  -0.0054548014886677265,
#  -0.03169986978173256,
#  0.005077981855720282,
#  -0.03502541780471802,
#  0.04525567963719368,
#  0.04163578525185585,
#  0.0356355756521225,
#  0.05451739579439163,
#  -0.023283576592803,
#  0.01358620822429657,
#  -0.021950898692011833,
#  -0.008589866571128368,
#  0.03821107745170593,
#  -0.031098434701561928,
#  -0.07930955290794373,
#  -0.007445826660841703,
#  -0.0014233514666557312,
#  -0.01045187283307314,
#  0.03625107556581497,
#  -0.021341897547245026,
#  0.05910727381706238,
#  -0.004229669459164143,
#  0.04962243512272835,
#  -0.030683472752571106,
#  -0.03464219346642494,
#  0.009575756266713142,
#  -0.04380085691809654,
#  0.011812643148005009,
#  -0.020904691889882088,
#  0.015696344897150993,
#  0.03875672072172165,
#  -0.01699901558458805,
#  -0.044550299644470215,
#  -0.005580217577517033,
#  -0.04296634718775749,
#  0.038001883774995804,
#  -0.004073292016983032,
#  0.019201483577489853,
#  -0.03783851116895676,
#  -0.026532787829637527,
#  0.046019211411476135,
#  -0.037556637078523636,
#  -0.024794895201921463,
#  -0.005257272627204657,
#  0.024554692208766937,
#  -0.02610648423433304,
#  -0.04269036278128624,
#  0.002519813599064946,
#  -0.010320086032152176,
#  -0.06406786292791367,
#  0.06547199934720993,
#  0.03775227069854736,
#  0.046232160180807114,
#  -0.0052683595567941666,
#  -0.005774048622697592,
#  -0.038109079003334045,
#  0.02176418900489807,
#  -0.022860951721668243,
#  0.03443135321140289,
#  -0.01237835455685854,
#  0.054686546325683594,
#  0.041602540761232376,
#  0.013438748195767403,
#  0.012831408530473709,
#  0.05741570517420769,
#  -0.07947380840778351,
#  0.003693734295666218,
#  -0.04212024807929993,
#  0.05016428232192993,
#  -0.01975451409816742,
#  0.01218129601329565,
#  0.08145065605640411,
#  0.0027568761724978685,
#  -0.026916025206446648,
#  0.028133369982242584,
#  0.05246499180793762,
#  -0.03178049996495247,
#  0.068170927464962,
#  0.017769375815987587,
#  -0.04386721923947334,
#  -0.07621213048696518,
#  -0.013898851349949837,
#  0.017669910565018654,
#  -0.04160947725176811,
#  0.006505243014544249,
#  0.024477776139974594,
#  0.010234839282929897,
#  0.0012291270541027188,
#  0.05544641986489296,
#  0.02611304633319378,
#  0.025038979947566986,
#  -0.016072766855359077,
#  -0.0039474028162658215,
#  0.001094253733754158,
#  -0.0007039058255031705,
#  -0.00786985456943512,
#  -0.016342604532837868,
#  -0.012077839113771915,
#  0.04485780745744705,
#  -0.02955951914191246,
#  -0.007736779749393463,
#  -0.017103252932429314,
#  0.05351058021187782,
#  -0.016791746020317078,
#  0.021153045818209648,
#  -0.001641428447328508,
#  0.013411798514425755,
#  -0.019856927916407585,
#  -0.06279610097408295,
#  -0.077810138463974,
#  -0.022020163014531136,
#  0.050996534526348114,
#  -0.011556543409824371,
#  0.012829146347939968,
#  0.02444482408463955,
#  0.004476900678128004,
#  -0.062002602964639664,
#  0.0007403616909869015,
#  -0.02694270946085453,
#  0.05165128782391548,
#  -0.0025850047823041677,
#  -0.022312520071864128,
#  0.027129512280225754,
#  -0.027755606919527054,
#  0.021918827667832375,
#  -0.042717356234788895,
#  0.062281303107738495,
#  0.036913223564624786,
#  0.02796281687915325,
#  0.02878100983798504,
#  0.012314781546592712,
#  -0.03881879523396492,
#  -0.014929763041436672,
#  0.0220179446041584,
#  0.02067427895963192,
#  0.056907910853624344,
#  0.026092978194355965,
#  0.03504166379570961,
#  -0.005038710311055183,
#  0.005058636423200369,
#  0.05940072983503342,
#  -0.0140689043328166,
#  -0.045731768012046814,
#  0.01818947307765484,
#  0.013065108098089695,
#  -0.04569258168339729,
#  0.017380550503730774,
#  -0.04095141589641571,
#  0.01404498890042305,
#  -0.03623756766319275,
#  0.002525270450860262,
#  0.07853692770004272,
#  -0.04972110688686371,
#  0.036864396184682846,
#  -0.012986685149371624,
#  0.009976081550121307,
#  -0.014870863407850266,
#  -0.08857288956642151,
#  -0.10010308772325516,
#  0.0037749994080513716,
#  -0.02985691837966442,
#  0.003525262465700507,
#  -0.018351582810282707,
#  -0.010879132896661758,
#  0.004204927012324333,
#  -0.026645520702004433,
#  0.03469597548246384,
#  0.000977373099885881,
#  -0.030508270487189293,
#  0.062436461448669434,
#  0.013467760756611824,
#  -0.027442878112196922,
#  -0.028017576783895493,
#  0.026107124984264374,
#  0.0013990706065669656,
#  -0.04221499338746071,
#  -0.0384339764714241,
#  0.029642129316926003,
#  -0.01227183360606432,
#  0.00619322806596756,
#  -0.0014124014414846897,
#  0.05163094028830528,
#  -0.011556731536984444,
#  0.020143548026680946,
#  -0.012521262280642986,
#  -0.0016757695702835917,
#  0.005294924136251211,
#  -0.07799472659826279,
#  0.007728248834609985,
#  -0.011179432272911072,
#  0.03543214872479439,
#  0.005345107521861792,
#  -0.03151271119713783,
#  -0.021743372082710266,
#  -0.028249390423297882,
#  -0.05531514063477516,
#  0.0336124412715435,
#  0.04783191904425621,
#  0.022779526188969612,
#  -0.011248823255300522,
#  -0.027011172845959663,
#  -0.012953869067132473,
#  0.014014090411365032,
#  0.08031704276800156,
#  -0.008776738308370113,
#  0.036470361053943634,
#  -0.00016280863201245666,
#  0.028902510181069374,
#  -0.04414992406964302,
#  0.01560185942798853,
#  0.027153614908456802,
#  -0.0284083504229784,
#  0.007592007052153349,
#  -0.007043386343866587,
#  0.01943523809313774,
#  0.028099991381168365,
#  -0.0625489130616188,
#  -0.018661437556147575,
#  0.019807938486337662,
#  0.022804850712418556,
#  0.0027139957528561354,
#  -0.007679247297346592,
#  -0.005988061428070068,
#  -0.018115606158971786,
#  0.04522697627544403,
#  -0.002136502880603075,
#  0.04261893779039383,
#  0.01905539259314537,
#  -0.02681535854935646,
#  0.03515937924385071,
#  -0.016226772218942642,
#  0.0018369009485468268,
#  0.000829888682346791,
#  0.005832236725836992,
#  0.05789657682180405,
#  -0.026817334815859795,
#  -0.012311832047998905,
#  -0.006704768165946007,
#  -0.026007013395428658,
#  0.025106454268097878,
#  0.004901713225990534,
#  -0.0028373526874929667,
#  0.012315533123910427,
#  -0.0052945492789149284,
#  0.08899150043725967,
#  0.02162254974246025,
#  0.03637179359793663,
#  -0.04886265844106674,
#  -0.024442754685878754,
#  0.0504956990480423,
#  -0.02015812136232853,
#  0.024284603074193,
#  0.02622336894273758,
#  -0.009570909664034843,
#  -0.0005620433366857469,
#  0.02951989695429802,
#  0.013637823052704334,
#  0.04586751013994217,
#  -0.0015540897147729993,
#  -0.0261845625936985,
#  0.07369350641965866,
#  0.036310385912656784,
#  -0.027991676703095436,
#  0.04452178254723549,
#  -0.01180343609303236,
#  -0.0202279482036829,
#  0.003069678321480751,
#  -0.04599233716726303,
#  -0.016528796404600143,
#  -0.05585829168558121,
#  0.06041981652379036,
#  0.032531529664993286,
#  -0.037220440804958344,
#  -0.0009400876588188112,
#  0.040680307894945145,
#  -0.0173980463296175,
#  -0.015445029363036156,
#  -0.034747619181871414,
#  -0.012023232877254486,
#  -0.033206939697265625,
#  0.023839574307203293,
#  -0.004850138444453478,
#  -0.06429785490036011,
#  -0.020965149626135826,
#  -0.05106113851070404,
#  0.05092696473002434,
#  -0.005295353941619396,
#  -0.06107170879840851,
#  -0.013815192505717278,
#  0.029596535488963127,
#  -0.063397616147995,
#  -0.024370454251766205,
#  -0.0638301894068718,
#  0.028483986854553223,
#  -0.017413057386875153,
#  0.02565888874232769,
#  -0.04014633968472481,
#  0.012637586332857609,
#  -0.010432980954647064,
#  0.028045063838362694,
#  -0.03513225540518761,
#  -0.055456534028053284,
#  -0.0018645200179889798,
#  0.004893580451607704,
#  -0.02582407556474209,
#  -0.002450218191370368,
#  0.024010082706809044,
#  0.010628855787217617,
#  -0.04539012163877487,
#  0.02565060928463936,
#  0.022771699354052544,
#  0.04143865033984184,
#  -0.015018233098089695,
#  0.01099147368222475,
#  0.05130261182785034,
#  0.07931889593601227,
#  -0.045470185577869415,
#  -0.029717521741986275,
#  -0.01678994856774807,
#  -0.030009543523192406,
#  -0.05061160400509834,
#  -0.056722477078437805,
#  0.01275696326047182,
#  -0.04193956032395363,
#  0.0005030638421885669,
#  -0.007917243055999279,
#  0.04753408208489418,
#  0.007661808282136917,
#  0.01237783394753933,
#  -0.012737325392663479,
#  0.0005345423123799264,
#  -0.06436681002378464,
#  -0.026133889332413673,
#  0.027983443811535835,
#  0.04273681342601776,
#  0.037128791213035583,
#  -0.018913375213742256,
#  -0.011187483556568623,
#  -0.038591161370277405,
#  -0.05961321294307709,
#  -0.026431472972035408,
#  0.012773184105753899,
#  -0.03526642546057701,
#  0.05664637312293053,
#  -0.037713561207056046,
#  -0.006832651328295469,
#  0.04031853750348091,
#  0.03944849967956543,
#  0.01605961099267006,
#  -0.015157457441091537,
#  0.07771581411361694,
#  0.0009254409815184772,
#  -0.02191169187426567,
#  -0.0041198390536010265,
#  0.0025936674792319536,
#  -0.03835824504494667,
#  0.008390775881707668,
#  0.019693845883011818,
#  0.0327112078666687,
#  0.06131919100880623,
#  0.03920748829841614,
#  0.042965251952409744,
#  -0.004410889931023121,
#  -0.0020497674122452736,
#  0.04935196042060852,
#  0.03640672564506531,
#  -0.01214501354843378,
#  -0.05345562472939491,
#  0.056652527302503586,
#  0.008113328367471695,
#  -0.0024341244716197252,
#  0.013293133117258549,
#  -0.012213710695505142,
#  -0.03845451399683952,
#  -0.03261594846844673,
#  0.03215611353516579,
#  -0.015679659321904182,
#  0.0794544592499733,
#  -0.047059375792741776,
#  0.007402915507555008,
#  0.00426091905683279,
#  0.007478285115212202,
#  0.0019815119449049234,
#  0.020227836444973946,
#  0.07263242453336716,
#  -0.02813042514026165,
#  0.05463928356766701,
#  0.0048174019902944565,
#  -0.0007758692954666913,
#  0.0362853966653347,
#  0.011134645901620388,
#  -0.04087495431303978,
#  0.08410234749317169,
#  0.07386332005262375,
#  0.06226300075650215,
#  -0.049761585891246796,
#  -0.012244517914950848,
#  0.039476752281188965,
#  0.06130628660321236,
#  -0.01851736009120941,
#  0.0007914163288660347,
#  0.006899362895637751,
#  0.016380995512008667,
#  0.10051275789737701,
#  0.04866243526339531,
#  0.04432421550154686,
#  -0.01111559383571148,
#  0.05523685738444328,
#  0.013711289502680302,
#  -0.06708771735429764,
#  -0.00857983622699976,
#  0.013522946275770664,
#  -0.02138013206422329,
#  0.0861143246293068,
#  -0.017797309905290604,
#  -0.0156769510358572,
#  0.004998139571398497,
#  0.005709697026759386,
#  0.025881357491016388,
#  0.06440958380699158,
#  0.030876077711582184,
#  -0.00523616187274456,
#  -0.024373643100261688,
#  -0.06343250721693039,
#  -0.055422041565179825,
#  0.0045286258682608604,
#  0.004907374270260334,
#  0.018854478374123573,
#  0.004680239595472813,
#  0.023658111691474915,
#  -0.04823880270123482,
#  0.04768948256969452,
#  -0.011114023625850677,
#  0.02652948908507824,
#  0.01979154907166958,
#  0.0018644692609086633,
#  0.041472502052783966,
#  -0.07391174882650375,
#  -0.0416557714343071,
#  0.004086846951395273,
#  0.023632893338799477,
#  -0.015253698453307152,
#  -0.026913989335298538,
#  0.0611342191696167,
#  -0.06778772175312042,
#  -0.03983818367123604,
#  0.023945050314068794,
#  -0.06410270929336548,
#  0.0442625917494297,
#  -0.016112850978970528,
#  -0.013758070766925812,
#  -0.04381865635514259,
#  0.022123470902442932,
#  -0.040807198733091354,
#  0.029453696683049202,
#  -0.0005812392919324338,
#  -0.08085868507623672,
#  -0.0127465995028615,
#  -0.0028338422998785973,
#  0.018937844783067703,
#  -0.02096850611269474,
#  -0.0430714376270771,
#  -0.017299888655543327,
#  -0.05148197337985039,
#  -0.015070229768753052,
#  0.02664383128285408,
#  -0.02017712965607643,
#  -0.07609183341264725,
#  0.01387413963675499,
#  -0.00888485461473465,
#  -0.024371091276407242,
#  -0.049183446913957596,
#  0.046510547399520874,
#  -0.04916473850607872,
#  -0.007733689155429602,
#  0.02914201095700264,
#  0.020305488258600235,
#  -0.0007183643174357712,
#  -0.00997813418507576,
#  0.04024428874254227]

# %%
for i in range(len(submission)):
    # print(i)
    try:
        submission.loc[i] = embed_model.encode(responses[i]).tolist()
    except:
        print(i)

# %%
total_submission = pd.DataFrame({'id': id})
total_submission
# Out:
#            id
# 0    TEST_000
# 1    TEST_001
# 2    TEST_002
# 3    TEST_003
# 4    TEST_004
# ..        ...
# 125  TEST_125
# 126  TEST_126
# 127  TEST_127
# 128  TEST_128
# 129  TEST_129
#
# [130 rows x 1 columns]

# %%
submission
# Out:
#         vec_0     vec_1     vec_2     vec_3     vec_4     vec_5     vec_6  \
# 0    0.042157  0.110453  0.047679 -0.023928  0.064065 -0.028182  0.008371
# 1   -0.017632  0.012751 -0.024733  0.025530  0.093969 -0.010829  0.030211
# 2   -0.007298 -0.046221 -0.038921 -0.017196  0.130244 -0.039105  0.020284
# 3   -0.028322 -0.011159 -0.003201  0.017152  0.070116 -0.094935 -0.039363
# 4    0.025546 -0.002228 -0.022075 -0.068469  0.109451 -0.029035  0.069532
# ..        ...       ...       ...       ...       ...       ...       ...
# 125 -0.013936 -0.005947  0.045813 -0.011203  0.125854 -0.010155  0.052437
# 126  0.011456 -0.036085 -0.044864 -0.006485  0.109058  0.001157  0.008894
# 127 -0.010161  0.008079 -0.009164  0.040240  0.081483 -0.030591  0.007630
# 128  0.029554  0.024604 -0.094784 -0.015168  0.077939 -0.049938 -0.003080
# 129  0.015579 -0.013476 -0.003931  0.003299  0.094400 -0.009214  0.016007
#
#         vec_7     vec_8     vec_9  ...   vec_502   vec_503   vec_504  \
# 0    0.009099  0.027948  0.033894  ... -0.024371 -0.049183  0.046511
# 1   -0.044759 -0.028521  0.013528  ... -0.041069 -0.035862  0.016926
# 2   -0.015590  0.064194  0.041591  ... -0.039106  0.020225  0.068059
# 3   -0.014712 -0.018029  0.013406  ... -0.018566 -0.019476  0.053251
# 4    0.063616  0.014408  0.002609  ... -0.000326 -0.012158  0.008391
# ..        ...       ...       ...  ...       ...       ...       ...
# 125  0.052894  0.044627  0.023029  ... -0.001679  0.048596  0.025770
# 126  0.030218  0.013328  0.023062  ... -0.045524 -0.036997  0.052447
# 127 -0.026661 -0.049713  0.020585  ... -0.021081 -0.096137  0.029437
# 128 -0.022820  0.043833  0.036563  ... -0.043556  0.036434 -0.020236
# 129  0.007738  0.074313 -0.008566  ... -0.036235 -0.030249 -0.026298
#
#       vec_505   vec_506   vec_507   vec_508   vec_509   vec_510   vec_511
# 0   -0.049165 -0.007734  0.029142  0.020305 -0.000718 -0.009978  0.040244
# 1   -0.025517 -0.030209  0.040165 -0.004050 -0.011119  0.000948  0.016093
# 2   -0.033572  0.002280 -0.029602 -0.029154 -0.018547 -0.036767  0.101903
# 3   -0.040362  0.004668  0.028740 -0.016223 -0.075514 -0.022465  0.079249
# 4    0.015916 -0.011787  0.003652 -0.002448  0.060200 -0.021662  0.070612
# ..        ...       ...       ...       ...       ...       ...       ...
# 125 -0.022390  0.046235  0.011444  0.066517 -0.069829  0.011634  0.025972
# 126 -0.030193 -0.006129  0.020568 -0.003103 -0.016428  0.007753  0.061514
# 127 -0.050750 -0.024995  0.058477  0.050730  0.026604 -0.007136 -0.012916
# 128 -0.006427 -0.024800  0.047569 -0.088198  0.020790  0.026581 -0.061856
# 129 -0.015567  0.053479  0.013262 -0.081229  0.009453 -0.034273  0.015914
#
# [130 rows x 512 columns]

# %%
sub = pd.concat([total_submission, submission] , axis = 1)

# %%
sub.to_csv('orion_submission.csv', index = False) #Rename
